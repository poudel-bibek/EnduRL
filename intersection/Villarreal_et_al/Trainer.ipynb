# %%
# !python train.py intersection
# Out:
# /mnt/c/Users/09_gi/Desktop/Beyond-Simulated-Drivers/flow/utils/flow_warnings.py:26: PendingDeprecationWarning: The attribute departLane in InFlows is deprecated, use depart_lane instead.
#   PendingDeprecationWarning
# /mnt/c/Users/09_gi/Desktop/Beyond-Simulated-Drivers/flow/utils/flow_warnings.py:26: PendingDeprecationWarning: The attribute departSpeed in InFlows is deprecated, use depart_speed instead.
#   PendingDeprecationWarning
# /mnt/c/Users/09_gi/Desktop/Beyond-Simulated-Drivers/flow/utils/flow_warnings.py:26: PendingDeprecationWarning: The attribute departLane in InFlows is deprecated, use depart_lane instead.
#   PendingDeprecationWarning
# /mnt/c/Users/09_gi/Desktop/Beyond-Simulated-Drivers/flow/utils/flow_warnings.py:26: PendingDeprecationWarning: The attribute departSpeed in InFlows is deprecated, use depart_speed instead.
#   PendingDeprecationWarning
# ...
