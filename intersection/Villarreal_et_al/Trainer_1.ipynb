# %%
# !python train.py intersection
# Out:
# /mnt/c/Users/bpoudel3/Desktop/flow/flow/utils/flow_warnings.py:26: PendingDeprecationWarning: The attribute departLane in InFlows is deprecated, use depart_lane instead.
#   PendingDeprecationWarning
# /mnt/c/Users/bpoudel3/Desktop/flow/flow/utils/flow_warnings.py:26: PendingDeprecationWarning: The attribute departSpeed in InFlows is deprecated, use depart_speed instead.
#   PendingDeprecationWarning
# /mnt/c/Users/bpoudel3/Desktop/flow/flow/utils/flow_warnings.py:26: PendingDeprecationWarning: The attribute departLane in InFlows is deprecated, use depart_lane instead.
#   PendingDeprecationWarning
# /mnt/c/Users/bpoudel3/Desktop/flow/flow/utils/flow_warnings.py:26: PendingDeprecationWarning: The attribute departSpeed in InFlows is deprecated, use depart_speed instead.
#   PendingDeprecationWarning
# /mnt/c/Users/bpoudel3/Desktop/flow/flow/utils/flow_warnings.py:26: PendingDeprecationWarning: The attribute departLane in InFlows is deprecated, use depart_lane instead.
# ...
