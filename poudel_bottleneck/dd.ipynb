# %%
#PPO_DensityAwareBottleneckEnv-v0_a810b000_2023-09-15_10-03-33byrumwt9

NUM_ROLLOUTS = 5
# !python test_rllib.py ./Ours/Trained_policies/ten_percent/PPO_DensityAwareBottleneckEnv-v0_a810b000_2023-09-15_10-03-33byrumwt9 1\
--method ours --num_rollouts $NUM_ROLLOUTS --gen_emission --shock --render
# Out:
# 2023-09-15 10:12:13,596	WARNING services.py:597 -- setpgrp failed, processes may not be cleaned up properly: [Errno 1] Operation not permitted.
# 2023-09-15 10:12:13,596	INFO resource_spec.py:216 -- Starting Ray with 30.03 GiB memory available for workers and up to 15.04 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# 2023-09-15 10:12:13,913	INFO trainer.py:371 -- Tip: set 'eager': true or the --eager flag to enable TensorFlow eager execution
# 2023-09-15 10:12:13,922	INFO trainer.py:512 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# 2023-09-15 10:12:17,206	WARNING util.py:45 -- Install gputil for GPU system monitoring.
# 2023-09-15 10:12:17,282	INFO trainable.py:346 -- Restored from checkpoint: ./Ours/Trained_policies/ten_percent/PPO_DensityAwareBottleneckEnv-v0_a810b000_2023-09-15_10-03-33byrumwt9/checkpoint_1/checkpoint-1
# 2023-09-15 10:12:17,282	INFO trainable.py:353 -- Current state after restoring: {'_iteration': 1, '_timesteps_total': 115200, '_time_total': 373.5308208465576, '_episodes_total': 32}
# Frequency: 57
# Intensity: -2.2279034777023994
# Duration: 2.0
# Intensity: -1.6905553166826037
# Duration: 1.0
# Intensity: -1.7341675396782512
# Duration: 1.6
# Intensity: -1.7399810702332024
# Duration: 1.6
# Intensity: -2.84317773916716
# Duration: 2.1
# Intensity: -2.3875101583257203
# Duration: 1.6
# Intensity: -1.3347189397076769
# Duration: 1.9
# Intensity: -1.9506492380243
# Duration: 0.5
# Intensity: -2.4127980671571
# Duration: 1.7
# Intensity: -1.2362839282123033
# Duration: 2.2
# Intensity: -2.053527311004255
# Duration: 1.1
# Intensity: -2.5502627597724388
# Duration: 0.7
# Intensity: -2.0471050524119376
# Duration: 1.2
# Intensity: -2.784561885699181
# Duration: 1.7
# Intensity: -2.876332627430922
# Duration: 2.1
# Intensity: -2.135819513417738
# Duration: 1.1
# Intensity: -1.988526011497227
# Duration: 0.6
# Intensity: -2.9422760649552204
# Duration: 1.0
# Intensity: -2.5187913863253195
# Duration: 1.1
# Intensity: -1.8590010800118102
# Duration: 1.6
# Intensity: -2.274507019727352
# Duration: 0.6
# Intensity: -2.870439258810865
# Duration: 2.0
# Intensity: -1.2921271055316126
# Duration: 1.0
# Intensity: -2.5127094896168
# Duration: 1.7
# Intensity: -1.3166171281012893
# Duration: 0.5
# Intensity: -2.1169613162821603
# Duration: 1.4
# Intensity: -2.581156085926933
# Duration: 1.4
# Intensity: -1.2950393295117397
# Duration: 0.5
# Intensity: -2.3914448626387044
# Duration: 1.5
# Intensity: -1.880282958784273
# Duration: 1.1
# Intensity: -1.6489292328402263
# Duration: 1.7
# Intensity: -2.8547640517092985
# Duration: 1.7
# Intensity: -1.52616749681357
# Duration: 0.7
# Intensity: -1.8389482732209472
# Duration: 1.6
# Intensity: -2.2869604046742835
# Duration: 0.9
# Intensity: -1.3265137081072005
# Duration: 0.5
# Intensity: -2.820629818348813
# Duration: 1.0
# Intensity: -2.927505874620751
# Duration: 1.0
# Intensity: -2.117673863708087
# Duration: 1.4
# Intensity: -2.518422809538748
# Duration: 1.9
# Intensity: -1.0668918915255385
# Duration: 1.4
# Intensity: -2.18899244753955
# Duration: 0.7
# Intensity: -2.114271560194285
# Duration: 2.0
# Intensity: -2.4743472878052257
# Duration: 1.9
# Intensity: -2.040091204019574
# Duration: 1.7
# Intensity: -1.5768650408130815
# Duration: 2.1
# Intensity: -1.6094951307904621
# Duration: 0.9
# Intensity: -1.8503257114827416
# Duration: 1.5
# Intensity: -2.2778356156408948
# Duration: 0.7
# Intensity: -2.7012797440045224
# Duration: 1.2
# Intensity: -2.1492006382774482
# Duration: 1.6
# Intensity: -1.0212064706326411
# Duration: 2.1
# Intensity: -1.761015934456168
# Duration: 0.7
# Intensity: -1.8453546342134655
# Duration: 1.7
# Intensity: -1.6658923436317903
# Duration: 2.0
# Intensity: -2.0283291329676834
# Duration: 0.7
# Intensity: -1.4917266399019282
# Duration: 1.7
# Durations:  [20. 10. 16. 16. 21. 16. 19.  5. 17. 22. 11.  7. 12. 17. 21. 11.  6. 10.
#  11. 16.  6. 20. 10. 17.  5. 14. 14.  5. 15. 11. 17. 17.  7. 16.  9.  5.
#  10. 10. 14. 19. 14.  7. 20. 19. 17. 21.  9. 15.  7. 12. 16. 21.  7. 17.
#  20.  7. 17.]
# Start times:  [ 7400  7463  7527  7591  7655  7719  7783  7847  7911  7975  8039  8103
#   8167  8231  8295  8359  8423  8487  8551  8615  8679  8743  8807  8871
#   8935  8999  9063  9127  9191  9255  9319  9383  9447  9511  9575  9639
#   9703  9767  9831  9895  9959 10023 10087 10151 10215 10279 10343 10407
#  10471 10535 10599 10663 10727 10791 10855 10919 10983]
# End times:  [7420.0, 7473.0, 7543.0, 7607.0, 7676.0, 7735.0, 7802.0, 7852.0, 7928.0, 7997.0, 8050.0, 8110.0, 8179.0, 8248.0, 8316.0, 8370.0, 8429.0, 8497.0, 8562.0, 8631.0, 8685.0, 8763.0, 8817.0, 8888.0, 8940.0, 9013.0, 9077.0, 9132.0, 9206.0, 9266.0, 9336.0, 9400.0, 9454.0, 9527.0, 9584.0, 9644.0, 9713.0, 9777.0, 9845.0, 9914.0, 9973.0, 10030.0, 10107.0, 10170.0, 10232.0, 10300.0, 10352.0, 10422.0, 10478.0, 10547.0, 10615.0, 10684.0, 10734.0, 10808.0, 10875.0, 10926.0, 11000.0]
# Shock times:
#  [[ 7400.  7420.]
#  [ 7463.  7473.]
#  [ 7527.  7543.]
#  [ 7591.  7607.]
#  [ 7655.  7676.]
#  [ 7719.  7735.]
#  [ 7783.  7802.]
#  [ 7847.  7852.]
#  [ 7911.  7928.]
#  [ 7975.  7997.]
#  [ 8039.  8050.]
#  [ 8103.  8110.]
#  [ 8167.  8179.]
#  [ 8231.  8248.]
#  [ 8295.  8316.]
#  [ 8359.  8370.]
#  [ 8423.  8429.]
#  [ 8487.  8497.]
#  [ 8551.  8562.]
#  [ 8615.  8631.]
#  [ 8679.  8685.]
#  [ 8743.  8763.]
#  [ 8807.  8817.]
#  [ 8871.  8888.]
#  [ 8935.  8940.]
#  [ 8999.  9013.]
#  [ 9063.  9077.]
#  [ 9127.  9132.]
#  [ 9191.  9206.]
#  [ 9255.  9266.]
#  [ 9319.  9336.]
#  [ 9383.  9400.]
#  [ 9447.  9454.]
#  [ 9511.  9527.]
#  [ 9575.  9584.]
#  [ 9639.  9644.]
#  [ 9703.  9713.]
#  [ 9767.  9777.]
#  [ 9831.  9845.]
#  [ 9895.  9914.]
#  [ 9959.  9973.]
#  [10023. 10030.]
#  [10087. 10107.]
#  [10151. 10170.]
#  [10215. 10232.]
#  [10279. 10300.]
#  [10343. 10352.]
#  [10407. 10422.]
#  [10471. 10478.]
#  [10535. 10547.]
#  [10599. 10615.]
#  [10663. 10684.]
#  [10727. 10734.]
#  [10791. 10808.]
#  [10855. 10875.]
#  [10919. 10926.]
#  [10983. 11000.]]
# Traceback (most recent call last):
#   File "test_rllib.py", line 454, in <module>
#     visualizer_rllib(args)
#   File "test_rllib.py", line 282, in visualizer_rllib
#     state, reward, done, _ = env.step(action)
#   File "/mnt/c/Users/09_gi/Desktop/flow/flow/envs/base.py", line 369, in step
#     self.k.simulation.simulation_step()
#   File "/mnt/c/Users/09_gi/Desktop/flow/flow/core/kernel/simulation/traci.py", line 92, in simulation_step
#     self.kernel_api.simulationStep()
#   File "/home/kurukshetra/anaconda3/envs/flow/lib/python3.7/site-packages/traci/connection.py", line 323, in simulationStep
#     result = self._sendExact()
#   File "/home/kurukshetra/anaconda3/envs/flow/lib/python3.7/site-packages/traci/connection.py", line 99, in _sendExact
#     raise FatalTraCIError("connection closed by SUMO")
# traci.exceptions.FatalTraCIError: connection closed by SUMO
# /mnt/c/Users/09_gi/Desktop/flow/poudel_bottleneck/test_time_rollout/ours/bottleneck_ours_20230915-1012131694787133.9237943-0_emission.csv /mnt/c/Users/09_gi/Desktop/flow/poudel_bottleneck/test_time_rollout/ours
