# %%
NUM_ROLLOUTS = 5
# !python classic.py --method bcm --gen_emission --num_rollouts $NUM_ROLLOUTS --shock --render
# Out:
# /mnt/c/Users/09_gi/Desktop/flow/flow/utils/flow_warnings.py:26: PendingDeprecationWarning: The attribute departLane in InFlows is deprecated, use depart_lane instead.
#   PendingDeprecationWarning
# /mnt/c/Users/09_gi/Desktop/flow/flow/utils/flow_warnings.py:26: PendingDeprecationWarning: The attribute departSpeed in InFlows is deprecated, use depart_speed instead.
#   PendingDeprecationWarning
# /mnt/c/Users/09_gi/Desktop/flow/flow/utils/flow_warnings.py:26: PendingDeprecationWarning: The attribute departLane in InFlows is deprecated, use depart_lane instead.
#   PendingDeprecationWarning
# /mnt/c/Users/09_gi/Desktop/flow/flow/utils/flow_warnings.py:26: PendingDeprecationWarning: The attribute departSpeed in InFlows is deprecated, use depart_speed instead.
#   PendingDeprecationWarning
# Frequency: 42
# Intensity: -1.5960670602934233
# Duration: 0.6
# Intensity: -2.562217706758811
# Duration: 1.0
# Intensity: -2.610110199055105
# Duration: 0.9
# Intensity: -1.3676161250626562
# Duration: 0.9
# Intensity: -1.1180241278594758
# Duration: 1.4
# Intensity: -2.1787481488082254
# Duration: 1.6
# Intensity: -1.5064964935452245
# Duration: 2.0
# Intensity: -1.8248233451396487
# Duration: 0.9
# Intensity: -1.0049743037060272
# Duration: 1.4
# Intensity: -1.3238513481707133
# Duration: 1.6
# Intensity: -2.0387635623425124
# Duration: 1.7
# Intensity: -2.0285175187243745
# Duration: 1.7
# Intensity: -2.8819555476520744
# Duration: 2.0
# Intensity: -2.9681572333162323
# Duration: 1.7
# Intensity: -2.9559963417314528
# Duration: 1.0
# Intensity: -2.607503946948912
# Duration: 2.1
# Intensity: -2.7191629307942344
# Duration: 1.1
# Intensity: -1.5370188866723837
# Duration: 0.4
# Intensity: -2.9589311219430092
# Duration: 1.9
# Intensity: -1.9690881695196643
# Duration: 1.7
# Intensity: -1.2146855411311348
# Duration: 0.6
# Intensity: -1.4082201387118776
# Duration: 1.4
# Intensity: -1.2186111559472708
# Duration: 0.7
# Intensity: -2.1965705956516635
# Duration: 1.7
# Intensity: -2.3010880415211368
# Duration: 1.5
# Intensity: -1.5804926423080108
# Duration: 1.6
# Intensity: -2.9830296335303856
# Duration: 1.9
# Intensity: -2.2995265650029575
# Duration: 0.4
# Intensity: -1.3854078296341903
# Duration: 1.5
# Intensity: -2.1311403907729876
# Duration: 1.2
# Intensity: -2.871872545498011
# Duration: 1.7
# Intensity: -2.6766232680583486
# Duration: 1.1
# Intensity: -2.876169095549865
# Duration: 0.9
# Intensity: -2.9065100620354416
# Duration: 2.5
# Intensity: -1.9552930316034793
# Duration: 1.2
# Intensity: -1.2491588915053782
# Duration: 0.5
# Intensity: -2.499248856138652
# Duration: 1.1
# Intensity: -2.4041562659983766
# Duration: 1.4
# Intensity: -1.5293823180550052
# Duration: 1.4
# Intensity: -2.25459669997855
# Duration: 2.0
# Intensity: -2.2670009245035185
# Duration: 1.9
# Intensity: -2.3330266960223724
# Duration: 2.2
# Durations:  [ 6. 10.  9.  9. 14. 16. 20.  9. 14. 16. 17. 17. 20. 17. 10. 21. 11.  4.
#  19. 17.  6. 14.  7. 17. 15. 16. 19.  4. 15. 12. 17. 11.  9. 25. 12.  5.
#  11. 14. 14. 20. 19. 22.]
# Start times:  [ 7400  7487  7574  7661  7749  7836  7923  8010  8098  8185  8272  8359
#   8447  8534  8621  8709  8796  8883  8970  9058  9145  9232  9319  9407
#   9494  9581  9668  9756  9843  9930 10018 10105 10192 10279 10367 10454
#  10541 10628 10716 10803 10890 10978]
# End times:  [7406.0, 7497.0, 7583.0, 7670.0, 7763.0, 7852.0, 7943.0, 8019.0, 8112.0, 8201.0, 8289.0, 8376.0, 8467.0, 8551.0, 8631.0, 8730.0, 8807.0, 8887.0, 8989.0, 9075.0, 9151.0, 9246.0, 9326.0, 9424.0, 9509.0, 9597.0, 9687.0, 9760.0, 9858.0, 9942.0, 10035.0, 10116.0, 10201.0, 10304.0, 10379.0, 10459.0, 10552.0, 10642.0, 10730.0, 10823.0, 10909.0, 11000.0]
# Shock times:
#  [[ 7400.  7406.]
#  [ 7487.  7497.]
#  [ 7574.  7583.]
#  [ 7661.  7670.]
#  [ 7749.  7763.]
#  [ 7836.  7852.]
#  [ 7923.  7943.]
#  [ 8010.  8019.]
#  [ 8098.  8112.]
#  [ 8185.  8201.]
#  [ 8272.  8289.]
#  [ 8359.  8376.]
#  [ 8447.  8467.]
#  [ 8534.  8551.]
#  [ 8621.  8631.]
#  [ 8709.  8730.]
#  [ 8796.  8807.]
#  [ 8883.  8887.]
#  [ 8970.  8989.]
#  [ 9058.  9075.]
#  [ 9145.  9151.]
#  [ 9232.  9246.]
#  [ 9319.  9326.]
#  [ 9407.  9424.]
#  [ 9494.  9509.]
#  [ 9581.  9597.]
#  [ 9668.  9687.]
#  [ 9756.  9760.]
#  [ 9843.  9858.]
#  [ 9930.  9942.]
#  [10018. 10035.]
#  [10105. 10116.]
#  [10192. 10201.]
#  [10279. 10304.]
#  [10367. 10379.]
#  [10454. 10459.]
#  [10541. 10552.]
#  [10628. 10642.]
#  [10716. 10730.]
#  [10803. 10823.]
#  [10890. 10909.]
#  [10978. 11000.]]
# Changing vehicle type for classic_00.0 to bcm
# Changing vehicle type for classic_00.1 to bcm
# Changing vehicle type for classic_00.2 to bcm
# Changing vehicle type for classic_00.3 to bcm
# Changing vehicle type for classic_00.4 to bcm
# Changing vehicle type for classic_00.5 to bcm
# Changing vehicle type for classic_00.6 to bcm
# Changing vehicle type for classic_00.7 to bcm
# Changing vehicle type for classic_00.8 to bcm
# Changing vehicle type for classic_00.9 to bcm
# Changing vehicle type for classic_00.10 to bcm
# Changing vehicle type for classic_00.11 to bcm
# Changing vehicle type for classic_00.12 to bcm
# Changing vehicle type for classic_00.13 to bcm
# Changing vehicle type for classic_00.14 to bcm
# Changing vehicle type for classic_00.15 to bcm
# Changing vehicle type for classic_00.16 to bcm
# Changing vehicle type for classic_00.17 to bcm
# Changing vehicle type for classic_00.18 to bcm
# Changing vehicle type for classic_00.19 to bcm
# Changing vehicle type for classic_00.20 to bcm
# Changing vehicle type for classic_00.21 to bcm
# Changing vehicle type for classic_00.22 to bcm
# Changing vehicle type for classic_00.23 to bcm
# Changing vehicle type for classic_00.24 to bcm
# Changing vehicle type for classic_00.25 to bcm
# Changing vehicle type for classic_00.26 to bcm
# Changing vehicle type for classic_00.27 to bcm
# Changing vehicle type for classic_00.28 to bcm
# Changing vehicle type for classic_00.29 to bcm
# Changing vehicle type for classic_00.30 to bcm
# Changing vehicle type for classic_00.31 to bcm
# Changing vehicle type for classic_00.32 to bcm
# Changing vehicle type for classic_00.33 to bcm
# Changing vehicle type for classic_00.34 to bcm
# Changing vehicle type for classic_00.35 to bcm
# Changing vehicle type for classic_00.36 to bcm
# Changing vehicle type for classic_00.37 to bcm
# Changing vehicle type for classic_00.38 to bcm
# Changing vehicle type for classic_00.39 to bcm
# Changing vehicle type for classic_00.40 to bcm
# Changing vehicle type for classic_00.41 to bcm
# Changing vehicle type for classic_00.42 to bcm
# Changing vehicle type for classic_00.43 to bcm
# Changing vehicle type for classic_00.44 to bcm
# Changing vehicle type for classic_00.45 to bcm
# Changing vehicle type for classic_00.46 to bcm
# Changing vehicle type for classic_00.47 to bcm
# Changing vehicle type for classic_00.48 to bcm
# Changing vehicle type for classic_00.49 to bcm
# Changing vehicle type for classic_00.50 to bcm
# Changing vehicle type for classic_00.51 to bcm
# Changing vehicle type for classic_00.52 to bcm
# Changing vehicle type for classic_00.53 to bcm
# Changing vehicle type for classic_00.54 to bcm
# Changing vehicle type for classic_00.55 to bcm
# Changing vehicle type for classic_00.56 to bcm
# Changing vehicle type for classic_00.57 to bcm
# Changing vehicle type for classic_00.58 to bcm
# Changing vehicle type for classic_00.59 to bcm
# Changing vehicle type for classic_00.60 to bcm
# Changing vehicle type for classic_00.61 to bcm
# Changing vehicle type for classic_00.62 to bcm
# Changing vehicle type for classic_00.63 to bcm
# Changing vehicle type for classic_00.64 to bcm
# Changing vehicle type for classic_00.65 to bcm
# Changing vehicle type for classic_00.66 to bcm
# Changing vehicle type for classic_00.67 to bcm
# Changing vehicle type for classic_00.68 to bcm
# Changing vehicle type for classic_00.69 to bcm
# Changing vehicle type for classic_00.70 to bcm
# Changing vehicle type for classic_00.71 to bcm
# Changing vehicle type for classic_00.72 to bcm
# Changing vehicle type for classic_00.73 to bcm
# Changing vehicle type for classic_00.74 to bcm
# Changing vehicle type for classic_00.75 to bcm
# Changing vehicle type for classic_00.76 to bcm
# Changing vehicle type for classic_00.77 to bcm
# Changing vehicle type for classic_00.78 to bcm
# Changing vehicle type for classic_00.79 to bcm
# Changing vehicle type for classic_00.80 to bcm
# Changing vehicle type for classic_00.81 to bcm
# Changing vehicle type for classic_00.82 to bcm
# Changing vehicle type for classic_00.83 to bcm
# Changing vehicle type for classic_00.84 to bcm
# Changing vehicle type for classic_00.85 to bcm
# Changing vehicle type for classic_00.86 to bcm
# Changing vehicle type for classic_00.87 to bcm
# Changing vehicle type for classic_00.88 to bcm
# Changing vehicle type for classic_00.89 to bcm
# Changing vehicle type for classic_00.90 to bcm
# Changing vehicle type for classic_00.91 to bcm
# Changing vehicle type for classic_00.92 to bcm
# Changing vehicle type for classic_00.93 to bcm
# Changing vehicle type for classic_00.94 to bcm
# Changing vehicle type for classic_00.95 to bcm
# Changing vehicle type for classic_00.96 to bcm
# Changing vehicle type for classic_00.97 to bcm
# Changing vehicle type for classic_00.98 to bcm
# Changing vehicle type for classic_00.99 to bcm
# Changing vehicle type for classic_00.100 to bcm
# Changing vehicle type for classic_00.101 to bcm
# Changing vehicle type for classic_00.102 to bcm
# Changing vehicle type for classic_00.103 to bcm
# Changing vehicle type for classic_00.104 to bcm
# Changing vehicle type for classic_00.105 to bcm
# Changing vehicle type for classic_00.106 to bcm
# Changing vehicle type for classic_00.107 to bcm
# Changing vehicle type for classic_00.108 to bcm
# Changing vehicle type for classic_00.109 to bcm
# Changing vehicle type for classic_00.110 to bcm
# Changing vehicle type for classic_00.111 to bcm
# Changing vehicle type for classic_00.112 to bcm
# Changing vehicle type for classic_00.113 to bcm
# Changing vehicle type for classic_00.114 to bcm
# Changing vehicle type for classic_00.115 to bcm
# Changing vehicle type for classic_00.116 to bcm
# Changing vehicle type for classic_00.117 to bcm
# Changing vehicle type for classic_00.118 to bcm
# Changing vehicle type for classic_00.119 to bcm
# Changing vehicle type for classic_00.120 to bcm
# Changing vehicle type for classic_00.121 to bcm
# Changing vehicle type for classic_00.122 to bcm
# Changing vehicle type for classic_00.123 to bcm
# Changing vehicle type for classic_00.124 to bcm
# Changing vehicle type for classic_00.125 to bcm
# Changing vehicle type for classic_00.126 to bcm
# Changing vehicle type for classic_00.127 to bcm
# Changing vehicle type for classic_00.128 to bcm
# Changing vehicle type for classic_00.129 to bcm
# Changing vehicle type for classic_00.130 to bcm
# Changing vehicle type for classic_00.131 to bcm
# Changing vehicle type for classic_00.132 to bcm
# Changing vehicle type for classic_00.133 to bcm
# Changing vehicle type for classic_00.134 to bcm
# Changing vehicle type for classic_00.135 to bcm
# Changing vehicle type for classic_00.136 to bcm
# Changing vehicle type for classic_00.137 to bcm
# Changing vehicle type for classic_00.138 to bcm
# Changing vehicle type for classic_00.139 to bcm
# Changing vehicle type for classic_00.140 to bcm
# Changing vehicle type for classic_00.141 to bcm
# Changing vehicle type for classic_00.142 to bcm
# Changing vehicle type for classic_00.143 to bcm
# Changing vehicle type for classic_00.144 to bcm
# Changing vehicle type for classic_00.145 to bcm
# Changing vehicle type for classic_00.146 to bcm
# Changing vehicle type for classic_00.147 to bcm
#
#
# Shock ids: ['flow_10.477' 'flow_10.568' 'flow_10.536' 'flow_10.550']
#
#
# Step = 7400, Shock params: (-1.5960670602934233, 0.6, 42) applied to vehicle ['flow_10.477' 'flow_10.568' 'flow_10.536' 'flow_10.550']
#
# Step = 7401, Shock params: (-1.5960670602934233, 0.6, 42) applied to vehicle ['flow_10.477' 'flow_10.568' 'flow_10.536' 'flow_10.550']
#
# Step = 7402, Shock params: (-1.5960670602934233, 0.6, 42) applied to vehicle ['flow_10.477' 'flow_10.568' 'flow_10.536' 'flow_10.550']
#
# Step = 7403, Shock params: (-1.5960670602934233, 0.6, 42) applied to vehicle ['flow_10.477' 'flow_10.568' 'flow_10.536' 'flow_10.550']
#
# Step = 7404, Shock params: (-1.5960670602934233, 0.6, 42) applied to vehicle ['flow_10.477' 'flow_10.568' 'flow_10.536' 'flow_10.550']
#
# Step = 7405, Shock params: (-1.5960670602934233, 0.6, 42) applied to vehicle ['flow_10.477' 'flow_10.568' 'flow_10.536' 'flow_10.550']
#
#
#
# Shock ids: ['flow_10.563' 'flow_10.526' 'flow_10.568' 'flow_10.560']
#
#
# Changing vehicle type for classic_00.148 to bcm
# Changing vehicle type for classic_00.149 to bcm
# Step = 7487, Shock params: (-2.562217706758811, 1.0, 42) applied to vehicle ['flow_10.563' 'flow_10.526' 'flow_10.568' 'flow_10.560']
#
# Step = 7488, Shock params: (-2.562217706758811, 1.0, 42) applied to vehicle ['flow_10.563' 'flow_10.526' 'flow_10.568' 'flow_10.560']
#
# Step = 7489, Shock params: (-2.562217706758811, 1.0, 42) applied to vehicle ['flow_10.563' 'flow_10.526' 'flow_10.568' 'flow_10.560']
#
# Step = 7490, Shock params: (-2.562217706758811, 1.0, 42) applied to vehicle ['flow_10.563' 'flow_10.526' 'flow_10.568' 'flow_10.560']
#
# Step = 7491, Shock params: (-2.562217706758811, 1.0, 42) applied to vehicle ['flow_10.563' 'flow_10.526' 'flow_10.568' 'flow_10.560']
#
# Step = 7492, Shock params: (-2.562217706758811, 1.0, 42) applied to vehicle ['flow_10.563' 'flow_10.526' 'flow_10.568' 'flow_10.560']
#
# Step = 7493, Shock params: (-2.562217706758811, 1.0, 42) applied to vehicle ['flow_10.563' 'flow_10.526' 'flow_10.568' 'flow_10.560']
#
# Step = 7494, Shock params: (-2.562217706758811, 1.0, 42) applied to vehicle ['flow_10.563' 'flow_10.526' 'flow_10.568' 'flow_10.560']
#
# Step = 7495, Shock params: (-2.562217706758811, 1.0, 42) applied to vehicle ['flow_10.563' 'flow_10.526' 'flow_10.568' 'flow_10.560']
#
# Step = 7496, Shock params: (-2.562217706758811, 1.0, 42) applied to vehicle ['flow_10.563' 'flow_10.526' 'flow_10.568' 'flow_10.560']
#
# Step = 7497, Shock params: (-2.562217706758811, 1.0, 42) applied to vehicle ['flow_10.563' 'flow_10.526' 'flow_10.568' 'flow_10.560']
#
#
#
# Shock ids: ['flow_10.546' 'flow_10.454' 'flow_10.533' 'flow_10.578']
#
#
# Changing vehicle type for classic_00.150 to bcm
# Changing vehicle type for classic_00.151 to bcm
# Step = 7574, Shock params: (-2.610110199055105, 0.9, 42) applied to vehicle ['flow_10.546' 'flow_10.454' 'flow_10.533' 'flow_10.578']
#
# Step = 7575, Shock params: (-2.610110199055105, 0.9, 42) applied to vehicle ['flow_10.546' 'flow_10.454' 'flow_10.533' 'flow_10.578']
#
# Step = 7576, Shock params: (-2.610110199055105, 0.9, 42) applied to vehicle ['flow_10.546' 'flow_10.454' 'flow_10.533' 'flow_10.578']
#
# Step = 7577, Shock params: (-2.610110199055105, 0.9, 42) applied to vehicle ['flow_10.546' 'flow_10.454' 'flow_10.533' 'flow_10.578']
#
# Step = 7578, Shock params: (-2.610110199055105, 0.9, 42) applied to vehicle ['flow_10.546' 'flow_10.454' 'flow_10.533' 'flow_10.578']
#
# Step = 7579, Shock params: (-2.610110199055105, 0.9, 42) applied to vehicle ['flow_10.546' 'flow_10.454' 'flow_10.533' 'flow_10.578']
#
# Step = 7580, Shock params: (-2.610110199055105, 0.9, 42) applied to vehicle ['flow_10.546' 'flow_10.454' 'flow_10.533' 'flow_10.578']
#
# Step = 7581, Shock params: (-2.610110199055105, 0.9, 42) applied to vehicle ['flow_10.546' 'flow_10.454' 'flow_10.533' 'flow_10.578']
#
# Step = 7582, Shock params: (-2.610110199055105, 0.9, 42) applied to vehicle ['flow_10.546' 'flow_10.454' 'flow_10.533' 'flow_10.578']
#
# Step = 7583, Shock params: (-2.610110199055105, 0.9, 42) applied to vehicle ['flow_10.546' 'flow_10.454' 'flow_10.533' 'flow_10.578']
#
#
#
# Shock ids: ['flow_10.520' 'flow_10.547' 'flow_10.584' 'flow_10.470']
#
#
# Changing vehicle type for classic_00.152 to bcm
# Changing vehicle type for classic_00.153 to bcm
# Step = 7661, Shock params: (-1.3676161250626562, 0.9, 42) applied to vehicle ['flow_10.520' 'flow_10.547' 'flow_10.584' 'flow_10.470']
#
# Step = 7662, Shock params: (-1.3676161250626562, 0.9, 42) applied to vehicle ['flow_10.520' 'flow_10.547' 'flow_10.584' 'flow_10.470']
#
# Step = 7663, Shock params: (-1.3676161250626562, 0.9, 42) applied to vehicle ['flow_10.520' 'flow_10.547' 'flow_10.584' 'flow_10.470']
#
# Step = 7664, Shock params: (-1.3676161250626562, 0.9, 42) applied to vehicle ['flow_10.520' 'flow_10.547' 'flow_10.584' 'flow_10.470']
#
# Step = 7665, Shock params: (-1.3676161250626562, 0.9, 42) applied to vehicle ['flow_10.520' 'flow_10.547' 'flow_10.584' 'flow_10.470']
#
# Step = 7666, Shock params: (-1.3676161250626562, 0.9, 42) applied to vehicle ['flow_10.520' 'flow_10.547' 'flow_10.584' 'flow_10.470']
#
# Step = 7667, Shock params: (-1.3676161250626562, 0.9, 42) applied to vehicle ['flow_10.520' 'flow_10.547' 'flow_10.584' 'flow_10.470']
#
# Step = 7668, Shock params: (-1.3676161250626562, 0.9, 42) applied to vehicle ['flow_10.520' 'flow_10.547' 'flow_10.584' 'flow_10.470']
# Step = 7669, Shock params: (-1.3676161250626562, 0.9, 42) applied to vehicle ['flow_10.520' 'flow_10.547' 'flow_10.584' 'flow_10.470']
#
# Step = 7670, Shock params: (-1.3676161250626562, 0.9, 42) applied to vehicle ['flow_10.520' 'flow_10.547' 'flow_10.584' 'flow_10.470']
#
#
#
# Shock ids: ['flow_10.428' 'flow_10.417' 'flow_10.482' 'flow_10.482']
#
#
# Changing vehicle type for classic_00.154 to bcm
# Step = 7749, Shock params: (-1.1180241278594758, 1.4, 42) applied to vehicle ['flow_10.428' 'flow_10.417' 'flow_10.482' 'flow_10.482']
#
# Step = 7750, Shock params: (-1.1180241278594758, 1.4, 42) applied to vehicle ['flow_10.428' 'flow_10.417' 'flow_10.482' 'flow_10.482']
#
# Step = 7751, Shock params: (-1.1180241278594758, 1.4, 42) applied to vehicle ['flow_10.428' 'flow_10.417' 'flow_10.482' 'flow_10.482']
#
# Step = 7752, Shock params: (-1.1180241278594758, 1.4, 42) applied to vehicle ['flow_10.428' 'flow_10.417' 'flow_10.482' 'flow_10.482']
#
# Step = 7753, Shock params: (-1.1180241278594758, 1.4, 42) applied to vehicle ['flow_10.428' 'flow_10.417' 'flow_10.482' 'flow_10.482']
#
# Step = 7754, Shock params: (-1.1180241278594758, 1.4, 42) applied to vehicle ['flow_10.428' 'flow_10.417' 'flow_10.482' 'flow_10.482']
#
# Step = 7755, Shock params: (-1.1180241278594758, 1.4, 42) applied to vehicle ['flow_10.428' 'flow_10.417' 'flow_10.482' 'flow_10.482']
#
# Step = 7756, Shock params: (-1.1180241278594758, 1.4, 42) applied to vehicle ['flow_10.428' 'flow_10.417' 'flow_10.482' 'flow_10.482']
#
# Step = 7757, Shock params: (-1.1180241278594758, 1.4, 42) applied to vehicle ['flow_10.428' 'flow_10.417' 'flow_10.482' 'flow_10.482']
#
# Step = 7758, Shock params: (-1.1180241278594758, 1.4, 42) applied to vehicle ['flow_10.428' 'flow_10.417' 'flow_10.482' 'flow_10.482']
#
# Changing vehicle type for classic_00.155 to bcm
# Step = 7759, Shock params: (-1.1180241278594758, 1.4, 42) applied to vehicle ['flow_10.428' 'flow_10.417' 'flow_10.482' 'flow_10.482']
#
# Step = 7760, Shock params: (-1.1180241278594758, 1.4, 42) applied to vehicle ['flow_10.428' 'flow_10.417' 'flow_10.482' 'flow_10.482']
#
# Step = 7761, Shock params: (-1.1180241278594758, 1.4, 42) applied to vehicle ['flow_10.428' 'flow_10.417' 'flow_10.482' 'flow_10.482']
#
# Step = 7762, Shock params: (-1.1180241278594758, 1.4, 42) applied to vehicle ['flow_10.428' 'flow_10.417' 'flow_10.482' 'flow_10.482']
#
#
#
# Shock ids: ['flow_10.478' 'flow_10.590' 'flow_10.583' 'flow_10.503']
#
#
# Changing vehicle type for classic_00.156 to bcm
# Step = 7836, Shock params: (-2.1787481488082254, 1.6, 42) applied to vehicle ['flow_10.478' 'flow_10.590' 'flow_10.583' 'flow_10.503']
#
# Step = 7837, Shock params: (-2.1787481488082254, 1.6, 42) applied to vehicle ['flow_10.478' 'flow_10.590' 'flow_10.583' 'flow_10.503']
#
# Step = 7838, Shock params: (-2.1787481488082254, 1.6, 42) applied to vehicle ['flow_10.478' 'flow_10.590' 'flow_10.583' 'flow_10.503']
#
# Step = 7839, Shock params: (-2.1787481488082254, 1.6, 42) applied to vehicle ['flow_10.478' 'flow_10.590' 'flow_10.583' 'flow_10.503']
#
# Step = 7840, Shock params: (-2.1787481488082254, 1.6, 42) applied to vehicle ['flow_10.478' 'flow_10.590' 'flow_10.583' 'flow_10.503']
#
# Step = 7841, Shock params: (-2.1787481488082254, 1.6, 42) applied to vehicle ['flow_10.478' 'flow_10.590' 'flow_10.583' 'flow_10.503']
#
# Step = 7842, Shock params: (-2.1787481488082254, 1.6, 42) applied to vehicle ['flow_10.478' 'flow_10.590' 'flow_10.583' 'flow_10.503']
#
# Step = 7843, Shock params: (-2.1787481488082254, 1.6, 42) applied to vehicle ['flow_10.478' 'flow_10.590' 'flow_10.583' 'flow_10.503']
#
# Step = 7844, Shock params: (-2.1787481488082254, 1.6, 42) applied to vehicle ['flow_10.478' 'flow_10.590' 'flow_10.583' 'flow_10.503']
#
# Step = 7845, Shock params: (-2.1787481488082254, 1.6, 42) applied to vehicle ['flow_10.478' 'flow_10.590' 'flow_10.583' 'flow_10.503']
#
# Step = 7846, Shock params: (-2.1787481488082254, 1.6, 42) applied to vehicle ['flow_10.478' 'flow_10.590' 'flow_10.583' 'flow_10.503']
#
# Step = 7847, Shock params: (-2.1787481488082254, 1.6, 42) applied to vehicle ['flow_10.478' 'flow_10.590' 'flow_10.583' 'flow_10.503']
#
# Step = 7848, Shock params: (-2.1787481488082254, 1.6, 42) applied to vehicle ['flow_10.478' 'flow_10.590' 'flow_10.583' 'flow_10.503']
#
# Step = 7849, Shock params: (-2.1787481488082254, 1.6, 42) applied to vehicle ['flow_10.478' 'flow_10.590' 'flow_10.583' 'flow_10.503']
#
# Step = 7850, Shock params: (-2.1787481488082254, 1.6, 42) applied to vehicle ['flow_10.478' 'flow_10.590' 'flow_10.583' 'flow_10.503']
#
# Step = 7851, Shock params: (-2.1787481488082254, 1.6, 42) applied to vehicle ['flow_10.478' 'flow_10.590' 'flow_10.583' 'flow_10.503']
#
#
#
# Shock ids: ['flow_10.538' 'flow_10.488' 'flow_10.598' 'flow_10.557']
#
#
# Changing vehicle type for classic_00.157 to bcm
# Changing vehicle type for classic_00.158 to bcm
# Step = 7923, Shock params: (-1.5064964935452245, 2.0, 42) applied to vehicle ['flow_10.538' 'flow_10.488' 'flow_10.598' 'flow_10.557']
#
# Step = 7924, Shock params: (-1.5064964935452245, 2.0, 42) applied to vehicle ['flow_10.538' 'flow_10.488' 'flow_10.598' 'flow_10.557']
#
# Step = 7925, Shock params: (-1.5064964935452245, 2.0, 42) applied to vehicle ['flow_10.538' 'flow_10.488' 'flow_10.598' 'flow_10.557']
#
# Step = 7926, Shock params: (-1.5064964935452245, 2.0, 42) applied to vehicle ['flow_10.538' 'flow_10.488' 'flow_10.598' 'flow_10.557']
#
# Step = 7927, Shock params: (-1.5064964935452245, 2.0, 42) applied to vehicle ['flow_10.538' 'flow_10.488' 'flow_10.598' 'flow_10.557']
#
# Step = 7928, Shock params: (-1.5064964935452245, 2.0, 42) applied to vehicle ['flow_10.538' 'flow_10.488' 'flow_10.598' 'flow_10.557']
#
# Step = 7929, Shock params: (-1.5064964935452245, 2.0, 42) applied to vehicle ['flow_10.538' 'flow_10.488' 'flow_10.598' 'flow_10.557']
#
# Step = 7930, Shock params: (-1.5064964935452245, 2.0, 42) applied to vehicle ['flow_10.538' 'flow_10.488' 'flow_10.598' 'flow_10.557']
#
# Step = 7931, Shock params: (-1.5064964935452245, 2.0, 42) applied to vehicle ['flow_10.538' 'flow_10.488' 'flow_10.598' 'flow_10.557']
#
# Step = 7932, Shock params: (-1.5064964935452245, 2.0, 42) applied to vehicle ['flow_10.538' 'flow_10.488' 'flow_10.598' 'flow_10.557']
#
# Step = 7933, Shock params: (-1.5064964935452245, 2.0, 42) applied to vehicle ['flow_10.538' 'flow_10.488' 'flow_10.598' 'flow_10.557']
#
# Step = 7934, Shock params: (-1.5064964935452245, 2.0, 42) applied to vehicle ['flow_10.538' 'flow_10.488' 'flow_10.598' 'flow_10.557']
#
# Step = 7935, Shock params: (-1.5064964935452245, 2.0, 42) applied to vehicle ['flow_10.538' 'flow_10.488' 'flow_10.598' 'flow_10.557']
#
# Step = 7936, Shock params: (-1.5064964935452245, 2.0, 42) applied to vehicle ['flow_10.538' 'flow_10.488' 'flow_10.598' 'flow_10.557']
#
# Step = 7937, Shock params: (-1.5064964935452245, 2.0, 42) applied to vehicle ['flow_10.538' 'flow_10.488' 'flow_10.598' 'flow_10.557']
#
# Step = 7938, Shock params: (-1.5064964935452245, 2.0, 42) applied to vehicle ['flow_10.538' 'flow_10.488' 'flow_10.598' 'flow_10.557']
#
# Step = 7939, Shock params: (-1.5064964935452245, 2.0, 42) applied to vehicle ['flow_10.538' 'flow_10.488' 'flow_10.598' 'flow_10.557']
#
# Step = 7940, Shock params: (-1.5064964935452245, 2.0, 42) applied to vehicle ['flow_10.538' 'flow_10.488' 'flow_10.598' 'flow_10.557']
#
# Step = 7941, Shock params: (-1.5064964935452245, 2.0, 42) applied to vehicle ['flow_10.538' 'flow_10.488' 'flow_10.598' 'flow_10.557']
#
# Step = 7942, Shock params: (-1.5064964935452245, 2.0, 42) applied to vehicle ['flow_10.538' 'flow_10.488' 'flow_10.598' 'flow_10.557']
#
#
#
# Shock ids: ['flow_10.600' 'flow_10.555' 'flow_10.613' 'flow_10.586']
#
#
# Changing vehicle type for classic_00.159 to bcm
# Changing vehicle type for classic_00.160 to bcm
# Step = 8010, Shock params: (-1.8248233451396487, 0.9, 42) applied to vehicle ['flow_10.600' 'flow_10.555' 'flow_10.613' 'flow_10.586']
#
# Step = 8011, Shock params: (-1.8248233451396487, 0.9, 42) applied to vehicle ['flow_10.600' 'flow_10.555' 'flow_10.613' 'flow_10.586']
#
# Step = 8012, Shock params: (-1.8248233451396487, 0.9, 42) applied to vehicle ['flow_10.600' 'flow_10.555' 'flow_10.613' 'flow_10.586']
#
# Step = 8013, Shock params: (-1.8248233451396487, 0.9, 42) applied to vehicle ['flow_10.600' 'flow_10.555' 'flow_10.613' 'flow_10.586']
#
# Step = 8014, Shock params: (-1.8248233451396487, 0.9, 42) applied to vehicle ['flow_10.600' 'flow_10.555' 'flow_10.613' 'flow_10.586']
# Step = 8015, Shock params: (-1.8248233451396487, 0.9, 42) applied to vehicle ['flow_10.600' 'flow_10.555' 'flow_10.613' 'flow_10.586']
#
# Step = 8016, Shock params: (-1.8248233451396487, 0.9, 42) applied to vehicle ['flow_10.600' 'flow_10.555' 'flow_10.613' 'flow_10.586']
#
# Step = 8017, Shock params: (-1.8248233451396487, 0.9, 42) applied to vehicle ['flow_10.600' 'flow_10.555' 'flow_10.613' 'flow_10.586']
#
# Step = 8018, Shock params: (-1.8248233451396487, 0.9, 42) applied to vehicle ['flow_10.600' 'flow_10.555' 'flow_10.613' 'flow_10.586']
#
# Step = 8019, Shock params: (-1.8248233451396487, 0.9, 42) applied to vehicle ['flow_10.600' 'flow_10.555' 'flow_10.613' 'flow_10.586']
#
#
#
# Shock ids: ['flow_10.530' 'flow_10.582' 'flow_10.611' 'flow_10.552']
#
#
# Changing vehicle type for classic_00.161 to bcm
# Step = 8098, Shock params: (-1.0049743037060272, 1.4, 42) applied to vehicle ['flow_10.530' 'flow_10.582' 'flow_10.611' 'flow_10.552']
#
# Step = 8099, Shock params: (-1.0049743037060272, 1.4, 42) applied to vehicle ['flow_10.530' 'flow_10.582' 'flow_10.611' 'flow_10.552']
#
# Step = 8100, Shock params: (-1.0049743037060272, 1.4, 42) applied to vehicle ['flow_10.530' 'flow_10.582' 'flow_10.611' 'flow_10.552']
#
# Step = 8101, Shock params: (-1.0049743037060272, 1.4, 42) applied to vehicle ['flow_10.530' 'flow_10.582' 'flow_10.611' 'flow_10.552']
#
# Step = 8102, Shock params: (-1.0049743037060272, 1.4, 42) applied to vehicle ['flow_10.530' 'flow_10.582' 'flow_10.611' 'flow_10.552']
#
# Step = 8103, Shock params: (-1.0049743037060272, 1.4, 42) applied to vehicle ['flow_10.530' 'flow_10.582' 'flow_10.611' 'flow_10.552']
#
# Step = 8104, Shock params: (-1.0049743037060272, 1.4, 42) applied to vehicle ['flow_10.530' 'flow_10.582' 'flow_10.611' 'flow_10.552']
#
# Step = 8105, Shock params: (-1.0049743037060272, 1.4, 42) applied to vehicle ['flow_10.530' 'flow_10.582' 'flow_10.611' 'flow_10.552']
#
# Step = 8106, Shock params: (-1.0049743037060272, 1.4, 42) applied to vehicle ['flow_10.530' 'flow_10.582' 'flow_10.611' 'flow_10.552']
#
# Step = 8107, Shock params: (-1.0049743037060272, 1.4, 42) applied to vehicle ['flow_10.530' 'flow_10.582' 'flow_10.611' 'flow_10.552']
#
# Step = 8108, Shock params: (-1.0049743037060272, 1.4, 42) applied to vehicle ['flow_10.530' 'flow_10.582' 'flow_10.611' 'flow_10.552']
#
# Changing vehicle type for classic_00.162 to bcm
# Step = 8109, Shock params: (-1.0049743037060272, 1.4, 42) applied to vehicle ['flow_10.530' 'flow_10.582' 'flow_10.611' 'flow_10.552']
#
# Step = 8110, Shock params: (-1.0049743037060272, 1.4, 42) applied to vehicle ['flow_10.530' 'flow_10.582' 'flow_10.611' 'flow_10.552']
#
# Step = 8111, Shock params: (-1.0049743037060272, 1.4, 42) applied to vehicle ['flow_10.530' 'flow_10.582' 'flow_10.611' 'flow_10.552']
#
#
#
# Shock ids: ['flow_10.564' 'flow_10.594' 'flow_10.564' 'flow_10.528']
#
#
# Changing vehicle type for classic_00.163 to bcm
# Step = 8185, Shock params: (-1.3238513481707133, 1.6, 42) applied to vehicle ['flow_10.564' 'flow_10.594' 'flow_10.564' 'flow_10.528']
#
# Step = 8186, Shock params: (-1.3238513481707133, 1.6, 42) applied to vehicle ['flow_10.564' 'flow_10.594' 'flow_10.564' 'flow_10.528']
#
# Step = 8187, Shock params: (-1.3238513481707133, 1.6, 42) applied to vehicle ['flow_10.564' 'flow_10.594' 'flow_10.564' 'flow_10.528']
#
# Step = 8188, Shock params: (-1.3238513481707133, 1.6, 42) applied to vehicle ['flow_10.564' 'flow_10.594' 'flow_10.564' 'flow_10.528']
#
# Step = 8189, Shock params: (-1.3238513481707133, 1.6, 42) applied to vehicle ['flow_10.564' 'flow_10.594' 'flow_10.564' 'flow_10.528']
#
# Step = 8190, Shock params: (-1.3238513481707133, 1.6, 42) applied to vehicle ['flow_10.564' 'flow_10.594' 'flow_10.564' 'flow_10.528']
#
# Step = 8191, Shock params: (-1.3238513481707133, 1.6, 42) applied to vehicle ['flow_10.564' 'flow_10.594' 'flow_10.564' 'flow_10.528']
#
# Step = 8192, Shock params: (-1.3238513481707133, 1.6, 42) applied to vehicle ['flow_10.564' 'flow_10.594' 'flow_10.564' 'flow_10.528']
#
# Step = 8193, Shock params: (-1.3238513481707133, 1.6, 42) applied to vehicle ['flow_10.564' 'flow_10.594' 'flow_10.564' 'flow_10.528']
#
# Step = 8194, Shock params: (-1.3238513481707133, 1.6, 42) applied to vehicle ['flow_10.564' 'flow_10.594' 'flow_10.564' 'flow_10.528']
#
# Step = 8195, Shock params: (-1.3238513481707133, 1.6, 42) applied to vehicle ['flow_10.564' 'flow_10.594' 'flow_10.564' 'flow_10.528']
#
# Step = 8196, Shock params: (-1.3238513481707133, 1.6, 42) applied to vehicle ['flow_10.564' 'flow_10.594' 'flow_10.564' 'flow_10.528']
#
# Step = 8197, Shock params: (-1.3238513481707133, 1.6, 42) applied to vehicle ['flow_10.564' 'flow_10.594' 'flow_10.564' 'flow_10.528']
#
# Step = 8198, Shock params: (-1.3238513481707133, 1.6, 42) applied to vehicle ['flow_10.564' 'flow_10.594' 'flow_10.564' 'flow_10.528']
#
# Step = 8199, Shock params: (-1.3238513481707133, 1.6, 42) applied to vehicle ['flow_10.564' 'flow_10.594' 'flow_10.564' 'flow_10.528']
#
# Step = 8200, Shock params: (-1.3238513481707133, 1.6, 42) applied to vehicle ['flow_10.564' 'flow_10.594' 'flow_10.564' 'flow_10.528']
#
#
#
# Shock ids: ['flow_10.508' 'flow_10.534' 'flow_10.632' 'flow_10.621']
#
#
# Changing vehicle type for classic_00.164 to bcm
# Changing vehicle type for classic_00.165 to bcm
# Step = 8272, Shock params: (-2.0387635623425124, 1.7, 42) applied to vehicle ['flow_10.508' 'flow_10.534' 'flow_10.632' 'flow_10.621']
#
# Step = 8273, Shock params: (-2.0387635623425124, 1.7, 42) applied to vehicle ['flow_10.508' 'flow_10.534' 'flow_10.632' 'flow_10.621']
#
# Step = 8274, Shock params: (-2.0387635623425124, 1.7, 42) applied to vehicle ['flow_10.508' 'flow_10.534' 'flow_10.632' 'flow_10.621']
#
# Step = 8275, Shock params: (-2.0387635623425124, 1.7, 42) applied to vehicle ['flow_10.508' 'flow_10.534' 'flow_10.632' 'flow_10.621']
#
# Step = 8276, Shock params: (-2.0387635623425124, 1.7, 42) applied to vehicle ['flow_10.508' 'flow_10.534' 'flow_10.632' 'flow_10.621']
#
# Step = 8277, Shock params: (-2.0387635623425124, 1.7, 42) applied to vehicle ['flow_10.508' 'flow_10.534' 'flow_10.632' 'flow_10.621']
#
# Step = 8278, Shock params: (-2.0387635623425124, 1.7, 42) applied to vehicle ['flow_10.508' 'flow_10.534' 'flow_10.632' 'flow_10.621']
#
# Step = 8279, Shock params: (-2.0387635623425124, 1.7, 42) applied to vehicle ['flow_10.508' 'flow_10.534' 'flow_10.632' 'flow_10.621']
#
# Step = 8280, Shock params: (-2.0387635623425124, 1.7, 42) applied to vehicle ['flow_10.508' 'flow_10.534' 'flow_10.632' 'flow_10.621']
#
# Step = 8281, Shock params: (-2.0387635623425124, 1.7, 42) applied to vehicle ['flow_10.508' 'flow_10.534' 'flow_10.632' 'flow_10.621']
#
# Step = 8282, Shock params: (-2.0387635623425124, 1.7, 42) applied to vehicle ['flow_10.508' 'flow_10.534' 'flow_10.632' 'flow_10.621']
#
# Step = 8283, Shock params: (-2.0387635623425124, 1.7, 42) applied to vehicle ['flow_10.508' 'flow_10.534' 'flow_10.632' 'flow_10.621']
#
# Step = 8284, Shock params: (-2.0387635623425124, 1.7, 42) applied to vehicle ['flow_10.508' 'flow_10.534' 'flow_10.632' 'flow_10.621']
#
# Step = 8285, Shock params: (-2.0387635623425124, 1.7, 42) applied to vehicle ['flow_10.508' 'flow_10.534' 'flow_10.632' 'flow_10.621']
#
# Step = 8286, Shock params: (-2.0387635623425124, 1.7, 42) applied to vehicle ['flow_10.508' 'flow_10.534' 'flow_10.632' 'flow_10.621']
#
# Step = 8287, Shock params: (-2.0387635623425124, 1.7, 42) applied to vehicle ['flow_10.508' 'flow_10.534' 'flow_10.632' 'flow_10.621']
#
# Step = 8288, Shock params: (-2.0387635623425124, 1.7, 42) applied to vehicle ['flow_10.508' 'flow_10.534' 'flow_10.632' 'flow_10.621']
#
#
#
# Shock ids: ['flow_10.628' 'flow_10.574' 'flow_10.635' 'flow_10.635']
#
#
# Changing vehicle type for classic_00.166 to bcm
# Changing vehicle type for classic_00.167 to bcm
# Step = 8359, Shock params: (-2.0285175187243745, 1.7, 42) applied to vehicle ['flow_10.628' 'flow_10.574' 'flow_10.635' 'flow_10.635']
#
# Step = 8360, Shock params: (-2.0285175187243745, 1.7, 42) applied to vehicle ['flow_10.628' 'flow_10.574' 'flow_10.635' 'flow_10.635']
#
# Step = 8361, Shock params: (-2.0285175187243745, 1.7, 42) applied to vehicle ['flow_10.628' 'flow_10.574' 'flow_10.635' 'flow_10.635']
#
# Step = 8362, Shock params: (-2.0285175187243745, 1.7, 42) applied to vehicle ['flow_10.628' 'flow_10.574' 'flow_10.635' 'flow_10.635']
# Step = 8363, Shock params: (-2.0285175187243745, 1.7, 42) applied to vehicle ['flow_10.628' 'flow_10.574' 'flow_10.635' 'flow_10.635']
#
# Step = 8364, Shock params: (-2.0285175187243745, 1.7, 42) applied to vehicle ['flow_10.628' 'flow_10.574' 'flow_10.635' 'flow_10.635']
#
# Step = 8365, Shock params: (-2.0285175187243745, 1.7, 42) applied to vehicle ['flow_10.628' 'flow_10.574' 'flow_10.635' 'flow_10.635']
#
# Step = 8366, Shock params: (-2.0285175187243745, 1.7, 42) applied to vehicle ['flow_10.628' 'flow_10.574' 'flow_10.635' 'flow_10.635']
#
# Step = 8367, Shock params: (-2.0285175187243745, 1.7, 42) applied to vehicle ['flow_10.628' 'flow_10.574' 'flow_10.635' 'flow_10.635']
#
# Step = 8368, Shock params: (-2.0285175187243745, 1.7, 42) applied to vehicle ['flow_10.628' 'flow_10.574' 'flow_10.635' 'flow_10.635']
#
# Step = 8369, Shock params: (-2.0285175187243745, 1.7, 42) applied to vehicle ['flow_10.628' 'flow_10.574' 'flow_10.635' 'flow_10.635']
#
# Step = 8370, Shock params: (-2.0285175187243745, 1.7, 42) applied to vehicle ['flow_10.628' 'flow_10.574' 'flow_10.635' 'flow_10.635']
#
# Step = 8371, Shock params: (-2.0285175187243745, 1.7, 42) applied to vehicle ['flow_10.628' 'flow_10.574' 'flow_10.635' 'flow_10.635']
#
# Step = 8372, Shock params: (-2.0285175187243745, 1.7, 42) applied to vehicle ['flow_10.628' 'flow_10.574' 'flow_10.635' 'flow_10.635']
#
# Step = 8373, Shock params: (-2.0285175187243745, 1.7, 42) applied to vehicle ['flow_10.628' 'flow_10.574' 'flow_10.635' 'flow_10.635']
#
# Step = 8374, Shock params: (-2.0285175187243745, 1.7, 42) applied to vehicle ['flow_10.628' 'flow_10.574' 'flow_10.635' 'flow_10.635']
#
# Step = 8375, Shock params: (-2.0285175187243745, 1.7, 42) applied to vehicle ['flow_10.628' 'flow_10.574' 'flow_10.635' 'flow_10.635']
#
#
#
# Shock ids: ['flow_10.584' 'flow_10.593' 'flow_10.629' 'flow_10.592']
#
#
# Changing vehicle type for classic_00.168 to bcm
# Step = 8447, Shock params: (-2.8819555476520744, 2.0, 42) applied to vehicle ['flow_10.584' 'flow_10.593' 'flow_10.629' 'flow_10.592']
#
# Step = 8448, Shock params: (-2.8819555476520744, 2.0, 42) applied to vehicle ['flow_10.584' 'flow_10.593' 'flow_10.629' 'flow_10.592']
#
# Step = 8449, Shock params: (-2.8819555476520744, 2.0, 42) applied to vehicle ['flow_10.584' 'flow_10.593' 'flow_10.629' 'flow_10.592']
#
# Step = 8450, Shock params: (-2.8819555476520744, 2.0, 42) applied to vehicle ['flow_10.584' 'flow_10.593' 'flow_10.629' 'flow_10.592']
#
# Step = 8451, Shock params: (-2.8819555476520744, 2.0, 42) applied to vehicle ['flow_10.584' 'flow_10.593' 'flow_10.629' 'flow_10.592']
#
# Step = 8452, Shock params: (-2.8819555476520744, 2.0, 42) applied to vehicle ['flow_10.584' 'flow_10.593' 'flow_10.629' 'flow_10.592']
#
# Step = 8453, Shock params: (-2.8819555476520744, 2.0, 42) applied to vehicle ['flow_10.584' 'flow_10.593' 'flow_10.629' 'flow_10.592']
#
# Step = 8454, Shock params: (-2.8819555476520744, 2.0, 42) applied to vehicle ['flow_10.584' 'flow_10.593' 'flow_10.629' 'flow_10.592']
#
# Step = 8455, Shock params: (-2.8819555476520744, 2.0, 42) applied to vehicle ['flow_10.584' 'flow_10.593' 'flow_10.629' 'flow_10.592']
#
# Step = 8456, Shock params: (-2.8819555476520744, 2.0, 42) applied to vehicle ['flow_10.584' 'flow_10.593' 'flow_10.629' 'flow_10.592']
#
# Step = 8457, Shock params: (-2.8819555476520744, 2.0, 42) applied to vehicle ['flow_10.584' 'flow_10.593' 'flow_10.629' 'flow_10.592']
#
# Step = 8458, Shock params: (-2.8819555476520744, 2.0, 42) applied to vehicle ['flow_10.584' 'flow_10.593' 'flow_10.629' 'flow_10.592']
#
# Changing vehicle type for classic_00.169 to bcm
# Step = 8459, Shock params: (-2.8819555476520744, 2.0, 42) applied to vehicle ['flow_10.584' 'flow_10.593' 'flow_10.629' 'flow_10.592']
#
# Step = 8460, Shock params: (-2.8819555476520744, 2.0, 42) applied to vehicle ['flow_10.584' 'flow_10.593' 'flow_10.629' 'flow_10.592']
#
# Step = 8461, Shock params: (-2.8819555476520744, 2.0, 42) applied to vehicle ['flow_10.584' 'flow_10.593' 'flow_10.629' 'flow_10.592']
#
# Step = 8462, Shock params: (-2.8819555476520744, 2.0, 42) applied to vehicle ['flow_10.584' 'flow_10.593' 'flow_10.629' 'flow_10.592']
#
# Step = 8463, Shock params: (-2.8819555476520744, 2.0, 42) applied to vehicle ['flow_10.584' 'flow_10.593' 'flow_10.629' 'flow_10.592']
#
# Step = 8464, Shock params: (-2.8819555476520744, 2.0, 42) applied to vehicle ['flow_10.584' 'flow_10.593' 'flow_10.629' 'flow_10.592']
#
# Step = 8465, Shock params: (-2.8819555476520744, 2.0, 42) applied to vehicle ['flow_10.584' 'flow_10.593' 'flow_10.629' 'flow_10.592']
#
# Step = 8466, Shock params: (-2.8819555476520744, 2.0, 42) applied to vehicle ['flow_10.584' 'flow_10.593' 'flow_10.629' 'flow_10.592']
#
#
#
# Shock ids: ['flow_10.595' 'flow_10.653' 'flow_10.586' 'flow_10.564']
#
#
# Changing vehicle type for classic_00.170 to bcm
# Step = 8534, Shock params: (-2.9681572333162323, 1.7, 42) applied to vehicle ['flow_10.595' 'flow_10.653' 'flow_10.586' 'flow_10.564']
#
# Step = 8535, Shock params: (-2.9681572333162323, 1.7, 42) applied to vehicle ['flow_10.595' 'flow_10.653' 'flow_10.586' 'flow_10.564']
#
# Step = 8536, Shock params: (-2.9681572333162323, 1.7, 42) applied to vehicle ['flow_10.595' 'flow_10.653' 'flow_10.586' 'flow_10.564']
#
# Step = 8537, Shock params: (-2.9681572333162323, 1.7, 42) applied to vehicle ['flow_10.595' 'flow_10.653' 'flow_10.586' 'flow_10.564']
#
# Step = 8538, Shock params: (-2.9681572333162323, 1.7, 42) applied to vehicle ['flow_10.595' 'flow_10.653' 'flow_10.586' 'flow_10.564']
#
# Step = 8539, Shock params: (-2.9681572333162323, 1.7, 42) applied to vehicle ['flow_10.595' 'flow_10.653' 'flow_10.586' 'flow_10.564']
#
# Step = 8540, Shock params: (-2.9681572333162323, 1.7, 42) applied to vehicle ['flow_10.595' 'flow_10.653' 'flow_10.586' 'flow_10.564']
#
# Step = 8541, Shock params: (-2.9681572333162323, 1.7, 42) applied to vehicle ['flow_10.595' 'flow_10.653' 'flow_10.586' 'flow_10.564']
#
# Step = 8542, Shock params: (-2.9681572333162323, 1.7, 42) applied to vehicle ['flow_10.595' 'flow_10.653' 'flow_10.586' 'flow_10.564']
#
# Step = 8543, Shock params: (-2.9681572333162323, 1.7, 42) applied to vehicle ['flow_10.595' 'flow_10.653' 'flow_10.586' 'flow_10.564']
#
# Step = 8544, Shock params: (-2.9681572333162323, 1.7, 42) applied to vehicle ['flow_10.595' 'flow_10.653' 'flow_10.586' 'flow_10.564']
#
# Step = 8545, Shock params: (-2.9681572333162323, 1.7, 42) applied to vehicle ['flow_10.595' 'flow_10.653' 'flow_10.586' 'flow_10.564']
#
# Step = 8546, Shock params: (-2.9681572333162323, 1.7, 42) applied to vehicle ['flow_10.595' 'flow_10.653' 'flow_10.586' 'flow_10.564']
#
# Step = 8547, Shock params: (-2.9681572333162323, 1.7, 42) applied to vehicle ['flow_10.595' 'flow_10.653' 'flow_10.586' 'flow_10.564']
#
# Step = 8548, Shock params: (-2.9681572333162323, 1.7, 42) applied to vehicle ['flow_10.595' 'flow_10.653' 'flow_10.586' 'flow_10.564']
#
# Step = 8549, Shock params: (-2.9681572333162323, 1.7, 42) applied to vehicle ['flow_10.595' 'flow_10.653' 'flow_10.586' 'flow_10.564']
#
# Step = 8550, Shock params: (-2.9681572333162323, 1.7, 42) applied to vehicle ['flow_10.595' 'flow_10.653' 'flow_10.586' 'flow_10.564']
#
#
#
# Shock ids: ['flow_10.518' 'flow_10.657' 'flow_10.662' 'flow_10.570']
#
#
# Changing vehicle type for classic_00.171 to bcm
# Changing vehicle type for classic_00.172 to bcm
# Step = 8621, Shock params: (-2.9559963417314528, 1.0, 42) applied to vehicle ['flow_10.518' 'flow_10.657' 'flow_10.662' 'flow_10.570']
#
# Step = 8622, Shock params: (-2.9559963417314528, 1.0, 42) applied to vehicle ['flow_10.518' 'flow_10.657' 'flow_10.662' 'flow_10.570']
#
# Step = 8623, Shock params: (-2.9559963417314528, 1.0, 42) applied to vehicle ['flow_10.518' 'flow_10.657' 'flow_10.662' 'flow_10.570']
#
# Step = 8624, Shock params: (-2.9559963417314528, 1.0, 42) applied to vehicle ['flow_10.518' 'flow_10.657' 'flow_10.662' 'flow_10.570']
#
# Step = 8625, Shock params: (-2.9559963417314528, 1.0, 42) applied to vehicle ['flow_10.518' 'flow_10.657' 'flow_10.662' 'flow_10.570']
#
# Step = 8626, Shock params: (-2.9559963417314528, 1.0, 42) applied to vehicle ['flow_10.518' 'flow_10.657' 'flow_10.662' 'flow_10.570']
#
# Step = 8627, Shock params: (-2.9559963417314528, 1.0, 42) applied to vehicle ['flow_10.518' 'flow_10.657' 'flow_10.662' 'flow_10.570']
#
# Step = 8628, Shock params: (-2.9559963417314528, 1.0, 42) applied to vehicle ['flow_10.518' 'flow_10.657' 'flow_10.662' 'flow_10.570']
# Step = 8629, Shock params: (-2.9559963417314528, 1.0, 42) applied to vehicle ['flow_10.518' 'flow_10.657' 'flow_10.662' 'flow_10.570']
#
# Step = 8630, Shock params: (-2.9559963417314528, 1.0, 42) applied to vehicle ['flow_10.518' 'flow_10.657' 'flow_10.662' 'flow_10.570']
#
# Step = 8631, Shock params: (-2.9559963417314528, 1.0, 42) applied to vehicle ['flow_10.518' 'flow_10.657' 'flow_10.662' 'flow_10.570']
#
#
#
# Shock ids: ['flow_10.518' 'flow_10.518' 'flow_10.600' 'flow_10.661']
#
#
# Changing vehicle type for classic_00.173 to bcm
# Changing vehicle type for classic_00.174 to bcm
# Step = 8709, Shock params: (-2.607503946948912, 2.1, 42) applied to vehicle ['flow_10.518' 'flow_10.518' 'flow_10.600' 'flow_10.661']
#
# Step = 8710, Shock params: (-2.607503946948912, 2.1, 42) applied to vehicle ['flow_10.518' 'flow_10.518' 'flow_10.600' 'flow_10.661']
#
# Step = 8711, Shock params: (-2.607503946948912, 2.1, 42) applied to vehicle ['flow_10.518' 'flow_10.518' 'flow_10.600' 'flow_10.661']
#
# Step = 8712, Shock params: (-2.607503946948912, 2.1, 42) applied to vehicle ['flow_10.518' 'flow_10.518' 'flow_10.600' 'flow_10.661']
#
# Step = 8713, Shock params: (-2.607503946948912, 2.1, 42) applied to vehicle ['flow_10.518' 'flow_10.518' 'flow_10.600' 'flow_10.661']
#
# Step = 8714, Shock params: (-2.607503946948912, 2.1, 42) applied to vehicle ['flow_10.518' 'flow_10.518' 'flow_10.600' 'flow_10.661']
#
# Step = 8715, Shock params: (-2.607503946948912, 2.1, 42) applied to vehicle ['flow_10.518' 'flow_10.518' 'flow_10.600' 'flow_10.661']
#
# Step = 8716, Shock params: (-2.607503946948912, 2.1, 42) applied to vehicle ['flow_10.518' 'flow_10.518' 'flow_10.600' 'flow_10.661']
#
# Step = 8717, Shock params: (-2.607503946948912, 2.1, 42) applied to vehicle ['flow_10.518' 'flow_10.518' 'flow_10.600' 'flow_10.661']
#
# Step = 8718, Shock params: (-2.607503946948912, 2.1, 42) applied to vehicle ['flow_10.518' 'flow_10.518' 'flow_10.600' 'flow_10.661']
#
# Step = 8719, Shock params: (-2.607503946948912, 2.1, 42) applied to vehicle ['flow_10.518' 'flow_10.518' 'flow_10.600' 'flow_10.661']
#
# Step = 8720, Shock params: (-2.607503946948912, 2.1, 42) applied to vehicle ['flow_10.518' 'flow_10.518' 'flow_10.600' 'flow_10.661']
#
# Step = 8721, Shock params: (-2.607503946948912, 2.1, 42) applied to vehicle ['flow_10.518' 'flow_10.518' 'flow_10.600' 'flow_10.661']
#
# Step = 8722, Shock params: (-2.607503946948912, 2.1, 42) applied to vehicle ['flow_10.518' 'flow_10.518' 'flow_10.600' 'flow_10.661']
#
# Step = 8723, Shock params: (-2.607503946948912, 2.1, 42) applied to vehicle ['flow_10.518' 'flow_10.518' 'flow_10.600' 'flow_10.661']
#
# Step = 8724, Shock params: (-2.607503946948912, 2.1, 42) applied to vehicle ['flow_10.518' 'flow_10.518' 'flow_10.600' 'flow_10.661']
#
# Step = 8725, Shock params: (-2.607503946948912, 2.1, 42) applied to vehicle ['flow_10.518' 'flow_10.518' 'flow_10.600' 'flow_10.661']
#
# Step = 8726, Shock params: (-2.607503946948912, 2.1, 42) applied to vehicle ['flow_10.518' 'flow_10.518' 'flow_10.600' 'flow_10.661']
#
# Step = 8727, Shock params: (-2.607503946948912, 2.1, 42) applied to vehicle ['flow_10.518' 'flow_10.518' 'flow_10.600' 'flow_10.661']
#
# Step = 8728, Shock params: (-2.607503946948912, 2.1, 42) applied to vehicle ['flow_10.518' 'flow_10.518' 'flow_10.600' 'flow_10.661']
#
# Step = 8729, Shock params: (-2.607503946948912, 2.1, 42) applied to vehicle ['flow_10.518' 'flow_10.518' 'flow_10.600' 'flow_10.661']
#
#
#
# Shock ids: ['flow_10.538' 'flow_10.619' 'flow_10.619' 'flow_10.538']
#
#
# Changing vehicle type for classic_00.175 to bcm
# Step = 8796, Shock params: (-2.7191629307942344, 1.1, 42) applied to vehicle ['flow_10.538' 'flow_10.619' 'flow_10.619' 'flow_10.538']
#
# Step = 8797, Shock params: (-2.7191629307942344, 1.1, 42) applied to vehicle ['flow_10.538' 'flow_10.619' 'flow_10.619' 'flow_10.538']
#
# Step = 8798, Shock params: (-2.7191629307942344, 1.1, 42) applied to vehicle ['flow_10.538' 'flow_10.619' 'flow_10.619' 'flow_10.538']
#
# Step = 8799, Shock params: (-2.7191629307942344, 1.1, 42) applied to vehicle ['flow_10.538' 'flow_10.619' 'flow_10.619' 'flow_10.538']
#
# Step = 8800, Shock params: (-2.7191629307942344, 1.1, 42) applied to vehicle ['flow_10.538' 'flow_10.619' 'flow_10.619' 'flow_10.538']
#
# Step = 8801, Shock params: (-2.7191629307942344, 1.1, 42) applied to vehicle ['flow_10.538' 'flow_10.619' 'flow_10.619' 'flow_10.538']
#
# Step = 8802, Shock params: (-2.7191629307942344, 1.1, 42) applied to vehicle ['flow_10.538' 'flow_10.619' 'flow_10.619' 'flow_10.538']
#
# Step = 8803, Shock params: (-2.7191629307942344, 1.1, 42) applied to vehicle ['flow_10.538' 'flow_10.619' 'flow_10.619' 'flow_10.538']
#
# Step = 8804, Shock params: (-2.7191629307942344, 1.1, 42) applied to vehicle ['flow_10.538' 'flow_10.619' 'flow_10.619' 'flow_10.538']
#
# Step = 8805, Shock params: (-2.7191629307942344, 1.1, 42) applied to vehicle ['flow_10.538' 'flow_10.619' 'flow_10.619' 'flow_10.538']
#
# Step = 8806, Shock params: (-2.7191629307942344, 1.1, 42) applied to vehicle ['flow_10.538' 'flow_10.619' 'flow_10.619' 'flow_10.538']
#
# Step = 8807, Shock params: (-2.7191629307942344, 1.1, 42) applied to vehicle ['flow_10.538' 'flow_10.619' 'flow_10.619' 'flow_10.538']
#
#
#
# Shock ids: ['flow_10.497' 'flow_10.684' 'flow_10.616' 'flow_10.568']
#
#
# Changing vehicle type for classic_00.176 to bcm
# Changing vehicle type for classic_00.177 to bcm
# Step = 8883, Shock params: (-1.5370188866723837, 0.4, 42) applied to vehicle ['flow_10.497' 'flow_10.684' 'flow_10.616' 'flow_10.568']
#
# Step = 8884, Shock params: (-1.5370188866723837, 0.4, 42) applied to vehicle ['flow_10.497' 'flow_10.684' 'flow_10.616' 'flow_10.568']
#
# Step = 8885, Shock params: (-1.5370188866723837, 0.4, 42) applied to vehicle ['flow_10.497' 'flow_10.684' 'flow_10.616' 'flow_10.568']
#
# Step = 8886, Shock params: (-1.5370188866723837, 0.4, 42) applied to vehicle ['flow_10.497' 'flow_10.684' 'flow_10.616' 'flow_10.568']
#
#
#
# Shock ids: ['flow_10.526' 'flow_10.692' 'flow_10.616' 'flow_10.667']
#
#
# Changing vehicle type for classic_00.178 to bcm
# Changing vehicle type for classic_00.179 to bcm
# Step = 8970, Shock params: (-2.9589311219430092, 1.9, 42) applied to vehicle ['flow_10.526' 'flow_10.692' 'flow_10.616' 'flow_10.667']
#
# Step = 8971, Shock params: (-2.9589311219430092, 1.9, 42) applied to vehicle ['flow_10.526' 'flow_10.692' 'flow_10.616' 'flow_10.667']
#
# Step = 8972, Shock params: (-2.9589311219430092, 1.9, 42) applied to vehicle ['flow_10.526' 'flow_10.692' 'flow_10.616' 'flow_10.667']
#
# ...
# Changing vehicle type for classic_00.63 to bcm
# Changing vehicle type for classic_00.64 to bcm
# Changing vehicle type for classic_00.65 to bcm
# Changing vehicle type for classic_00.66 to bcm
# Changing vehicle type for classic_00.67 to bcm
# Changing vehicle type for classic_00.68 to bcm
# Changing vehicle type for classic_00.69 to bcm
# Changing vehicle type for classic_00.70 to bcm
# Changing vehicle type for classic_00.71 to bcm
# Changing vehicle type for classic_00.72 to bcm
# Changing vehicle type for classic_00.73 to bcm
# Changing vehicle type for classic_00.74 to bcm
# Changing vehicle type for classic_00.75 to bcm
# Changing vehicle type for classic_00.76 to bcm
# Changing vehicle type for classic_00.77 to bcm
# Changing vehicle type for classic_00.78 to bcm
# Changing vehicle type for classic_00.79 to bcm
# Changing vehicle type for classic_00.80 to bcm
# Changing vehicle type for classic_00.81 to bcm
# Changing vehicle type for classic_00.82 to bcm
# Changing vehicle type for classic_00.83 to bcm
# Changing vehicle type for classic_00.84 to bcm
# Changing vehicle type for classic_00.85 to bcm
# Changing vehicle type for classic_00.86 to bcm
# Changing vehicle type for classic_00.87 to bcm
# Changing vehicle type for classic_00.88 to bcm
# Changing vehicle type for classic_00.89 to bcm
# Changing vehicle type for classic_00.90 to bcm
# Changing vehicle type for classic_00.91 to bcm
# Changing vehicle type for classic_00.92 to bcm
# Changing vehicle type for classic_00.93 to bcm
# Changing vehicle type for classic_00.94 to bcm
# Changing vehicle type for classic_00.95 to bcm
# Changing vehicle type for classic_00.96 to bcm
# Changing vehicle type for classic_00.97 to bcm
# Changing vehicle type for classic_00.98 to bcm
# Changing vehicle type for classic_00.99 to bcm
# Changing vehicle type for classic_00.100 to bcm
# Changing vehicle type for classic_00.101 to bcm
# Changing vehicle type for classic_00.102 to bcm
# Changing vehicle type for classic_00.103 to bcm
# Changing vehicle type for classic_00.104 to bcm
# Changing vehicle type for classic_00.105 to bcm
# Changing vehicle type for classic_00.106 to bcm
# Changing vehicle type for classic_00.107 to bcm
# Changing vehicle type for classic_00.108 to bcm
# Changing vehicle type for classic_00.109 to bcm
# Changing vehicle type for classic_00.110 to bcm
# Changing vehicle type for classic_00.111 to bcm
# Changing vehicle type for classic_00.112 to bcm
# Changing vehicle type for classic_00.113 to bcm
# Changing vehicle type for classic_00.114 to bcm
# Changing vehicle type for classic_00.115 to bcm
# Changing vehicle type for classic_00.116 to bcm
# Changing vehicle type for classic_00.117 to bcm
# Changing vehicle type for classic_00.118 to bcm
# Changing vehicle type for classic_00.119 to bcm
# Changing vehicle type for classic_00.120 to bcm
# Changing vehicle type for classic_00.121 to bcm
# Changing vehicle type for classic_00.122 to bcm
# Changing vehicle type for classic_00.123 to bcm
# Changing vehicle type for classic_00.124 to bcm
# Changing vehicle type for classic_00.125 to bcm
# Changing vehicle type for classic_00.126 to bcm
# Changing vehicle type for classic_00.127 to bcm
# Changing vehicle type for classic_00.128 to bcm
# Changing vehicle type for classic_00.129 to bcm
# Changing vehicle type for classic_00.130 to bcm
# Changing vehicle type for classic_00.131 to bcm
# Changing vehicle type for classic_00.132 to bcm
# Changing vehicle type for classic_00.133 to bcm
# Changing vehicle type for classic_00.134 to bcm
# Changing vehicle type for classic_00.135 to bcm
# Changing vehicle type for classic_00.136 to bcm
# Changing vehicle type for classic_00.137 to bcm
# Changing vehicle type for classic_00.138 to bcm
# Changing vehicle type for classic_00.139 to bcm
# Changing vehicle type for classic_00.140 to bcm
# Changing vehicle type for classic_00.141 to bcm
# Changing vehicle type for classic_00.142 to bcm
# Changing vehicle type for classic_00.143 to bcm
# Changing vehicle type for classic_00.144 to bcm
# Changing vehicle type for classic_00.145 to bcm
# Changing vehicle type for classic_00.146 to bcm
# Changing vehicle type for classic_00.147 to bcm
#
#
# Shock ids: ['flow_10.572' 'flow_10.566' 'flow_10.573' 'flow_10.569']
#
#
# Step = 7400, Shock params: (-2.324834454217295, 1.9, 33) applied to vehicle ['flow_10.572' 'flow_10.566' 'flow_10.573' 'flow_10.569']
#
# Step = 7401, Shock params: (-2.324834454217295, 1.9, 33) applied to vehicle ['flow_10.572' 'flow_10.566' 'flow_10.573' 'flow_10.569']
#
# Step = 7402, Shock params: (-2.324834454217295, 1.9, 33) applied to vehicle ['flow_10.572' 'flow_10.566' 'flow_10.573' 'flow_10.569']
#
# Step = 7403, Shock params: (-2.324834454217295, 1.9, 33) applied to vehicle ['flow_10.572' 'flow_10.566' 'flow_10.573' 'flow_10.569']
#
# Step = 7404, Shock params: (-2.324834454217295, 1.9, 33) applied to vehicle ['flow_10.572' 'flow_10.566' 'flow_10.573' 'flow_10.569']
#
# Step = 7405, Shock params: (-2.324834454217295, 1.9, 33) applied to vehicle ['flow_10.572' 'flow_10.566' 'flow_10.573' 'flow_10.569']
#
# Step = 7406, Shock params: (-2.324834454217295, 1.9, 33) applied to vehicle ['flow_10.572' 'flow_10.566' 'flow_10.573' 'flow_10.569']
#
# Step = 7407, Shock params: (-2.324834454217295, 1.9, 33) applied to vehicle ['flow_10.572' 'flow_10.566' 'flow_10.573' 'flow_10.569']
#
# Step = 7408, Shock params: (-2.324834454217295, 1.9, 33) applied to vehicle ['flow_10.572' 'flow_10.566' 'flow_10.573' 'flow_10.569']
#
# Changing vehicle type for classic_00.148 to bcm
# Step = 7409, Shock params: (-2.324834454217295, 1.9, 33) applied to vehicle ['flow_10.572' 'flow_10.566' 'flow_10.573' 'flow_10.569']
# Step = 7410, Shock params: (-2.324834454217295, 1.9, 33) applied to vehicle ['flow_10.572' 'flow_10.566' 'flow_10.573' 'flow_10.569']
#
# Step = 7411, Shock params: (-2.324834454217295, 1.9, 33) applied to vehicle ['flow_10.572' 'flow_10.566' 'flow_10.573' 'flow_10.569']
#
# Step = 7412, Shock params: (-2.324834454217295, 1.9, 33) applied to vehicle ['flow_10.572' 'flow_10.566' 'flow_10.573' 'flow_10.569']
#
# Step = 7413, Shock params: (-2.324834454217295, 1.9, 33) applied to vehicle ['flow_10.572' 'flow_10.566' 'flow_10.573' 'flow_10.569']
#
# Step = 7414, Shock params: (-2.324834454217295, 1.9, 33) applied to vehicle ['flow_10.572' 'flow_10.566' 'flow_10.573' 'flow_10.569']
#
# Step = 7415, Shock params: (-2.324834454217295, 1.9, 33) applied to vehicle ['flow_10.572' 'flow_10.566' 'flow_10.573' 'flow_10.569']
#
# Step = 7416, Shock params: (-2.324834454217295, 1.9, 33) applied to vehicle ['flow_10.572' 'flow_10.566' 'flow_10.573' 'flow_10.569']
#
# Step = 7417, Shock params: (-2.324834454217295, 1.9, 33) applied to vehicle ['flow_10.572' 'flow_10.566' 'flow_10.573' 'flow_10.569']
#
# Step = 7418, Shock params: (-2.324834454217295, 1.9, 33) applied to vehicle ['flow_10.572' 'flow_10.566' 'flow_10.573' 'flow_10.569']
#
#
#
# Shock ids: ['flow_10.562' 'flow_10.574' 'flow_10.464' 'flow_10.559']
#
#
# Changing vehicle type for classic_00.149 to bcm
# Changing vehicle type for classic_00.150 to bcm
# Step = 7511, Shock params: (-1.1783593646731394, 0.4, 33) applied to vehicle ['flow_10.562' 'flow_10.574' 'flow_10.464' 'flow_10.559']
#
# Step = 7512, Shock params: (-1.1783593646731394, 0.4, 33) applied to vehicle ['flow_10.562' 'flow_10.574' 'flow_10.464' 'flow_10.559']
#
# Step = 7513, Shock params: (-1.1783593646731394, 0.4, 33) applied to vehicle ['flow_10.562' 'flow_10.574' 'flow_10.464' 'flow_10.559']
#
# Step = 7514, Shock params: (-1.1783593646731394, 0.4, 33) applied to vehicle ['flow_10.562' 'flow_10.574' 'flow_10.464' 'flow_10.559']
#
#
#
# Shock ids: ['flow_10.562' 'flow_10.573' 'flow_10.473' 'flow_10.583']
#
#
# Changing vehicle type for classic_00.151 to bcm
# Changing vehicle type for classic_00.152 to bcm
# Step = 7623, Shock params: (-2.2265616931172385, 0.9, 33) applied to vehicle ['flow_10.562' 'flow_10.573' 'flow_10.473' 'flow_10.583']
#
# Step = 7624, Shock params: (-2.2265616931172385, 0.9, 33) applied to vehicle ['flow_10.562' 'flow_10.573' 'flow_10.473' 'flow_10.583']
#
# Step = 7625, Shock params: (-2.2265616931172385, 0.9, 33) applied to vehicle ['flow_10.562' 'flow_10.573' 'flow_10.473' 'flow_10.583']
#
# Step = 7626, Shock params: (-2.2265616931172385, 0.9, 33) applied to vehicle ['flow_10.562' 'flow_10.573' 'flow_10.473' 'flow_10.583']
#
# Step = 7627, Shock params: (-2.2265616931172385, 0.9, 33) applied to vehicle ['flow_10.562' 'flow_10.573' 'flow_10.473' 'flow_10.583']
#
# Step = 7628, Shock params: (-2.2265616931172385, 0.9, 33) applied to vehicle ['flow_10.562' 'flow_10.573' 'flow_10.473' 'flow_10.583']
#
# Step = 7629, Shock params: (-2.2265616931172385, 0.9, 33) applied to vehicle ['flow_10.562' 'flow_10.573' 'flow_10.473' 'flow_10.583']
#
# Step = 7630, Shock params: (-2.2265616931172385, 0.9, 33) applied to vehicle ['flow_10.562' 'flow_10.573' 'flow_10.473' 'flow_10.583']
#
# Step = 7631, Shock params: (-2.2265616931172385, 0.9, 33) applied to vehicle ['flow_10.562' 'flow_10.573' 'flow_10.473' 'flow_10.583']
#
# Step = 7632, Shock params: (-2.2265616931172385, 0.9, 33) applied to vehicle ['flow_10.562' 'flow_10.573' 'flow_10.473' 'flow_10.583']
#
#
#
# Shock ids: ['flow_10.477' 'flow_10.558' 'flow_10.511' 'flow_10.476']
#
#
# Changing vehicle type for classic_00.153 to bcm
# Changing vehicle type for classic_00.154 to bcm
# Step = 7735, Shock params: (-2.3953642384576943, 1.6, 33) applied to vehicle ['flow_10.477' 'flow_10.558' 'flow_10.511' 'flow_10.476']
#
# Step = 7736, Shock params: (-2.3953642384576943, 1.6, 33) applied to vehicle ['flow_10.477' 'flow_10.558' 'flow_10.511' 'flow_10.476']
#
# Step = 7737, Shock params: (-2.3953642384576943, 1.6, 33) applied to vehicle ['flow_10.477' 'flow_10.558' 'flow_10.511' 'flow_10.476']
#
# Step = 7738, Shock params: (-2.3953642384576943, 1.6, 33) applied to vehicle ['flow_10.477' 'flow_10.558' 'flow_10.511' 'flow_10.476']
#
# Step = 7739, Shock params: (-2.3953642384576943, 1.6, 33) applied to vehicle ['flow_10.477' 'flow_10.558' 'flow_10.511' 'flow_10.476']
#
# Step = 7740, Shock params: (-2.3953642384576943, 1.6, 33) applied to vehicle ['flow_10.477' 'flow_10.558' 'flow_10.511' 'flow_10.476']
#
# Step = 7741, Shock params: (-2.3953642384576943, 1.6, 33) applied to vehicle ['flow_10.477' 'flow_10.558' 'flow_10.511' 'flow_10.476']
#
# Step = 7742, Shock params: (-2.3953642384576943, 1.6, 33) applied to vehicle ['flow_10.477' 'flow_10.558' 'flow_10.511' 'flow_10.476']
#
# Step = 7743, Shock params: (-2.3953642384576943, 1.6, 33) applied to vehicle ['flow_10.477' 'flow_10.558' 'flow_10.511' 'flow_10.476']
#
# Step = 7744, Shock params: (-2.3953642384576943, 1.6, 33) applied to vehicle ['flow_10.477' 'flow_10.558' 'flow_10.511' 'flow_10.476']
#
# Step = 7745, Shock params: (-2.3953642384576943, 1.6, 33) applied to vehicle ['flow_10.477' 'flow_10.558' 'flow_10.511' 'flow_10.476']
#
# Step = 7746, Shock params: (-2.3953642384576943, 1.6, 33) applied to vehicle ['flow_10.477' 'flow_10.558' 'flow_10.511' 'flow_10.476']
#
# Step = 7747, Shock params: (-2.3953642384576943, 1.6, 33) applied to vehicle ['flow_10.477' 'flow_10.558' 'flow_10.511' 'flow_10.476']
#
# Step = 7748, Shock params: (-2.3953642384576943, 1.6, 33) applied to vehicle ['flow_10.477' 'flow_10.558' 'flow_10.511' 'flow_10.476']
#
# Step = 7749, Shock params: (-2.3953642384576943, 1.6, 33) applied to vehicle ['flow_10.477' 'flow_10.558' 'flow_10.511' 'flow_10.476']
#
# Step = 7750, Shock params: (-2.3953642384576943, 1.6, 33) applied to vehicle ['flow_10.477' 'flow_10.558' 'flow_10.511' 'flow_10.476']
#
#
#
# Shock ids: ['flow_10.536' 'flow_10.596' 'flow_10.530' 'flow_10.598']
#
#
# Changing vehicle type for classic_00.155 to bcm
# Changing vehicle type for classic_00.156 to bcm
# Step = 7847, Shock params: (-1.3108154751703038, 0.7, 33) applied to vehicle ['flow_10.536' 'flow_10.596' 'flow_10.530' 'flow_10.598']
#
# Step = 7848, Shock params: (-1.3108154751703038, 0.7, 33) applied to vehicle ['flow_10.536' 'flow_10.596' 'flow_10.530' 'flow_10.598']
#
# Step = 7849, Shock params: (-1.3108154751703038, 0.7, 33) applied to vehicle ['flow_10.536' 'flow_10.596' 'flow_10.530' 'flow_10.598']
#
# Step = 7850, Shock params: (-1.3108154751703038, 0.7, 33) applied to vehicle ['flow_10.536' 'flow_10.596' 'flow_10.530' 'flow_10.598']
#
# Step = 7851, Shock params: (-1.3108154751703038, 0.7, 33) applied to vehicle ['flow_10.536' 'flow_10.596' 'flow_10.530' 'flow_10.598']
#
# Step = 7852, Shock params: (-1.3108154751703038, 0.7, 33) applied to vehicle ['flow_10.536' 'flow_10.596' 'flow_10.530' 'flow_10.598']
#
# Step = 7853, Shock params: (-1.3108154751703038, 0.7, 33) applied to vehicle ['flow_10.536' 'flow_10.596' 'flow_10.530' 'flow_10.598']
#
#
#
# Shock ids: ['flow_10.576' 'flow_10.525' 'flow_10.584' 'flow_10.592']
#
#
# Changing vehicle type for classic_00.157 to bcm
# Changing vehicle type for classic_00.158 to bcm
# Changing vehicle type for classic_00.159 to bcm
# Step = 7959, Shock params: (-1.276458383040015, 0.4, 33) applied to vehicle ['flow_10.576' 'flow_10.525' 'flow_10.584' 'flow_10.592']
#
# Step = 7960, Shock params: (-1.276458383040015, 0.4, 33) applied to vehicle ['flow_10.576' 'flow_10.525' 'flow_10.584' 'flow_10.592']
#
# Step = 7961, Shock params: (-1.276458383040015, 0.4, 33) applied to vehicle ['flow_10.576' 'flow_10.525' 'flow_10.584' 'flow_10.592']
#
# Step = 7962, Shock params: (-1.276458383040015, 0.4, 33) applied to vehicle ['flow_10.576' 'flow_10.525' 'flow_10.584' 'flow_10.592']
#
#
#
# Shock ids: ['flow_10.545' 'flow_10.515' 'flow_10.496' 'flow_10.496']
#
#
# Changing vehicle type for classic_00.160 to bcm
# Changing vehicle type for classic_00.161 to bcm
# Step = 8071, Shock params: (-1.0658591488265543, 2.1, 33) applied to vehicle ['flow_10.545' 'flow_10.515' 'flow_10.496' 'flow_10.496']
#
# Step = 8072, Shock params: (-1.0658591488265543, 2.1, 33) applied to vehicle ['flow_10.545' 'flow_10.515' 'flow_10.496' 'flow_10.496']
#
# Step = 8073, Shock params: (-1.0658591488265543, 2.1, 33) applied to vehicle ['flow_10.545' 'flow_10.515' 'flow_10.496' 'flow_10.496']
#
# Step = 8074, Shock params: (-1.0658591488265543, 2.1, 33) applied to vehicle ['flow_10.545' 'flow_10.515' 'flow_10.496' 'flow_10.496']
# Step = 8075, Shock params: (-1.0658591488265543, 2.1, 33) applied to vehicle ['flow_10.545' 'flow_10.515' 'flow_10.496' 'flow_10.496']
#
# Step = 8076, Shock params: (-1.0658591488265543, 2.1, 33) applied to vehicle ['flow_10.545' 'flow_10.515' 'flow_10.496' 'flow_10.496']
#
# Step = 8077, Shock params: (-1.0658591488265543, 2.1, 33) applied to vehicle ['flow_10.545' 'flow_10.515' 'flow_10.496' 'flow_10.496']
#
# Step = 8078, Shock params: (-1.0658591488265543, 2.1, 33) applied to vehicle ['flow_10.545' 'flow_10.515' 'flow_10.496' 'flow_10.496']
#
# Step = 8079, Shock params: (-1.0658591488265543, 2.1, 33) applied to vehicle ['flow_10.545' 'flow_10.515' 'flow_10.496' 'flow_10.496']
#
# Step = 8080, Shock params: (-1.0658591488265543, 2.1, 33) applied to vehicle ['flow_10.545' 'flow_10.515' 'flow_10.496' 'flow_10.496']
#
# Step = 8081, Shock params: (-1.0658591488265543, 2.1, 33) applied to vehicle ['flow_10.545' 'flow_10.515' 'flow_10.496' 'flow_10.496']
#
# Step = 8082, Shock params: (-1.0658591488265543, 2.1, 33) applied to vehicle ['flow_10.545' 'flow_10.515' 'flow_10.496' 'flow_10.496']
#
# Step = 8083, Shock params: (-1.0658591488265543, 2.1, 33) applied to vehicle ['flow_10.545' 'flow_10.515' 'flow_10.496' 'flow_10.496']
#
# Traceback (most recent call last):
#   File "classic.py", line 55, in <module>
#     run(args)
#   File "classic.py", line 44, in run
#     _ = exp.run(1, convert_to_csv=False)
#   File "/mnt/c/Users/09_gi/Desktop/flow/flow/core/experiment.py", line 145, in run
#     state, reward, done, _ = self.env.step(rl_actions(state))
#   File "/mnt/c/Users/09_gi/Desktop/flow/flow/envs/classic_bottleneck.py", line 234, in step
#     self.perform_shock(self.shock_times)
#   File "/mnt/c/Users/09_gi/Desktop/flow/flow/envs/classic_bottleneck.py", line 265, in perform_shock
#     controller.set_shock_time(False)
# AttributeError: 'NoneType' object has no attribute 'set_shock_time'
# /mnt/c/Users/09_gi/Desktop/flow/poudel_bottleneck/test_time_rollout/bcm/bottleneck_2_bcm_20230911-1050271694443827.4447901-0_emission.csv /mnt/c/Users/09_gi/Desktop/flow/poudel_bottleneck/test_time_rollout/bcm

# %%
# Vinitsky
# 3233 at around 13.5 M = 94 ep
# Here start time and end time is not 4400 and 8000 rather: 
# Data recording stars at warmup
chkpt = 94
NUM_ROLLOUTS = 5
# !python test_rllib.py ./Vinitsky_et_al/Trained_policies/PPO_BottleneckDesiredVelocityEnv-v0_18afac40_2023-09-04_11-31-19u4dl8wsj $chkpt\
--method vinitsky --num_rollouts $NUM_ROLLOUTS --gen_emission --shock --render
# Out:
# 2023-09-11 10:53:36,019	WARNING services.py:597 -- setpgrp failed, processes may not be cleaned up properly: [Errno 1] Operation not permitted.
# 2023-09-11 10:53:36,019	INFO resource_spec.py:216 -- Starting Ray with 26.46 GiB memory available for workers and up to 13.24 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# 2023-09-11 10:53:36,378	INFO trainer.py:371 -- Tip: set 'eager': true or the --eager flag to enable TensorFlow eager execution
# 2023-09-11 10:53:36,387	INFO trainer.py:512 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# Error: tcpip::Socket::recvAndCheck @ recv: peer shutdown
# Quitting (on error).
# 2023-09-11 10:53:41,281	WARNING util.py:45 -- Install gputil for GPU system monitoring.
# 2023-09-11 10:53:41,373	INFO trainable.py:346 -- Restored from checkpoint: ./Vinitsky_et_al/Trained_policies/PPO_BottleneckDesiredVelocityEnv-v0_18afac40_2023-09-04_11-31-19u4dl8wsj/checkpoint_94/checkpoint-94
# 2023-09-11 10:53:41,373	INFO trainable.py:353 -- Current state after restoring: {'_iteration': 94, '_timesteps_total': 13536000, '_time_total': 27651.214074134827, '_episodes_total': 3759}
# Error: tcpip::Socket::recvAndCheck @ recv: peer shutdown
# Quitting (on error).
# Frequency: 45
# Intensity: -1.9558820490160316
# Duration: 1.6
# Intensity: -2.755668339261941
# Duration: 2.0
# Intensity: -2.8219273948182755
# Duration: 2.2
# Intensity: -2.9883556785512484
# Duration: 2.5
# Intensity: -1.1701496296411857
# Duration: 1.5
# Intensity: -1.768841635438301
# Duration: 1.0
# Intensity: -1.9187135233955501
# Duration: 1.4
# Intensity: -2.685436083107871
# Duration: 2.2
# Intensity: -1.2323377669440194
# Duration: 0.7
# Intensity: -1.5887487941607026
# Duration: 1.6
# Intensity: -1.8894998503160734
# Duration: 0.4
# Intensity: -1.6711254049182007
# Duration: 1.7
# Intensity: -2.2202419343124387
# Duration: 1.7
# Intensity: -1.8119850563449165
# Duration: 1.1
# Intensity: -2.8712216984697667
# Duration: 1.9
# Intensity: -2.5192303631567565
# Duration: 2.4
# Intensity: -2.570265304980759
# Duration: 2.2
# Intensity: -1.406879502612042
# Duration: 0.6
# Intensity: -1.0687225036110835
# Duration: 0.9
# Intensity: -1.869988981916894
# Duration: 1.6
# Intensity: -1.5082601139270795
# Duration: 0.9
# Intensity: -2.7655645552045365
# Duration: 1.7
# Intensity: -1.9758810816139674
# Duration: 0.4
# Intensity: -1.0934497199162736
# Duration: 1.9
# Intensity: -2.7041580078909266
# Duration: 1.5
# Intensity: -2.3402203937806725
# Duration: 0.9
# Intensity: -1.3943018794261701
# Duration: 2.4
# Intensity: -1.2717159181405324
# Duration: 1.5
# Intensity: -1.5258333382457199
# Duration: 0.7
# Intensity: -1.80232725377565
# Duration: 2.0
# Intensity: -2.7359272324047885
# Duration: 1.6
# Intensity: -1.8550740404210353
# Duration: 0.9
# Intensity: -1.521618169238682
# Duration: 0.9
# Intensity: -1.2509309194640703
# Duration: 1.4
# Intensity: -1.7125398456959853
# Duration: 1.0
# Intensity: -2.74413822071722
# Duration: 2.2
# Intensity: -2.2449310594825675
# Duration: 1.5
# Intensity: -2.463165865903461
# Duration: 0.4
# Intensity: -2.8286627183330264
# Duration: 1.7
# Intensity: -1.3455757711038816
# Duration: 0.9
# Intensity: -2.0859461862393056
# Duration: 1.7
# Intensity: -2.065217045594368
# Duration: 1.1
# Intensity: -2.059104010057424
# Duration: 1.4
# Intensity: -1.5515576628810246
# Duration: 1.9
# Intensity: -2.3389436167558824
# Duration: 1.5
# Durations:  [16. 20. 22. 25. 15. 10. 14. 22.  7. 16.  4. 17. 17. 11. 19. 24. 22.  6.
#   9. 16.  9. 17.  4. 19. 15.  9. 24. 15.  7. 20. 16.  9.  9. 14. 10. 22.
#  15.  4. 17.  9. 17. 11. 14. 19. 15.]
# Start times:  [ 7400  7481  7562  7644  7725  7807  7888  7970  8051  8133  8214  8296
#   8377  8459  8540  8622  8703  8785  8866  8948  9029  9111  9192  9273
#   9355  9436  9518  9599  9681  9762  9844  9925 10007 10088 10170 10251
#  10333 10414 10496 10577 10659 10740 10822 10903 10985]
# End times:  [7416.0, 7501.0, 7584.0, 7669.0, 7740.0, 7817.0, 7902.0, 7992.0, 8058.0, 8149.0, 8218.0, 8313.0, 8394.0, 8470.0, 8559.0, 8646.0, 8725.0, 8791.0, 8875.0, 8964.0, 9038.0, 9128.0, 9196.0, 9292.0, 9370.0, 9445.0, 9542.0, 9614.0, 9688.0, 9782.0, 9860.0, 9934.0, 10016.0, 10102.0, 10180.0, 10273.0, 10348.0, 10418.0, 10513.0, 10586.0, 10676.0, 10751.0, 10836.0, 10922.0, 11000.0]
# Shock times:
#  [[ 7400.  7416.]
#  [ 7481.  7501.]
#  [ 7562.  7584.]
#  [ 7644.  7669.]
#  [ 7725.  7740.]
#  [ 7807.  7817.]
#  [ 7888.  7902.]
#  [ 7970.  7992.]
#  [ 8051.  8058.]
#  [ 8133.  8149.]
#  [ 8214.  8218.]
#  [ 8296.  8313.]
#  [ 8377.  8394.]
#  [ 8459.  8470.]
#  [ 8540.  8559.]
#  [ 8622.  8646.]
#  [ 8703.  8725.]
#  [ 8785.  8791.]
#  [ 8866.  8875.]
#  [ 8948.  8964.]
#  [ 9029.  9038.]
#  [ 9111.  9128.]
#  [ 9192.  9196.]
#  [ 9273.  9292.]
#  [ 9355.  9370.]
#  [ 9436.  9445.]
#  [ 9518.  9542.]
#  [ 9599.  9614.]
#  [ 9681.  9688.]
#  [ 9762.  9782.]
#  [ 9844.  9860.]
#  [ 9925.  9934.]
#  [10007. 10016.]
#  [10088. 10102.]
#  [10170. 10180.]
#  [10251. 10273.]
#  [10333. 10348.]
#  [10414. 10418.]
#  [10496. 10513.]
#  [10577. 10586.]
#  [10659. 10676.]
#  [10740. 10751.]
#  [10822. 10836.]
#  [10903. 10922.]
#  [10985. 11000.]]
# Round 0, Return: 7916.3999999994685
# /mnt/c/Users/09_gi/Desktop/flow/poudel_bottleneck/test_time_rollout/vinitsky/bottleneck_2_20230911-1053361694444016.3910718-0_emission.csv /mnt/c/Users/09_gi/Desktop/flow/poudel_bottleneck/test_time_rollout/vinitsky
# Frequency: 39
# Intensity: -2.7003046085445566
# Duration: 0.7
# Intensity: -2.947516769681227
# Duration: 2.1
# Intensity: -1.5873006833183765
# Duration: 0.6
# Intensity: -2.2976076196075663
# Duration: 2.0
# Intensity: -1.1075243684956095
# Duration: 1.0
# Intensity: -1.2492195210646406
# Duration: 2.1
# Intensity: -1.6848703414493227
# Duration: 1.6
# Intensity: -2.080579648279958
# Duration: 1.1
# Intensity: -1.65465549552445
# Duration: 1.2
# Intensity: -2.0208689483720566
# Duration: 0.6
# Intensity: -1.5073072272492458
# Duration: 0.6
# Intensity: -2.6594919923676805
# Duration: 0.9
# Intensity: -1.8623773812032742
# Duration: 0.9
# Intensity: -2.926307056055575
# Duration: 0.7
# Intensity: -1.9507646846163247
# Duration: 1.4
# Intensity: -1.8852035880256475
# Duration: 0.4
# Intensity: -2.0214895144070293
# Duration: 2.1
# Intensity: -1.7421898252212213
# Duration: 1.1
# Intensity: -1.5834484567705092
# Duration: 0.5
# Intensity: -2.3685279924363574
# Duration: 2.2
# Intensity: -1.350643646412958
# Duration: 0.9
# Intensity: -2.3039887773677767
# Duration: 1.4
# Intensity: -1.0597924129257195
# Duration: 0.9
# Intensity: -2.4045606305103786
# Duration: 1.0
# Intensity: -2.55522235816986
# Duration: 1.5
# Intensity: -1.3744206724996764
# Duration: 1.0
# Intensity: -1.6279233018414718
# Duration: 1.2
# Intensity: -2.2957738330183077
# Duration: 0.4
# Intensity: -1.3920698323170146
# Duration: 1.6
# Intensity: -2.7177159082014164
# Duration: 0.7
# Intensity: -1.3172212975383155
# Duration: 0.6
# Intensity: -1.5789604678854396
# Duration: 0.9
# Intensity: -1.7772813351758245
# Duration: 0.4
# Intensity: -2.249318535530853
# Duration: 1.5
# Intensity: -1.7238451931920473
# Duration: 1.2
# Intensity: -1.800852762771986
# Duration: 1.0
# Intensity: -1.9270661052250628
# Duration: 1.2
# Intensity: -2.2492507637185604
# Duration: 1.6
# Intensity: -2.5988602475076914
# Duration: 1.9
# Durations:  [ 7. 21.  6. 20. 10. 21. 16. 11. 12.  6.  6.  9.  9.  7. 14.  4. 21. 11.
#   5. 22.  9. 14.  9. 10. 15. 10. 12.  4. 16.  7.  6.  9.  4. 15. 12. 10.
#  12. 16. 19.]
# Start times:  [ 7400  7494  7588  7682  7776  7871  7965  8059  8153  8248  8342  8436
#   8530  8625  8719  8813  8907  9002  9096  9190  9284  9378  9473  9567
#   9661  9755  9850  9944 10038 10132 10227 10321 10415 10509 10604 10698
#  10792 10886 10981]
# End times:  [7407.0, 7515.0, 7594.0, 7702.0, 7786.0, 7892.0, 7981.0, 8070.0, 8165.0, 8254.0, 8348.0, 8445.0, 8539.0, 8632.0, 8733.0, 8817.0, 8928.0, 9013.0, 9101.0, 9212.0, 9293.0, 9392.0, 9482.0, 9577.0, 9676.0, 9765.0, 9862.0, 9948.0, 10054.0, 10139.0, 10233.0, 10330.0, 10419.0, 10524.0, 10616.0, 10708.0, 10804.0, 10902.0, 11000.0]
# Shock times:
#  [[ 7400.  7407.]
#  [ 7494.  7515.]
#  [ 7588.  7594.]
#  [ 7682.  7702.]
#  [ 7776.  7786.]
#  [ 7871.  7892.]
#  [ 7965.  7981.]
#  [ 8059.  8070.]
#  [ 8153.  8165.]
#  [ 8248.  8254.]
#  [ 8342.  8348.]
#  [ 8436.  8445.]
#  [ 8530.  8539.]
#  [ 8625.  8632.]
#  [ 8719.  8733.]
#  [ 8813.  8817.]
#  [ 8907.  8928.]
#  [ 9002.  9013.]
#  [ 9096.  9101.]
#  [ 9190.  9212.]
#  [ 9284.  9293.]
#  [ 9378.  9392.]
#  [ 9473.  9482.]
#  [ 9567.  9577.]
#  [ 9661.  9676.]
#  [ 9755.  9765.]
#  [ 9850.  9862.]
#  [ 9944.  9948.]
#  [10038. 10054.]
#  [10132. 10139.]
#  [10227. 10233.]
#  [10321. 10330.]
#  [10415. 10419.]
#  [10509. 10524.]
#  [10604. 10616.]
#  [10698. 10708.]
#  [10792. 10804.]
#  [10886. 10902.]
#  [10981. 11000.]]
