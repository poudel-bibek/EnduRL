# %% [markdown]
# ### Data collection for various metrics:
#
# For Ours:
# Data Collection for Safety and Stability Metrics (Ignore the efficiency metrics even though they are displayed).
#
# Collection performed in 2 stages
#
#     A. Data collection for Safety and CAV (Controller Acceleration Variation)
#     B. Data collevtion for WAR (Wave Attenuation Ratio)
#
# ### Notes:
#
# - Desired velocity change for FS May need monitoring (May not be set for all possible lengths)
# - PI can have failures, so have to turn ON render and manually check
# - Generated data will be saved in the folder `test_time_rollout`
#
# - At test time: The inflow should be fixed and be same as the classic controllers
# - Sim step: At training, was set to 0.5. At test, set to 0.1
#
# ## When analyzing the csv files
# - For RL shocks start at 7400 and end at 11000
# - To make it fair, for classic controller the rollouts goes upto 11000 with shocks that come up at 7400 (for some reason, the warmup value makes the horizon longer but does not push the shock start time back.)

# %%
NUM_ROLLOUTS = 5

# %% [markdown]
# ## IDM

# %%
# idm --shock 
# !python classic.py --method idm --gen_emission --num_rollouts $NUM_ROLLOUTS --render --shock
# Out:
# /mnt/c/Users/09_gi/Desktop/flow/flow/utils/flow_warnings.py:26: PendingDeprecationWarning: The attribute departLane in InFlows is deprecated, use depart_lane instead.
#   PendingDeprecationWarning
# /mnt/c/Users/09_gi/Desktop/flow/flow/utils/flow_warnings.py:26: PendingDeprecationWarning: The attribute departSpeed in InFlows is deprecated, use depart_speed instead.
#   PendingDeprecationWarning
# Frequency: 36
# Intensity: -2.7339895847277935
# Duration: 1.5
# Intensity: -1.9877295255206635
# Duration: 0.4
# Intensity: -1.466704913813585
# Duration: 1.6
# Intensity: -1.133438126856025
# Duration: 1.5
# Intensity: -1.5015068695178864
# Duration: 0.5
# Intensity: -2.2758151894374623
# Duration: 1.7
# Intensity: -2.610564820581714
# Duration: 1.7
# Intensity: -2.3181294320524106
# Duration: 1.1
# Intensity: -2.21270206303405
# Duration: 1.0
# Intensity: -2.715342656043783
# Duration: 1.6
# Intensity: -2.2054553877591663
# Duration: 1.6
# Intensity: -1.8469795477810802
# Duration: 1.0
# Intensity: -2.3632600363509875
# Duration: 1.0
# Intensity: -2.329401161811961
# Duration: 0.5
# Intensity: -2.701181615275299
# Duration: 2.1
# Intensity: -1.5792750768277148
# Duration: 0.7
# Intensity: -1.6607348770561015
# Duration: 1.6
# Intensity: -1.9505493502209674
# Duration: 1.6
# Intensity: -2.6344414924191373
# Duration: 1.5
# Intensity: -2.7785639541070526
# Duration: 1.0
# Intensity: -2.726625332930282
# Duration: 2.4
# Intensity: -1.3508157429900447
# Duration: 0.9
# Intensity: -1.3619523350862404
# Duration: 1.1
# Intensity: -2.2387170708466915
# Duration: 1.7
# Intensity: -2.574578748409642
# Duration: 1.4
# Intensity: -1.940760884216615
# Duration: 1.9
# Intensity: -2.7676395807383245
# Duration: 2.4
# Intensity: -1.597535631234299
# Duration: 0.9
# Intensity: -1.80967924029429
# Duration: 2.0
# Intensity: -2.731351973248425
# Duration: 1.4
# Intensity: -2.719351548315438
# Duration: 1.9
# Intensity: -1.3586841493694661
# Duration: 1.0
# Intensity: -1.150927518940858
# Duration: 0.7
# Intensity: -2.390357686426479
# Duration: 1.7
# Intensity: -1.010046668308659
# Duration: 0.7
# Intensity: -2.7391315505245144
# Duration: 1.1
# Durations:  [15.  4. 16. 15.  5. 17. 17. 11. 10. 16. 16. 10. 10.  5. 21.  7. 16. 16.
#  15. 10. 24.  9. 11. 17. 14. 19. 24.  9. 20. 14. 19. 10.  7. 17.  7. 11.]
# Start times:  [ 7400  7502  7605  7707  7810  7912  8015  8117  8220  8322  8425  8527
#   8630  8733  8835  8938  9040  9143  9245  9348  9450  9553  9655  9758
#   9861  9963 10066 10168 10271 10373 10476 10578 10681 10783 10886 10989]
# End times:  [7415.0, 7506.0, 7621.0, 7722.0, 7815.0, 7929.0, 8032.0, 8128.0, 8230.0, 8338.0, 8441.0, 8537.0, 8640.0, 8738.0, 8856.0, 8945.0, 9056.0, 9159.0, 9260.0, 9358.0, 9474.0, 9562.0, 9666.0, 9775.0, 9875.0, 9982.0, 10090.0, 10177.0, 10291.0, 10387.0, 10495.0, 10588.0, 10688.0, 10800.0, 10893.0, 11000.0]
# Shock times:
#  [[ 7400.  7415.]
#  [ 7502.  7506.]
#  [ 7605.  7621.]
#  [ 7707.  7722.]
#  [ 7810.  7815.]
#  [ 7912.  7929.]
#  [ 8015.  8032.]
#  [ 8117.  8128.]
#  [ 8220.  8230.]
#  [ 8322.  8338.]
#  [ 8425.  8441.]
#  [ 8527.  8537.]
#  [ 8630.  8640.]
#  [ 8733.  8738.]
#  [ 8835.  8856.]
#  [ 8938.  8945.]
#  [ 9040.  9056.]
#  [ 9143.  9159.]
#  [ 9245.  9260.]
#  [ 9348.  9358.]
#  [ 9450.  9474.]
#  [ 9553.  9562.]
#  [ 9655.  9666.]
#  [ 9758.  9775.]
#  [ 9861.  9875.]
#  [ 9963.  9982.]
#  [10066. 10090.]
#  [10168. 10177.]
#  [10271. 10291.]
#  [10373. 10387.]
#  [10476. 10495.]
#  [10578. 10588.]
#  [10681. 10688.]
#  [10783. 10800.]
#  [10886. 10893.]
#  [10989. 11000.]]
#
#
# Shock ids: ['flow_00.620' 'flow_00.600' 'flow_00.716' 'flow_00.614']
#
#
# Step = 7400, Shock params: (-2.7339895847277935, 1.5, 36) applied to vehicle ['flow_00.620' 'flow_00.600' 'flow_00.716' 'flow_00.614']
#
# Step = 7401, Shock params: (-2.7339895847277935, 1.5, 36) applied to vehicle ['flow_00.620' 'flow_00.600' 'flow_00.716' 'flow_00.614']
#
# Step = 7402, Shock params: (-2.7339895847277935, 1.5, 36) applied to vehicle ['flow_00.620' 'flow_00.600' 'flow_00.716' 'flow_00.614']
#
# Step = 7403, Shock params: (-2.7339895847277935, 1.5, 36) applied to vehicle ['flow_00.620' 'flow_00.600' 'flow_00.716' 'flow_00.614']
#
# Step = 7404, Shock params: (-2.7339895847277935, 1.5, 36) applied to vehicle ['flow_00.620' 'flow_00.600' 'flow_00.716' 'flow_00.614']
#
# Step = 7405, Shock params: (-2.7339895847277935, 1.5, 36) applied to vehicle ['flow_00.620' 'flow_00.600' 'flow_00.716' 'flow_00.614']
#
# Step = 7406, Shock params: (-2.7339895847277935, 1.5, 36) applied to vehicle ['flow_00.620' 'flow_00.600' 'flow_00.716' 'flow_00.614']
#
# Step = 7407, Shock params: (-2.7339895847277935, 1.5, 36) applied to vehicle ['flow_00.620' 'flow_00.600' 'flow_00.716' 'flow_00.614']
#
# Step = 7408, Shock params: (-2.7339895847277935, 1.5, 36) applied to vehicle ['flow_00.620' 'flow_00.600' 'flow_00.716' 'flow_00.614']
#
# Step = 7409, Shock params: (-2.7339895847277935, 1.5, 36) applied to vehicle ['flow_00.620' 'flow_00.600' 'flow_00.716' 'flow_00.614']
#
# Step = 7410, Shock params: (-2.7339895847277935, 1.5, 36) applied to vehicle ['flow_00.620' 'flow_00.600' 'flow_00.716' 'flow_00.614']
#
# Step = 7411, Shock params: (-2.7339895847277935, 1.5, 36) applied to vehicle ['flow_00.620' 'flow_00.600' 'flow_00.716' 'flow_00.614']
#
# Step = 7412, Shock params: (-2.7339895847277935, 1.5, 36) applied to vehicle ['flow_00.620' 'flow_00.600' 'flow_00.716' 'flow_00.614']
#
# Step = 7413, Shock params: (-2.7339895847277935, 1.5, 36) applied to vehicle ['flow_00.620' 'flow_00.600' 'flow_00.716' 'flow_00.614']
#
# Step = 7414, Shock params: (-2.7339895847277935, 1.5, 36) applied to vehicle ['flow_00.620' 'flow_00.600' 'flow_00.716' 'flow_00.614']
#
#
#
# Shock ids: ['flow_00.616' 'flow_00.714' 'flow_00.616' 'flow_00.656']
#
#
# Step = 7502, Shock params: (-1.9877295255206635, 0.4, 36) applied to vehicle ['flow_00.616' 'flow_00.714' 'flow_00.616' 'flow_00.656']
#
# Step = 7503, Shock params: (-1.9877295255206635, 0.4, 36) applied to vehicle ['flow_00.616' 'flow_00.714' 'flow_00.616' 'flow_00.656']
#
# Step = 7504, Shock params: (-1.9877295255206635, 0.4, 36) applied to vehicle ['flow_00.616' 'flow_00.714' 'flow_00.616' 'flow_00.656']
#
# Step = 7505, Shock params: (-1.9877295255206635, 0.4, 36) applied to vehicle ['flow_00.616' 'flow_00.714' 'flow_00.616' 'flow_00.656']
#
#
#
# Shock ids: ['flow_00.624' 'flow_00.686' 'flow_00.674' 'flow_00.654']
#
#
# Step = 7605, Shock params: (-1.466704913813585, 1.6, 36) applied to vehicle ['flow_00.624' 'flow_00.686' 'flow_00.674' 'flow_00.654']
#
# Step = 7606, Shock params: (-1.466704913813585, 1.6, 36) applied to vehicle ['flow_00.624' 'flow_00.686' 'flow_00.674' 'flow_00.654']
#
# Step = 7607, Shock params: (-1.466704913813585, 1.6, 36) applied to vehicle ['flow_00.624' 'flow_00.686' 'flow_00.674' 'flow_00.654']
#
# Step = 7608, Shock params: (-1.466704913813585, 1.6, 36) applied to vehicle ['flow_00.624' 'flow_00.686' 'flow_00.674' 'flow_00.654']
#
# Step = 7609, Shock params: (-1.466704913813585, 1.6, 36) applied to vehicle ['flow_00.624' 'flow_00.686' 'flow_00.674' 'flow_00.654']
#
# Step = 7610, Shock params: (-1.466704913813585, 1.6, 36) applied to vehicle ['flow_00.624' 'flow_00.686' 'flow_00.674' 'flow_00.654']
#
# Step = 7611, Shock params: (-1.466704913813585, 1.6, 36) applied to vehicle ['flow_00.624' 'flow_00.686' 'flow_00.674' 'flow_00.654']
#
# Step = 7612, Shock params: (-1.466704913813585, 1.6, 36) applied to vehicle ['flow_00.624' 'flow_00.686' 'flow_00.674' 'flow_00.654']
#
# Step = 7613, Shock params: (-1.466704913813585, 1.6, 36) applied to vehicle ['flow_00.624' 'flow_00.686' 'flow_00.674' 'flow_00.654']
#
# Step = 7614, Shock params: (-1.466704913813585, 1.6, 36) applied to vehicle ['flow_00.624' 'flow_00.686' 'flow_00.674' 'flow_00.654']
#
# Step = 7615, Shock params: (-1.466704913813585, 1.6, 36) applied to vehicle ['flow_00.624' 'flow_00.686' 'flow_00.674' 'flow_00.654']
#
# Step = 7616, Shock params: (-1.466704913813585, 1.6, 36) applied to vehicle ['flow_00.624' 'flow_00.686' 'flow_00.674' 'flow_00.654']
#
# Step = 7617, Shock params: (-1.466704913813585, 1.6, 36) applied to vehicle ['flow_00.624' 'flow_00.686' 'flow_00.674' 'flow_00.654']
#
# Step = 7618, Shock params: (-1.466704913813585, 1.6, 36) applied to vehicle ['flow_00.624' 'flow_00.686' 'flow_00.674' 'flow_00.654']
#
# Step = 7619, Shock params: (-1.466704913813585, 1.6, 36) applied to vehicle ['flow_00.624' 'flow_00.686' 'flow_00.674' 'flow_00.654']
#
# Step = 7620, Shock params: (-1.466704913813585, 1.6, 36) applied to vehicle ['flow_00.624' 'flow_00.686' 'flow_00.674' 'flow_00.654']
# Shock ids: ['flow_00.737' 'flow_00.603' 'flow_00.664' 'flow_00.667']
#
#
# Step = 7707, Shock params: (-1.133438126856025, 1.5, 36) applied to vehicle ['flow_00.737' 'flow_00.603' 'flow_00.664' 'flow_00.667']
#
# Step = 7708, Shock params: (-1.133438126856025, 1.5, 36) applied to vehicle ['flow_00.737' 'flow_00.603' 'flow_00.664' 'flow_00.667']
#
# Step = 7709, Shock params: (-1.133438126856025, 1.5, 36) applied to vehicle ['flow_00.737' 'flow_00.603' 'flow_00.664' 'flow_00.667']
#
# Step = 7710, Shock params: (-1.133438126856025, 1.5, 36) applied to vehicle ['flow_00.737' 'flow_00.603' 'flow_00.664' 'flow_00.667']
#
# Step = 7711, Shock params: (-1.133438126856025, 1.5, 36) applied to vehicle ['flow_00.737' 'flow_00.603' 'flow_00.664' 'flow_00.667']
#
# Step = 7712, Shock params: (-1.133438126856025, 1.5, 36) applied to vehicle ['flow_00.737' 'flow_00.603' 'flow_00.664' 'flow_00.667']
#
# Step = 7713, Shock params: (-1.133438126856025, 1.5, 36) applied to vehicle ['flow_00.737' 'flow_00.603' 'flow_00.664' 'flow_00.667']
#
# Step = 7714, Shock params: (-1.133438126856025, 1.5, 36) applied to vehicle ['flow_00.737' 'flow_00.603' 'flow_00.664' 'flow_00.667']
#
# Step = 7715, Shock params: (-1.133438126856025, 1.5, 36) applied to vehicle ['flow_00.737' 'flow_00.603' 'flow_00.664' 'flow_00.667']
#
# Step = 7716, Shock params: (-1.133438126856025, 1.5, 36) applied to vehicle ['flow_00.737' 'flow_00.603' 'flow_00.664' 'flow_00.667']
#
# Step = 7717, Shock params: (-1.133438126856025, 1.5, 36) applied to vehicle ['flow_00.737' 'flow_00.603' 'flow_00.664' 'flow_00.667']
#
# Step = 7718, Shock params: (-1.133438126856025, 1.5, 36) applied to vehicle ['flow_00.737' 'flow_00.603' 'flow_00.664' 'flow_00.667']
#
# Step = 7719, Shock params: (-1.133438126856025, 1.5, 36) applied to vehicle ['flow_00.737' 'flow_00.603' 'flow_00.664' 'flow_00.667']
#
# Step = 7720, Shock params: (-1.133438126856025, 1.5, 36) applied to vehicle ['flow_00.737' 'flow_00.603' 'flow_00.664' 'flow_00.667']
#
# Step = 7721, Shock params: (-1.133438126856025, 1.5, 36) applied to vehicle ['flow_00.737' 'flow_00.603' 'flow_00.664' 'flow_00.667']
#
#
#
# Shock ids: ['flow_00.526' 'flow_00.637' 'flow_00.741' 'flow_00.692']
#
#
# Step = 7810, Shock params: (-1.5015068695178864, 0.5, 36) applied to vehicle ['flow_00.526' 'flow_00.637' 'flow_00.741' 'flow_00.692']
#
# Step = 7811, Shock params: (-1.5015068695178864, 0.5, 36) applied to vehicle ['flow_00.526' 'flow_00.637' 'flow_00.741' 'flow_00.692']
#
# Step = 7812, Shock params: (-1.5015068695178864, 0.5, 36) applied to vehicle ['flow_00.526' 'flow_00.637' 'flow_00.741' 'flow_00.692']
#
# Step = 7813, Shock params: (-1.5015068695178864, 0.5, 36) applied to vehicle ['flow_00.526' 'flow_00.637' 'flow_00.741' 'flow_00.692']
#
# Step = 7814, Shock params: (-1.5015068695178864, 0.5, 36) applied to vehicle ['flow_00.526' 'flow_00.637' 'flow_00.741' 'flow_00.692']
#
#
#
# Shock ids: ['flow_00.756' 'flow_00.675' 'flow_00.754' 'flow_00.720']
#
#
# Step = 7912, Shock params: (-2.2758151894374623, 1.7, 36) applied to vehicle ['flow_00.756' 'flow_00.675' 'flow_00.754' 'flow_00.720']
#
# Step = 7913, Shock params: (-2.2758151894374623, 1.7, 36) applied to vehicle ['flow_00.756' 'flow_00.675' 'flow_00.754' 'flow_00.720']
#
# Step = 7914, Shock params: (-2.2758151894374623, 1.7, 36) applied to vehicle ['flow_00.756' 'flow_00.675' 'flow_00.754' 'flow_00.720']
#
# Step = 7915, Shock params: (-2.2758151894374623, 1.7, 36) applied to vehicle ['flow_00.756' 'flow_00.675' 'flow_00.754' 'flow_00.720']
#
# Step = 7916, Shock params: (-2.2758151894374623, 1.7, 36) applied to vehicle ['flow_00.756' 'flow_00.675' 'flow_00.754' 'flow_00.720']
#
# Step = 7917, Shock params: (-2.2758151894374623, 1.7, 36) applied to vehicle ['flow_00.756' 'flow_00.675' 'flow_00.754' 'flow_00.720']
#
# Step = 7918, Shock params: (-2.2758151894374623, 1.7, 36) applied to vehicle ['flow_00.756' 'flow_00.675' 'flow_00.754' 'flow_00.720']
#
# Step = 7919, Shock params: (-2.2758151894374623, 1.7, 36) applied to vehicle ['flow_00.756' 'flow_00.675' 'flow_00.754' 'flow_00.720']
#
# Step = 7920, Shock params: (-2.2758151894374623, 1.7, 36) applied to vehicle ['flow_00.756' 'flow_00.675' 'flow_00.754' 'flow_00.720']
#
# Step = 7921, Shock params: (-2.2758151894374623, 1.7, 36) applied to vehicle ['flow_00.756' 'flow_00.675' 'flow_00.754' 'flow_00.720']
#
# Step = 7922, Shock params: (-2.2758151894374623, 1.7, 36) applied to vehicle ['flow_00.756' 'flow_00.675' 'flow_00.754' 'flow_00.720']
#
# Step = 7923, Shock params: (-2.2758151894374623, 1.7, 36) applied to vehicle ['flow_00.756' 'flow_00.675' 'flow_00.754' 'flow_00.720']
#
# Step = 7924, Shock params: (-2.2758151894374623, 1.7, 36) applied to vehicle ['flow_00.756' 'flow_00.675' 'flow_00.754' 'flow_00.720']
#
# Step = 7925, Shock params: (-2.2758151894374623, 1.7, 36) applied to vehicle ['flow_00.756' 'flow_00.675' 'flow_00.754' 'flow_00.720']
#
# Step = 7926, Shock params: (-2.2758151894374623, 1.7, 36) applied to vehicle ['flow_00.756' 'flow_00.675' 'flow_00.754' 'flow_00.720']
#
# Step = 7927, Shock params: (-2.2758151894374623, 1.7, 36) applied to vehicle ['flow_00.756' 'flow_00.675' 'flow_00.754' 'flow_00.720']
#
# Step = 7928, Shock params: (-2.2758151894374623, 1.7, 36) applied to vehicle ['flow_00.756' 'flow_00.675' 'flow_00.754' 'flow_00.720']
#
#
#
# Shock ids: ['flow_00.546' 'flow_00.763' 'flow_00.568' 'flow_00.767']
#
#
# Step = 8015, Shock params: (-2.610564820581714, 1.7, 36) applied to vehicle ['flow_00.546' 'flow_00.763' 'flow_00.568' 'flow_00.767']
#
# Step = 8016, Shock params: (-2.610564820581714, 1.7, 36) applied to vehicle ['flow_00.546' 'flow_00.763' 'flow_00.568' 'flow_00.767']
#
# Step = 8017, Shock params: (-2.610564820581714, 1.7, 36) applied to vehicle ['flow_00.546' 'flow_00.763' 'flow_00.568' 'flow_00.767']
#
# Step = 8018, Shock params: (-2.610564820581714, 1.7, 36) applied to vehicle ['flow_00.546' 'flow_00.763' 'flow_00.568' 'flow_00.767']
#
# Step = 8019, Shock params: (-2.610564820581714, 1.7, 36) applied to vehicle ['flow_00.546' 'flow_00.763' 'flow_00.568' 'flow_00.767']
#
# Step = 8020, Shock params: (-2.610564820581714, 1.7, 36) applied to vehicle ['flow_00.546' 'flow_00.763' 'flow_00.568' 'flow_00.767']
#
# Step = 8021, Shock params: (-2.610564820581714, 1.7, 36) applied to vehicle ['flow_00.546' 'flow_00.763' 'flow_00.568' 'flow_00.767']
#
# Step = 8022, Shock params: (-2.610564820581714, 1.7, 36) applied to vehicle ['flow_00.546' 'flow_00.763' 'flow_00.568' 'flow_00.767']
#
# Step = 8023, Shock params: (-2.610564820581714, 1.7, 36) applied to vehicle ['flow_00.546' 'flow_00.763' 'flow_00.568' 'flow_00.767']
#
# Step = 8024, Shock params: (-2.610564820581714, 1.7, 36) applied to vehicle ['flow_00.546' 'flow_00.763' 'flow_00.568' 'flow_00.767']
#
# Step = 8025, Shock params: (-2.610564820581714, 1.7, 36) applied to vehicle ['flow_00.546' 'flow_00.763' 'flow_00.568' 'flow_00.767']
#
# Step = 8026, Shock params: (-2.610564820581714, 1.7, 36) applied to vehicle ['flow_00.546' 'flow_00.763' 'flow_00.568' 'flow_00.767']
#
# Step = 8027, Shock params: (-2.610564820581714, 1.7, 36) applied to vehicle ['flow_00.546' 'flow_00.763' 'flow_00.568' 'flow_00.767']
#
# Step = 8028, Shock params: (-2.610564820581714, 1.7, 36) applied to vehicle ['flow_00.546' 'flow_00.763' 'flow_00.568' 'flow_00.767']
#
# Step = 8029, Shock params: (-2.610564820581714, 1.7, 36) applied to vehicle ['flow_00.546' 'flow_00.763' 'flow_00.568' 'flow_00.767']
#
# Step = 8030, Shock params: (-2.610564820581714, 1.7, 36) applied to vehicle ['flow_00.546' 'flow_00.763' 'flow_00.568' 'flow_00.767']
#
# Step = 8031, Shock params: (-2.610564820581714, 1.7, 36) applied to vehicle ['flow_00.546' 'flow_00.763' 'flow_00.568' 'flow_00.767']
#
#
#
# Shock ids: ['flow_00.549' 'flow_00.669' 'flow_00.776' 'flow_00.582']
#
#
# Step = 8117, Shock params: (-2.3181294320524106, 1.1, 36) applied to vehicle ['flow_00.549' 'flow_00.669' 'flow_00.776' 'flow_00.582']
#
# Step = 8118, Shock params: (-2.3181294320524106, 1.1, 36) applied to vehicle ['flow_00.549' 'flow_00.669' 'flow_00.776' 'flow_00.582']
#
# Step = 8119, Shock params: (-2.3181294320524106, 1.1, 36) applied to vehicle ['flow_00.549' 'flow_00.669' 'flow_00.776' 'flow_00.582']
#
# Step = 8120, Shock params: (-2.3181294320524106, 1.1, 36) applied to vehicle ['flow_00.549' 'flow_00.669' 'flow_00.776' 'flow_00.582']
# Step = 8121, Shock params: (-2.3181294320524106, 1.1, 36) applied to vehicle ['flow_00.549' 'flow_00.669' 'flow_00.776' 'flow_00.582']
#
# Step = 8122, Shock params: (-2.3181294320524106, 1.1, 36) applied to vehicle ['flow_00.549' 'flow_00.669' 'flow_00.776' 'flow_00.582']
#
# Step = 8123, Shock params: (-2.3181294320524106, 1.1, 36) applied to vehicle ['flow_00.549' 'flow_00.669' 'flow_00.776' 'flow_00.582']
#
# Step = 8124, Shock params: (-2.3181294320524106, 1.1, 36) applied to vehicle ['flow_00.549' 'flow_00.669' 'flow_00.776' 'flow_00.582']
#
# Step = 8125, Shock params: (-2.3181294320524106, 1.1, 36) applied to vehicle ['flow_00.549' 'flow_00.669' 'flow_00.776' 'flow_00.582']
#
# Step = 8126, Shock params: (-2.3181294320524106, 1.1, 36) applied to vehicle ['flow_00.549' 'flow_00.669' 'flow_00.776' 'flow_00.582']
#
# Step = 8127, Shock params: (-2.3181294320524106, 1.1, 36) applied to vehicle ['flow_00.549' 'flow_00.669' 'flow_00.776' 'flow_00.582']
#
# Step = 8128, Shock params: (-2.3181294320524106, 1.1, 36) applied to vehicle ['flow_00.549' 'flow_00.669' 'flow_00.776' 'flow_00.582']
#
#
#
# Shock ids: ['flow_00.676' 'flow_00.665' 'flow_00.608' 'flow_00.628']
#
#
# Step = 8220, Shock params: (-2.21270206303405, 1.0, 36) applied to vehicle ['flow_00.676' 'flow_00.665' 'flow_00.608' 'flow_00.628']
#
# Step = 8221, Shock params: (-2.21270206303405, 1.0, 36) applied to vehicle ['flow_00.676' 'flow_00.665' 'flow_00.608' 'flow_00.628']
#
# Step = 8222, Shock params: (-2.21270206303405, 1.0, 36) applied to vehicle ['flow_00.676' 'flow_00.665' 'flow_00.608' 'flow_00.628']
#
# Step = 8223, Shock params: (-2.21270206303405, 1.0, 36) applied to vehicle ['flow_00.676' 'flow_00.665' 'flow_00.608' 'flow_00.628']
#
# Step = 8224, Shock params: (-2.21270206303405, 1.0, 36) applied to vehicle ['flow_00.676' 'flow_00.665' 'flow_00.608' 'flow_00.628']
#
# Step = 8225, Shock params: (-2.21270206303405, 1.0, 36) applied to vehicle ['flow_00.676' 'flow_00.665' 'flow_00.608' 'flow_00.628']
#
# Step = 8226, Shock params: (-2.21270206303405, 1.0, 36) applied to vehicle ['flow_00.676' 'flow_00.665' 'flow_00.608' 'flow_00.628']
#
# Step = 8227, Shock params: (-2.21270206303405, 1.0, 36) applied to vehicle ['flow_00.676' 'flow_00.665' 'flow_00.608' 'flow_00.628']
#
# Step = 8228, Shock params: (-2.21270206303405, 1.0, 36) applied to vehicle ['flow_00.676' 'flow_00.665' 'flow_00.608' 'flow_00.628']
#
# Step = 8229, Shock params: (-2.21270206303405, 1.0, 36) applied to vehicle ['flow_00.676' 'flow_00.665' 'flow_00.608' 'flow_00.628']
#
# Step = 8230, Shock params: (-2.21270206303405, 1.0, 36) applied to vehicle ['flow_00.676' 'flow_00.665' 'flow_00.608' 'flow_00.628']
#
#
#
# Shock ids: ['flow_00.733' 'flow_00.661' 'flow_00.687' 'flow_00.733']
#
#
# Step = 8322, Shock params: (-2.715342656043783, 1.6, 36) applied to vehicle ['flow_00.733' 'flow_00.661' 'flow_00.687' 'flow_00.733']
#
# Step = 8323, Shock params: (-2.715342656043783, 1.6, 36) applied to vehicle ['flow_00.733' 'flow_00.661' 'flow_00.687' 'flow_00.733']
#
# Step = 8324, Shock params: (-2.715342656043783, 1.6, 36) applied to vehicle ['flow_00.733' 'flow_00.661' 'flow_00.687' 'flow_00.733']
#
# Step = 8325, Shock params: (-2.715342656043783, 1.6, 36) applied to vehicle ['flow_00.733' 'flow_00.661' 'flow_00.687' 'flow_00.733']
#
# Step = 8326, Shock params: (-2.715342656043783, 1.6, 36) applied to vehicle ['flow_00.733' 'flow_00.661' 'flow_00.687' 'flow_00.733']
#
# Step = 8327, Shock params: (-2.715342656043783, 1.6, 36) applied to vehicle ['flow_00.733' 'flow_00.661' 'flow_00.687' 'flow_00.733']
#
# Step = 8328, Shock params: (-2.715342656043783, 1.6, 36) applied to vehicle ['flow_00.733' 'flow_00.661' 'flow_00.687' 'flow_00.733']
#
# Step = 8329, Shock params: (-2.715342656043783, 1.6, 36) applied to vehicle ['flow_00.733' 'flow_00.661' 'flow_00.687' 'flow_00.733']
#
# Step = 8330, Shock params: (-2.715342656043783, 1.6, 36) applied to vehicle ['flow_00.733' 'flow_00.661' 'flow_00.687' 'flow_00.733']
#
# Step = 8331, Shock params: (-2.715342656043783, 1.6, 36) applied to vehicle ['flow_00.733' 'flow_00.661' 'flow_00.687' 'flow_00.733']
#
# Step = 8332, Shock params: (-2.715342656043783, 1.6, 36) applied to vehicle ['flow_00.733' 'flow_00.661' 'flow_00.687' 'flow_00.733']
#
# Step = 8333, Shock params: (-2.715342656043783, 1.6, 36) applied to vehicle ['flow_00.733' 'flow_00.661' 'flow_00.687' 'flow_00.733']
#
# Step = 8334, Shock params: (-2.715342656043783, 1.6, 36) applied to vehicle ['flow_00.733' 'flow_00.661' 'flow_00.687' 'flow_00.733']
#
# Step = 8335, Shock params: (-2.715342656043783, 1.6, 36) applied to vehicle ['flow_00.733' 'flow_00.661' 'flow_00.687' 'flow_00.733']
#
# Step = 8336, Shock params: (-2.715342656043783, 1.6, 36) applied to vehicle ['flow_00.733' 'flow_00.661' 'flow_00.687' 'flow_00.733']
#
# Step = 8337, Shock params: (-2.715342656043783, 1.6, 36) applied to vehicle ['flow_00.733' 'flow_00.661' 'flow_00.687' 'flow_00.733']
#
#
#
# Shock ids: ['flow_00.691' 'flow_00.692' 'flow_00.669' 'flow_00.696']
#
#
# Step = 8425, Shock params: (-2.2054553877591663, 1.6, 36) applied to vehicle ['flow_00.691' 'flow_00.692' 'flow_00.669' 'flow_00.696']
#
# Step = 8426, Shock params: (-2.2054553877591663, 1.6, 36) applied to vehicle ['flow_00.691' 'flow_00.692' 'flow_00.669' 'flow_00.696']
#
# Step = 8427, Shock params: (-2.2054553877591663, 1.6, 36) applied to vehicle ['flow_00.691' 'flow_00.692' 'flow_00.669' 'flow_00.696']
#
# Step = 8428, Shock params: (-2.2054553877591663, 1.6, 36) applied to vehicle ['flow_00.691' 'flow_00.692' 'flow_00.669' 'flow_00.696']
#
# Step = 8429, Shock params: (-2.2054553877591663, 1.6, 36) applied to vehicle ['flow_00.691' 'flow_00.692' 'flow_00.669' 'flow_00.696']
#
# Step = 8430, Shock params: (-2.2054553877591663, 1.6, 36) applied to vehicle ['flow_00.691' 'flow_00.692' 'flow_00.669' 'flow_00.696']
#
# Step = 8431, Shock params: (-2.2054553877591663, 1.6, 36) applied to vehicle ['flow_00.691' 'flow_00.692' 'flow_00.669' 'flow_00.696']
#
# Step = 8432, Shock params: (-2.2054553877591663, 1.6, 36) applied to vehicle ['flow_00.691' 'flow_00.692' 'flow_00.669' 'flow_00.696']
#
# Step = 8433, Shock params: (-2.2054553877591663, 1.6, 36) applied to vehicle ['flow_00.691' 'flow_00.692' 'flow_00.669' 'flow_00.696']
#
# Step = 8434, Shock params: (-2.2054553877591663, 1.6, 36) applied to vehicle ['flow_00.691' 'flow_00.692' 'flow_00.669' 'flow_00.696']
#
# Step = 8435, Shock params: (-2.2054553877591663, 1.6, 36) applied to vehicle ['flow_00.691' 'flow_00.692' 'flow_00.669' 'flow_00.696']
#
# Step = 8436, Shock params: (-2.2054553877591663, 1.6, 36) applied to vehicle ['flow_00.691' 'flow_00.692' 'flow_00.669' 'flow_00.696']
#
# Step = 8437, Shock params: (-2.2054553877591663, 1.6, 36) applied to vehicle ['flow_00.691' 'flow_00.692' 'flow_00.669' 'flow_00.696']
#
# Step = 8438, Shock params: (-2.2054553877591663, 1.6, 36) applied to vehicle ['flow_00.691' 'flow_00.692' 'flow_00.669' 'flow_00.696']
#
# Step = 8439, Shock params: (-2.2054553877591663, 1.6, 36) applied to vehicle ['flow_00.691' 'flow_00.692' 'flow_00.669' 'flow_00.696']
#
# Step = 8440, Shock params: (-2.2054553877591663, 1.6, 36) applied to vehicle ['flow_00.691' 'flow_00.692' 'flow_00.669' 'flow_00.696']
#
#
#
# Shock ids: ['flow_00.618' 'flow_00.671' 'flow_00.732' 'flow_00.758']
#
#
# Step = 8527, Shock params: (-1.8469795477810802, 1.0, 36) applied to vehicle ['flow_00.618' 'flow_00.671' 'flow_00.732' 'flow_00.758']
#
# Step = 8528, Shock params: (-1.8469795477810802, 1.0, 36) applied to vehicle ['flow_00.618' 'flow_00.671' 'flow_00.732' 'flow_00.758']
#
# Step = 8529, Shock params: (-1.8469795477810802, 1.0, 36) applied to vehicle ['flow_00.618' 'flow_00.671' 'flow_00.732' 'flow_00.758']
#
# Step = 8530, Shock params: (-1.8469795477810802, 1.0, 36) applied to vehicle ['flow_00.618' 'flow_00.671' 'flow_00.732' 'flow_00.758']
#
# Step = 8531, Shock params: (-1.8469795477810802, 1.0, 36) applied to vehicle ['flow_00.618' 'flow_00.671' 'flow_00.732' 'flow_00.758']
#
# Step = 8532, Shock params: (-1.8469795477810802, 1.0, 36) applied to vehicle ['flow_00.618' 'flow_00.671' 'flow_00.732' 'flow_00.758']
#
# Step = 8533, Shock params: (-1.8469795477810802, 1.0, 36) applied to vehicle ['flow_00.618' 'flow_00.671' 'flow_00.732' 'flow_00.758']
#
# Step = 8534, Shock params: (-1.8469795477810802, 1.0, 36) applied to vehicle ['flow_00.618' 'flow_00.671' 'flow_00.732' 'flow_00.758']
# Step = 8535, Shock params: (-1.8469795477810802, 1.0, 36) applied to vehicle ['flow_00.618' 'flow_00.671' 'flow_00.732' 'flow_00.758']
#
# Step = 8536, Shock params: (-1.8469795477810802, 1.0, 36) applied to vehicle ['flow_00.618' 'flow_00.671' 'flow_00.732' 'flow_00.758']
#
# Step = 8537, Shock params: (-1.8469795477810802, 1.0, 36) applied to vehicle ['flow_00.618' 'flow_00.671' 'flow_00.732' 'flow_00.758']
#
#
#
# Shock ids: ['flow_00.802' 'flow_00.830' 'flow_00.787' 'flow_00.701']
#
#
# Step = 8630, Shock params: (-2.3632600363509875, 1.0, 36) applied to vehicle ['flow_00.802' 'flow_00.830' 'flow_00.787' 'flow_00.701']
#
# Step = 8631, Shock params: (-2.3632600363509875, 1.0, 36) applied to vehicle ['flow_00.802' 'flow_00.830' 'flow_00.787' 'flow_00.701']
#
# Step = 8632, Shock params: (-2.3632600363509875, 1.0, 36) applied to vehicle ['flow_00.802' 'flow_00.830' 'flow_00.787' 'flow_00.701']
#
# Step = 8633, Shock params: (-2.3632600363509875, 1.0, 36) applied to vehicle ['flow_00.802' 'flow_00.830' 'flow_00.787' 'flow_00.701']
#
# Step = 8634, Shock params: (-2.3632600363509875, 1.0, 36) applied to vehicle ['flow_00.802' 'flow_00.830' 'flow_00.787' 'flow_00.701']
#
# Step = 8635, Shock params: (-2.3632600363509875, 1.0, 36) applied to vehicle ['flow_00.802' 'flow_00.830' 'flow_00.787' 'flow_00.701']
#
# Step = 8636, Shock params: (-2.3632600363509875, 1.0, 36) applied to vehicle ['flow_00.802' 'flow_00.830' 'flow_00.787' 'flow_00.701']
#
# Step = 8637, Shock params: (-2.3632600363509875, 1.0, 36) applied to vehicle ['flow_00.802' 'flow_00.830' 'flow_00.787' 'flow_00.701']
#
# Step = 8638, Shock params: (-2.3632600363509875, 1.0, 36) applied to vehicle ['flow_00.802' 'flow_00.830' 'flow_00.787' 'flow_00.701']
#
# Step = 8639, Shock params: (-2.3632600363509875, 1.0, 36) applied to vehicle ['flow_00.802' 'flow_00.830' 'flow_00.787' 'flow_00.701']
#
# Step = 8640, Shock params: (-2.3632600363509875, 1.0, 36) applied to vehicle ['flow_00.802' 'flow_00.830' 'flow_00.787' 'flow_00.701']
#
#
#
# Shock ids: ['flow_00.836' 'flow_00.828' 'flow_00.803' 'flow_00.702']
#
#
# Step = 8733, Shock params: (-2.329401161811961, 0.5, 36) applied to vehicle ['flow_00.836' 'flow_00.828' 'flow_00.803' 'flow_00.702']
#
# Step = 8734, Shock params: (-2.329401161811961, 0.5, 36) applied to vehicle ['flow_00.836' 'flow_00.828' 'flow_00.803' 'flow_00.702']
#
# Step = 8735, Shock params: (-2.329401161811961, 0.5, 36) applied to vehicle ['flow_00.836' 'flow_00.828' 'flow_00.803' 'flow_00.702']
#
# Step = 8736, Shock params: (-2.329401161811961, 0.5, 36) applied to vehicle ['flow_00.836' 'flow_00.828' 'flow_00.803' 'flow_00.702']
#
# Step = 8737, Shock params: (-2.329401161811961, 0.5, 36) applied to vehicle ['flow_00.836' 'flow_00.828' 'flow_00.803' 'flow_00.702']
#
#
#
# Shock ids: ['flow_00.848' 'flow_00.716' 'flow_00.577' 'flow_00.719']
#
#
# Step = 8835, Shock params: (-2.701181615275299, 2.1, 36) applied to vehicle ['flow_00.848' 'flow_00.716' 'flow_00.577' 'flow_00.719']
#
# Step = 8836, Shock params: (-2.701181615275299, 2.1, 36) applied to vehicle ['flow_00.848' 'flow_00.716' 'flow_00.577' 'flow_00.719']
#
# Step = 8837, Shock params: (-2.701181615275299, 2.1, 36) applied to vehicle ['flow_00.848' 'flow_00.716' 'flow_00.577' 'flow_00.719']
#
# Step = 8838, Shock params: (-2.701181615275299, 2.1, 36) applied to vehicle ['flow_00.848' 'flow_00.716' 'flow_00.577' 'flow_00.719']
#
# Step = 8839, Shock params: (-2.701181615275299, 2.1, 36) applied to vehicle ['flow_00.848' 'flow_00.716' 'flow_00.577' 'flow_00.719']
#
# Step = 8840, Shock params: (-2.701181615275299, 2.1, 36) applied to vehicle ['flow_00.848' 'flow_00.716' 'flow_00.577' 'flow_00.719']
#
# Step = 8841, Shock params: (-2.701181615275299, 2.1, 36) applied to vehicle ['flow_00.848' 'flow_00.716' 'flow_00.577' 'flow_00.719']
#
# Step = 8842, Shock params: (-2.701181615275299, 2.1, 36) applied to vehicle ['flow_00.848' 'flow_00.716' 'flow_00.577' 'flow_00.719']
#
# Step = 8843, Shock params: (-2.701181615275299, 2.1, 36) applied to vehicle ['flow_00.848' 'flow_00.716' 'flow_00.577' 'flow_00.719']
#
# Step = 8844, Shock params: (-2.701181615275299, 2.1, 36) applied to vehicle ['flow_00.848' 'flow_00.716' 'flow_00.577' 'flow_00.719']
#
# Step = 8845, Shock params: (-2.701181615275299, 2.1, 36) applied to vehicle ['flow_00.848' 'flow_00.716' 'flow_00.577' 'flow_00.719']
#
# Step = 8846, Shock params: (-2.701181615275299, 2.1, 36) applied to vehicle ['flow_00.848' 'flow_00.716' 'flow_00.577' 'flow_00.719']
#
# Step = 8847, Shock params: (-2.701181615275299, 2.1, 36) applied to vehicle ['flow_00.848' 'flow_00.716' 'flow_00.577' 'flow_00.719']
#
# Step = 8848, Shock params: (-2.701181615275299, 2.1, 36) applied to vehicle ['flow_00.848' 'flow_00.716' 'flow_00.577' 'flow_00.719']
#
# Step = 8849, Shock params: (-2.701181615275299, 2.1, 36) applied to vehicle ['flow_00.848' 'flow_00.716' 'flow_00.577' 'flow_00.719']
#
# Step = 8850, Shock params: (-2.701181615275299, 2.1, 36) applied to vehicle ['flow_00.848' 'flow_00.716' 'flow_00.577' 'flow_00.719']
#
# Step = 8851, Shock params: (-2.701181615275299, 2.1, 36) applied to vehicle ['flow_00.848' 'flow_00.716' 'flow_00.577' 'flow_00.719']
#
# Step = 8852, Shock params: (-2.701181615275299, 2.1, 36) applied to vehicle ['flow_00.848' 'flow_00.716' 'flow_00.577' 'flow_00.719']
#
# Step = 8853, Shock params: (-2.701181615275299, 2.1, 36) applied to vehicle ['flow_00.848' 'flow_00.716' 'flow_00.577' 'flow_00.719']
#
# Step = 8854, Shock params: (-2.701181615275299, 2.1, 36) applied to vehicle ['flow_00.848' 'flow_00.716' 'flow_00.577' 'flow_00.719']
#
# Step = 8855, Shock params: (-2.701181615275299, 2.1, 36) applied to vehicle ['flow_00.848' 'flow_00.716' 'flow_00.577' 'flow_00.719']
#
#
#
# Shock ids: ['flow_00.722' 'flow_00.813' 'flow_00.808' 'flow_00.858']
#
#
# Step = 8938, Shock params: (-1.5792750768277148, 0.7, 36) applied to vehicle ['flow_00.722' 'flow_00.813' 'flow_00.808' 'flow_00.858']
#
# Step = 8939, Shock params: (-1.5792750768277148, 0.7, 36) applied to vehicle ['flow_00.722' 'flow_00.813' 'flow_00.808' 'flow_00.858']
#
# Step = 8940, Shock params: (-1.5792750768277148, 0.7, 36) applied to vehicle ['flow_00.722' 'flow_00.813' 'flow_00.808' 'flow_00.858']
#
# Step = 8941, Shock params: (-1.5792750768277148, 0.7, 36) applied to vehicle ['flow_00.722' 'flow_00.813' 'flow_00.808' 'flow_00.858']
#
# Step = 8942, Shock params: (-1.5792750768277148, 0.7, 36) applied to vehicle ['flow_00.722' 'flow_00.813' 'flow_00.808' 'flow_00.858']
#
# Step = 8943, Shock params: (-1.5792750768277148, 0.7, 36) applied to vehicle ['flow_00.722' 'flow_00.813' 'flow_00.808' 'flow_00.858']
#
# Step = 8944, Shock params: (-1.5792750768277148, 0.7, 36) applied to vehicle ['flow_00.722' 'flow_00.813' 'flow_00.808' 'flow_00.858']
#
#
#
# Shock ids: ['flow_00.738' 'flow_00.728' 'flow_00.863' 'flow_00.737']
#
#
# Step = 9040, Shock params: (-1.6607348770561015, 1.6, 36) applied to vehicle ['flow_00.738' 'flow_00.728' 'flow_00.863' 'flow_00.737']
#
# Step = 9041, Shock params: (-1.6607348770561015, 1.6, 36) applied to vehicle ['flow_00.738' 'flow_00.728' 'flow_00.863' 'flow_00.737']
#
# Step = 9042, Shock params: (-1.6607348770561015, 1.6, 36) applied to vehicle ['flow_00.738' 'flow_00.728' 'flow_00.863' 'flow_00.737']
#
# Step = 9043, Shock params: (-1.6607348770561015, 1.6, 36) applied to vehicle ['flow_00.738' 'flow_00.728' 'flow_00.863' 'flow_00.737']
#
# Step = 9044, Shock params: (-1.6607348770561015, 1.6, 36) applied to vehicle ['flow_00.738' 'flow_00.728' 'flow_00.863' 'flow_00.737']
#
# Step = 9045, Shock params: (-1.6607348770561015, 1.6, 36) applied to vehicle ['flow_00.738' 'flow_00.728' 'flow_00.863' 'flow_00.737']
#
# Step = 9046, Shock params: (-1.6607348770561015, 1.6, 36) applied to vehicle ['flow_00.738' 'flow_00.728' 'flow_00.863' 'flow_00.737']
#
# Step = 9047, Shock params: (-1.6607348770561015, 1.6, 36) applied to vehicle ['flow_00.738' 'flow_00.728' 'flow_00.863' 'flow_00.737']
#
# Step = 9048, Shock params: (-1.6607348770561015, 1.6, 36) applied to vehicle ['flow_00.738' 'flow_00.728' 'flow_00.863' 'flow_00.737']
#
# Step = 9049, Shock params: (-1.6607348770561015, 1.6, 36) applied to vehicle ['flow_00.738' 'flow_00.728' 'flow_00.863' 'flow_00.737']
#
# Step = 9050, Shock params: (-1.6607348770561015, 1.6, 36) applied to vehicle ['flow_00.738' 'flow_00.728' 'flow_00.863' 'flow_00.737']
# Step = 9051, Shock params: (-1.6607348770561015, 1.6, 36) applied to vehicle ['flow_00.738' 'flow_00.728' 'flow_00.863' 'flow_00.737']
#
# Step = 9052, Shock params: (-1.6607348770561015, 1.6, 36) applied to vehicle ['flow_00.738' 'flow_00.728' 'flow_00.863' 'flow_00.737']
#
# Step = 9053, Shock params: (-1.6607348770561015, 1.6, 36) applied to vehicle ['flow_00.738' 'flow_00.728' 'flow_00.863' 'flow_00.737']
#
# Step = 9054, Shock params: (-1.6607348770561015, 1.6, 36) applied to vehicle ['flow_00.738' 'flow_00.728' 'flow_00.863' 'flow_00.737']
#
# Step = 9055, Shock params: (-1.6607348770561015, 1.6, 36) applied to vehicle ['flow_00.738' 'flow_00.728' 'flow_00.863' 'flow_00.737']
#
#
#
# Shock ids: ['flow_00.882' 'flow_00.749' 'flow_00.756' 'flow_00.751']
#
#
# Step = 9143, Shock params: (-1.9505493502209674, 1.6, 36) applied to vehicle ['flow_00.882' 'flow_00.749' 'flow_00.756' 'flow_00.751']
#
# Step = 9144, Shock params: (-1.9505493502209674, 1.6, 36) applied to vehicle ['flow_00.882' 'flow_00.749' 'flow_00.756' 'flow_00.751']
#
# Step = 9145, Shock params: (-1.9505493502209674, 1.6, 36) applied to vehicle ['flow_00.882' 'flow_00.749' 'flow_00.756' 'flow_00.751']
#
# Step = 9146, Shock params: (-1.9505493502209674, 1.6, 36) applied to vehicle ['flow_00.882' 'flow_00.749' 'flow_00.756' 'flow_00.751']
#
# Step = 9147, Shock params: (-1.9505493502209674, 1.6, 36) applied to vehicle ['flow_00.882' 'flow_00.749' 'flow_00.756' 'flow_00.751']
#
# Step = 9148, Shock params: (-1.9505493502209674, 1.6, 36) applied to vehicle ['flow_00.882' 'flow_00.749' 'flow_00.756' 'flow_00.751']
#
# Step = 9149, Shock params: (-1.9505493502209674, 1.6, 36) applied to vehicle ['flow_00.882' 'flow_00.749' 'flow_00.756' 'flow_00.751']
#
# Step = 9150, Shock params: (-1.9505493502209674, 1.6, 36) applied to vehicle ['flow_00.882' 'flow_00.749' 'flow_00.756' 'flow_00.751']
#
# Step = 9151, Shock params: (-1.9505493502209674, 1.6, 36) applied to vehicle ['flow_00.882' 'flow_00.749' 'flow_00.756' 'flow_00.751']
#
# Step = 9152, Shock params: (-1.9505493502209674, 1.6, 36) applied to vehicle ['flow_00.882' 'flow_00.749' 'flow_00.756' 'flow_00.751']
#
# Step = 9153, Shock params: (-1.9505493502209674, 1.6, 36) applied to vehicle ['flow_00.882' 'flow_00.749' 'flow_00.756' 'flow_00.751']
#
# Step = 9154, Shock params: (-1.9505493502209674, 1.6, 36) applied to vehicle ['flow_00.882' 'flow_00.749' 'flow_00.756' 'flow_00.751']
#
# Step = 9155, Shock params: (-1.9505493502209674, 1.6, 36) applied to vehicle ['flow_00.882' 'flow_00.749' 'flow_00.756' 'flow_00.751']
#
# Step = 9156, Shock params: (-1.9505493502209674, 1.6, 36) applied to vehicle ['flow_00.882' 'flow_00.749' 'flow_00.756' 'flow_00.751']
#
# Step = 9157, Shock params: (-1.9505493502209674, 1.6, 36) applied to vehicle ['flow_00.882' 'flow_00.749' 'flow_00.756' 'flow_00.751']
#
# Step = 9158, Shock params: (-1.9505493502209674, 1.6, 36) applied to vehicle ['flow_00.882' 'flow_00.749' 'flow_00.756' 'flow_00.751']
#
#
#
# Shock ids: ['flow_00.848' 'flow_00.793' 'flow_00.779' 'flow_00.771']
#
#
# Step = 9245, Shock params: (-2.6344414924191373, 1.5, 36) applied to vehicle ['flow_00.848' 'flow_00.793' 'flow_00.779' 'flow_00.771']
#
# Step = 9246, Shock params: (-2.6344414924191373, 1.5, 36) applied to vehicle ['flow_00.848' 'flow_00.793' 'flow_00.779' 'flow_00.771']
#
# Step = 9247, Shock params: (-2.6344414924191373, 1.5, 36) applied to vehicle ['flow_00.848' 'flow_00.793' 'flow_00.779' 'flow_00.771']
#
# Step = 9248, Shock params: (-2.6344414924191373, 1.5, 36) applied to vehicle ['flow_00.848' 'flow_00.793' 'flow_00.779' 'flow_00.771']
#
# Step = 9249, Shock params: (-2.6344414924191373, 1.5, 36) applied to vehicle ['flow_00.848' 'flow_00.793' 'flow_00.779' 'flow_00.771']
#
# Step = 9250, Shock params: (-2.6344414924191373, 1.5, 36) applied to vehicle ['flow_00.848' 'flow_00.793' 'flow_00.779' 'flow_00.771']
#
# Step = 9251, Shock params: (-2.6344414924191373, 1.5, 36) applied to vehicle ['flow_00.848' 'flow_00.793' 'flow_00.779' 'flow_00.771']
#
# Step = 9252, Shock params: (-2.6344414924191373, 1.5, 36) applied to vehicle ['flow_00.848' 'flow_00.793' 'flow_00.779' 'flow_00.771']
#
# Step = 9253, Shock params: (-2.6344414924191373, 1.5, 36) applied to vehicle ['flow_00.848' 'flow_00.793' 'flow_00.779' 'flow_00.771']
#
# Step = 9254, Shock params: (-2.6344414924191373, 1.5, 36) applied to vehicle ['flow_00.848' 'flow_00.793' 'flow_00.779' 'flow_00.771']
#
# Step = 9255, Shock params: (-2.6344414924191373, 1.5, 36) applied to vehicle ['flow_00.848' 'flow_00.793' 'flow_00.779' 'flow_00.771']
#
# Step = 9256, Shock params: (-2.6344414924191373, 1.5, 36) applied to vehicle ['flow_00.848' 'flow_00.793' 'flow_00.779' 'flow_00.771']
#
# Step = 9257, Shock params: (-2.6344414924191373, 1.5, 36) applied to vehicle ['flow_00.848' 'flow_00.793' 'flow_00.779' 'flow_00.771']
#
# Step = 9258, Shock params: (-2.6344414924191373, 1.5, 36) applied to vehicle ['flow_00.848' 'flow_00.793' 'flow_00.779' 'flow_00.771']
#
# Step = 9259, Shock params: (-2.6344414924191373, 1.5, 36) applied to vehicle ['flow_00.848' 'flow_00.793' 'flow_00.779' 'flow_00.771']
#
#
#
# Shock ids: ['flow_00.901' 'flow_00.846' 'flow_00.800' 'flow_00.901']
#
#
# Step = 9348, Shock params: (-2.7785639541070526, 1.0, 36) applied to vehicle ['flow_00.901' 'flow_00.846' 'flow_00.800' 'flow_00.901']
#
# Step = 9349, Shock params: (-2.7785639541070526, 1.0, 36) applied to vehicle ['flow_00.901' 'flow_00.846' 'flow_00.800' 'flow_00.901']
#
# Step = 9350, Shock params: (-2.7785639541070526, 1.0, 36) applied to vehicle ['flow_00.901' 'flow_00.846' 'flow_00.800' 'flow_00.901']
#
# Step = 9351, Shock params: (-2.7785639541070526, 1.0, 36) applied to vehicle ['flow_00.901' 'flow_00.846' 'flow_00.800' 'flow_00.901']
#
# Step = 9352, Shock params: (-2.7785639541070526, 1.0, 36) applied to vehicle ['flow_00.901' 'flow_00.846' 'flow_00.800' 'flow_00.901']
#
# Step = 9353, Shock params: (-2.7785639541070526, 1.0, 36) applied to vehicle ['flow_00.901' 'flow_00.846' 'flow_00.800' 'flow_00.901']
#
# Step = 9354, Shock params: (-2.7785639541070526, 1.0, 36) applied to vehicle ['flow_00.901' 'flow_00.846' 'flow_00.800' 'flow_00.901']
#
# Step = 9355, Shock params: (-2.7785639541070526, 1.0, 36) applied to vehicle ['flow_00.901' 'flow_00.846' 'flow_00.800' 'flow_00.901']
#
# Step = 9356, Shock params: (-2.7785639541070526, 1.0, 36) applied to vehicle ['flow_00.901' 'flow_00.846' 'flow_00.800' 'flow_00.901']
#
# Step = 9357, Shock params: (-2.7785639541070526, 1.0, 36) applied to vehicle ['flow_00.901' 'flow_00.846' 'flow_00.800' 'flow_00.901']
#
# Step = 9358, Shock params: (-2.7785639541070526, 1.0, 36) applied to vehicle ['flow_00.901' 'flow_00.846' 'flow_00.800' 'flow_00.901']
#
#
#
# Shock ids: ['flow_00.863' 'flow_00.906' 'flow_00.869' 'flow_00.874']
#
#
# Step = 9450, Shock params: (-2.726625332930282, 2.4, 36) applied to vehicle ['flow_00.863' 'flow_00.906' 'flow_00.869' 'flow_00.874']
#
# Step = 9451, Shock params: (-2.726625332930282, 2.4, 36) applied to vehicle ['flow_00.863' 'flow_00.906' 'flow_00.869' 'flow_00.874']
#
# Step = 9452, Shock params: (-2.726625332930282, 2.4, 36) applied to vehicle ['flow_00.863' 'flow_00.906' 'flow_00.869' 'flow_00.874']
#
# Step = 9453, Shock params: (-2.726625332930282, 2.4, 36) applied to vehicle ['flow_00.863' 'flow_00.906' 'flow_00.869' 'flow_00.874']
#
# Step = 9454, Shock params: (-2.726625332930282, 2.4, 36) applied to vehicle ['flow_00.863' 'flow_00.906' 'flow_00.869' 'flow_00.874']
#
# Step = 9455, Shock params: (-2.726625332930282, 2.4, 36) applied to vehicle ['flow_00.863' 'flow_00.906' 'flow_00.869' 'flow_00.874']
#
# Step = 9456, Shock params: (-2.726625332930282, 2.4, 36) applied to vehicle ['flow_00.863' 'flow_00.906' 'flow_00.869' 'flow_00.874']
#
# Step = 9457, Shock params: (-2.726625332930282, 2.4, 36) applied to vehicle ['flow_00.863' 'flow_00.906' 'flow_00.869' 'flow_00.874']
#
# Step = 9458, Shock params: (-2.726625332930282, 2.4, 36) applied to vehicle ['flow_00.863' 'flow_00.906' 'flow_00.869' 'flow_00.874']
#
# Step = 9459, Shock params: (-2.726625332930282, 2.4, 36) applied to vehicle ['flow_00.863' 'flow_00.906' 'flow_00.869' 'flow_00.874']
#
# Step = 9460, Shock params: (-2.726625332930282, 2.4, 36) applied to vehicle ['flow_00.863' 'flow_00.906' 'flow_00.869' 'flow_00.874']
#
# Step = 9461, Shock params: (-2.726625332930282, 2.4, 36) applied to vehicle ['flow_00.863' 'flow_00.906' 'flow_00.869' 'flow_00.874']
#
# Step = 9462, Shock params: (-2.726625332930282, 2.4, 36) applied to vehicle ['flow_00.863' 'flow_00.906' 'flow_00.869' 'flow_00.874']
# Step = 9463, Shock params: (-2.726625332930282, 2.4, 36) applied to vehicle ['flow_00.863' 'flow_00.906' 'flow_00.869' 'flow_00.874']
#
# Step = 9464, Shock params: (-2.726625332930282, 2.4, 36) applied to vehicle ['flow_00.863' 'flow_00.906' 'flow_00.869' 'flow_00.874']
#
# Step = 9465, Shock params: (-2.726625332930282, 2.4, 36) applied to vehicle ['flow_00.863' 'flow_00.906' 'flow_00.869' 'flow_00.874']
#
# Step = 9466, Shock params: (-2.726625332930282, 2.4, 36) applied to vehicle ['flow_00.863' 'flow_00.906' 'flow_00.869' 'flow_00.874']
#
# Step = 9467, Shock params: (-2.726625332930282, 2.4, 36) applied to vehicle ['flow_00.863' 'flow_00.906' 'flow_00.869' 'flow_00.874']
#
# Step = 9468, Shock params: (-2.726625332930282, 2.4, 36) applied to vehicle ['flow_00.863' 'flow_00.906' 'flow_00.869' 'flow_00.874']
#
# Step = 9469, Shock params: (-2.726625332930282, 2.4, 36) applied to vehicle ['flow_00.863' 'flow_00.906' 'flow_00.869' 'flow_00.874']
#
# Step = 9470, Shock params: (-2.726625332930282, 2.4, 36) applied to vehicle ['flow_00.863' 'flow_00.906' 'flow_00.869' 'flow_00.874']
#
# Step = 9471, Shock params: (-2.726625332930282, 2.4, 36) applied to vehicle ['flow_00.863' 'flow_00.906' 'flow_00.869' 'flow_00.874']
#
# Step = 9472, Shock params: (-2.726625332930282, 2.4, 36) applied to vehicle ['flow_00.863' 'flow_00.906' 'flow_00.869' 'flow_00.874']
#
# Step = 9473, Shock params: (-2.726625332930282, 2.4, 36) applied to vehicle ['flow_00.863' 'flow_00.906' 'flow_00.869' 'flow_00.874']
#
#
#
# Shock ids: ['flow_00.919' 'flow_00.911' 'flow_00.920' 'flow_00.775']
#
#
# Step = 9553, Shock params: (-1.3508157429900447, 0.9, 36) applied to vehicle ['flow_00.919' 'flow_00.911' 'flow_00.920' 'flow_00.775']
#
# Step = 9554, Shock params: (-1.3508157429900447, 0.9, 36) applied to vehicle ['flow_00.919' 'flow_00.911' 'flow_00.920' 'flow_00.775']
#
# Step = 9555, Shock params: (-1.3508157429900447, 0.9, 36) applied to vehicle ['flow_00.919' 'flow_00.911' 'flow_00.920' 'flow_00.775']
#
# Step = 9556, Shock params: (-1.3508157429900447, 0.9, 36) applied to vehicle ['flow_00.919' 'flow_00.911' 'flow_00.920' 'flow_00.775']
#
# Step = 9557, Shock params: (-1.3508157429900447, 0.9, 36) applied to vehicle ['flow_00.919' 'flow_00.911' 'flow_00.920' 'flow_00.775']
#
# Step = 9558, Shock params: (-1.3508157429900447, 0.9, 36) applied to vehicle ['flow_00.919' 'flow_00.911' 'flow_00.920' 'flow_00.775']
#
# Step = 9559, Shock params: (-1.3508157429900447, 0.9, 36) applied to vehicle ['flow_00.919' 'flow_00.911' 'flow_00.920' 'flow_00.775']
#
# Step = 9560, Shock params: (-1.3508157429900447, 0.9, 36) applied to vehicle ['flow_00.919' 'flow_00.911' 'flow_00.920' 'flow_00.775']
#
# Step = 9561, Shock params: (-1.3508157429900447, 0.9, 36) applied to vehicle ['flow_00.919' 'flow_00.911' 'flow_00.920' 'flow_00.775']
#
# Step = 9562, Shock params: (-1.3508157429900447, 0.9, 36) applied to vehicle ['flow_00.919' 'flow_00.911' 'flow_00.920' 'flow_00.775']
#
#
#
# Shock ids: ['flow_00.928' 'flow_00.925' 'flow_00.670' 'flow_00.929']
#
#
# Step = 9655, Shock params: (-1.3619523350862404, 1.1, 36) applied to vehicle ['flow_00.928' 'flow_00.925' 'flow_00.670' 'flow_00.929']
#
# Step = 9656, Shock params: (-1.3619523350862404, 1.1, 36) applied to vehicle ['flow_00.928' 'flow_00.925' 'flow_00.670' 'flow_00.929']
#
# Step = 9657, Shock params: (-1.3619523350862404, 1.1, 36) applied to vehicle ['flow_00.928' 'flow_00.925' 'flow_00.670' 'flow_00.929']
#
# Step = 9658, Shock params: (-1.3619523350862404, 1.1, 36) applied to vehicle ['flow_00.928' 'flow_00.925' 'flow_00.670' 'flow_00.929']
#
# Step = 9659, Shock params: (-1.3619523350862404, 1.1, 36) applied to vehicle ['flow_00.928' 'flow_00.925' 'flow_00.670' 'flow_00.929']
#
# Step = 9660, Shock params: (-1.3619523350862404, 1.1, 36) applied to vehicle ['flow_00.928' 'flow_00.925' 'flow_00.670' 'flow_00.929']
#
# Step = 9661, Shock params: (-1.3619523350862404, 1.1, 36) applied to vehicle ['flow_00.928' 'flow_00.925' 'flow_00.670' 'flow_00.929']
#
# Step = 9662, Shock params: (-1.3619523350862404, 1.1, 36) applied to vehicle ['flow_00.928' 'flow_00.925' 'flow_00.670' 'flow_00.929']
#
# Step = 9663, Shock params: (-1.3619523350862404, 1.1, 36) applied to vehicle ['flow_00.928' 'flow_00.925' 'flow_00.670' 'flow_00.929']
#
# Step = 9664, Shock params: (-1.3619523350862404, 1.1, 36) applied to vehicle ['flow_00.928' 'flow_00.925' 'flow_00.670' 'flow_00.929']
#
# Step = 9665, Shock params: (-1.3619523350862404, 1.1, 36) applied to vehicle ['flow_00.928' 'flow_00.925' 'flow_00.670' 'flow_00.929']
#
# Step = 9666, Shock params: (-1.3619523350862404, 1.1, 36) applied to vehicle ['flow_00.928' 'flow_00.925' 'flow_00.670' 'flow_00.929']
#
#
#
# Shock ids: ['flow_00.717' 'flow_00.806' 'flow_00.705' 'flow_00.682']
#
#
# Step = 9758, Shock params: (-2.2387170708466915, 1.7, 36) applied to vehicle ['flow_00.717' 'flow_00.806' 'flow_00.705' 'flow_00.682']
#
# Step = 9759, Shock params: (-2.2387170708466915, 1.7, 36) applied to vehicle ['flow_00.717' 'flow_00.806' 'flow_00.705' 'flow_00.682']
#
# Step = 9760, Shock params: (-2.2387170708466915, 1.7, 36) applied to vehicle ['flow_00.717' 'flow_00.806' 'flow_00.705' 'flow_00.682']
#
# Step = 9761, Shock params: (-2.2387170708466915, 1.7, 36) applied to vehicle ['flow_00.717' 'flow_00.806' 'flow_00.705' 'flow_00.682']
#
# Step = 9762, Shock params: (-2.2387170708466915, 1.7, 36) applied to vehicle ['flow_00.717' 'flow_00.806' 'flow_00.705' 'flow_00.682']
#
# Step = 9763, Shock params: (-2.2387170708466915, 1.7, 36) applied to vehicle ['flow_00.717' 'flow_00.806' 'flow_00.705' 'flow_00.682']
#
# Step = 9764, Shock params: (-2.2387170708466915, 1.7, 36) applied to vehicle ['flow_00.717' 'flow_00.806' 'flow_00.705' 'flow_00.682']
#
# Step = 9765, Shock params: (-2.2387170708466915, 1.7, 36) applied to vehicle ['flow_00.717' 'flow_00.806' 'flow_00.705' 'flow_00.682']
#
# Step = 9766, Shock params: (-2.2387170708466915, 1.7, 36) applied to vehicle ['flow_00.717' 'flow_00.806' 'flow_00.705' 'flow_00.682']
#
# Step = 9767, Shock params: (-2.2387170708466915, 1.7, 36) applied to vehicle ['flow_00.717' 'flow_00.806' 'flow_00.705' 'flow_00.682']
#
# Step = 9768, Shock params: (-2.2387170708466915, 1.7, 36) applied to vehicle ['flow_00.717' 'flow_00.806' 'flow_00.705' 'flow_00.682']
#
# Step = 9769, Shock params: (-2.2387170708466915, 1.7, 36) applied to vehicle ['flow_00.717' 'flow_00.806' 'flow_00.705' 'flow_00.682']
#
# Step = 9770, Shock params: (-2.2387170708466915, 1.7, 36) applied to vehicle ['flow_00.717' 'flow_00.806' 'flow_00.705' 'flow_00.682']
#
# ...
#
# Step = 10678, Shock params: (-2.5972018041019798, 1.1, 57) applied to vehicle ['flow_00.866' 'flow_00.862' 'flow_00.867' 'flow_00.1029']
#
# Step = 10679, Shock params: (-2.5972018041019798, 1.1, 57) applied to vehicle ['flow_00.866' 'flow_00.862' 'flow_00.867' 'flow_00.1029']
#
# Step = 10680, Shock params: (-2.5972018041019798, 1.1, 57) applied to vehicle ['flow_00.866' 'flow_00.862' 'flow_00.867' 'flow_00.1029']
#
# Step = 10681, Shock params: (-2.5972018041019798, 1.1, 57) applied to vehicle ['flow_00.866' 'flow_00.862' 'flow_00.867' 'flow_00.1029']
#
#
#
# Shock ids: ['flow_00.896' 'flow_00.896' 'flow_00.932' 'flow_00.907']
#
#
# Step = 10734, Shock params: (-1.355509457933945, 1.6, 57) applied to vehicle ['flow_00.896' 'flow_00.896' 'flow_00.932' 'flow_00.907']
#
# Step = 10735, Shock params: (-1.355509457933945, 1.6, 57) applied to vehicle ['flow_00.896' 'flow_00.896' 'flow_00.932' 'flow_00.907']
#
# Step = 10736, Shock params: (-1.355509457933945, 1.6, 57) applied to vehicle ['flow_00.896' 'flow_00.896' 'flow_00.932' 'flow_00.907']
#
# Step = 10737, Shock params: (-1.355509457933945, 1.6, 57) applied to vehicle ['flow_00.896' 'flow_00.896' 'flow_00.932' 'flow_00.907']
#
# Step = 10738, Shock params: (-1.355509457933945, 1.6, 57) applied to vehicle ['flow_00.896' 'flow_00.896' 'flow_00.932' 'flow_00.907']
#
# Step = 10739, Shock params: (-1.355509457933945, 1.6, 57) applied to vehicle ['flow_00.896' 'flow_00.896' 'flow_00.932' 'flow_00.907']
#
# Step = 10740, Shock params: (-1.355509457933945, 1.6, 57) applied to vehicle ['flow_00.896' 'flow_00.896' 'flow_00.932' 'flow_00.907']
#
# Step = 10741, Shock params: (-1.355509457933945, 1.6, 57) applied to vehicle ['flow_00.896' 'flow_00.896' 'flow_00.932' 'flow_00.907']
#
# Step = 10742, Shock params: (-1.355509457933945, 1.6, 57) applied to vehicle ['flow_00.896' 'flow_00.896' 'flow_00.932' 'flow_00.907']
#
# Step = 10743, Shock params: (-1.355509457933945, 1.6, 57) applied to vehicle ['flow_00.896' 'flow_00.896' 'flow_00.932' 'flow_00.907']
#
# Step = 10744, Shock params: (-1.355509457933945, 1.6, 57) applied to vehicle ['flow_00.896' 'flow_00.896' 'flow_00.932' 'flow_00.907']
#
# Step = 10745, Shock params: (-1.355509457933945, 1.6, 57) applied to vehicle ['flow_00.896' 'flow_00.896' 'flow_00.932' 'flow_00.907']
#
# Step = 10746, Shock params: (-1.355509457933945, 1.6, 57) applied to vehicle ['flow_00.896' 'flow_00.896' 'flow_00.932' 'flow_00.907']
#
# Step = 10747, Shock params: (-1.355509457933945, 1.6, 57) applied to vehicle ['flow_00.896' 'flow_00.896' 'flow_00.932' 'flow_00.907']
#
# Step = 10748, Shock params: (-1.355509457933945, 1.6, 57) applied to vehicle ['flow_00.896' 'flow_00.896' 'flow_00.932' 'flow_00.907']
#
# Step = 10749, Shock params: (-1.355509457933945, 1.6, 57) applied to vehicle ['flow_00.896' 'flow_00.896' 'flow_00.932' 'flow_00.907']
# Shock ids: ['flow_00.829' 'flow_00.946' 'flow_00.845' 'flow_00.941']
#
#
# Step = 10798, Shock params: (-2.817136950266214, 2.0, 57) applied to vehicle ['flow_00.829' 'flow_00.946' 'flow_00.845' 'flow_00.941']
#
# Step = 10799, Shock params: (-2.817136950266214, 2.0, 57) applied to vehicle ['flow_00.829' 'flow_00.946' 'flow_00.845' 'flow_00.941']
#
# Step = 10800, Shock params: (-2.817136950266214, 2.0, 57) applied to vehicle ['flow_00.829' 'flow_00.946' 'flow_00.845' 'flow_00.941']
#
# Step = 10801, Shock params: (-2.817136950266214, 2.0, 57) applied to vehicle ['flow_00.829' 'flow_00.946' 'flow_00.845' 'flow_00.941']
#
# Step = 10802, Shock params: (-2.817136950266214, 2.0, 57) applied to vehicle ['flow_00.829' 'flow_00.946' 'flow_00.845' 'flow_00.941']
#
# Step = 10803, Shock params: (-2.817136950266214, 2.0, 57) applied to vehicle ['flow_00.829' 'flow_00.946' 'flow_00.845' 'flow_00.941']
#
# Step = 10804, Shock params: (-2.817136950266214, 2.0, 57) applied to vehicle ['flow_00.829' 'flow_00.946' 'flow_00.845' 'flow_00.941']
#
# Step = 10805, Shock params: (-2.817136950266214, 2.0, 57) applied to vehicle ['flow_00.829' 'flow_00.946' 'flow_00.845' 'flow_00.941']
#
# Step = 10806, Shock params: (-2.817136950266214, 2.0, 57) applied to vehicle ['flow_00.829' 'flow_00.946' 'flow_00.845' 'flow_00.941']
#
# Step = 10807, Shock params: (-2.817136950266214, 2.0, 57) applied to vehicle ['flow_00.829' 'flow_00.946' 'flow_00.845' 'flow_00.941']
#
# Step = 10808, Shock params: (-2.817136950266214, 2.0, 57) applied to vehicle ['flow_00.829' 'flow_00.946' 'flow_00.845' 'flow_00.941']
#
# Step = 10809, Shock params: (-2.817136950266214, 2.0, 57) applied to vehicle ['flow_00.829' 'flow_00.946' 'flow_00.845' 'flow_00.941']
#
# Step = 10810, Shock params: (-2.817136950266214, 2.0, 57) applied to vehicle ['flow_00.829' 'flow_00.946' 'flow_00.845' 'flow_00.941']
#
# Step = 10811, Shock params: (-2.817136950266214, 2.0, 57) applied to vehicle ['flow_00.829' 'flow_00.946' 'flow_00.845' 'flow_00.941']
#
# Step = 10812, Shock params: (-2.817136950266214, 2.0, 57) applied to vehicle ['flow_00.829' 'flow_00.946' 'flow_00.845' 'flow_00.941']
#
# Step = 10813, Shock params: (-2.817136950266214, 2.0, 57) applied to vehicle ['flow_00.829' 'flow_00.946' 'flow_00.845' 'flow_00.941']
#
# Step = 10814, Shock params: (-2.817136950266214, 2.0, 57) applied to vehicle ['flow_00.829' 'flow_00.946' 'flow_00.845' 'flow_00.941']
#
# Step = 10815, Shock params: (-2.817136950266214, 2.0, 57) applied to vehicle ['flow_00.829' 'flow_00.946' 'flow_00.845' 'flow_00.941']
#
# Step = 10816, Shock params: (-2.817136950266214, 2.0, 57) applied to vehicle ['flow_00.829' 'flow_00.946' 'flow_00.845' 'flow_00.941']
#
# Step = 10817, Shock params: (-2.817136950266214, 2.0, 57) applied to vehicle ['flow_00.829' 'flow_00.946' 'flow_00.845' 'flow_00.941']
#
#
#
# Shock ids: ['flow_00.969' 'flow_00.959' 'flow_00.950' 'flow_00.975']
#
#
# Step = 10862, Shock params: (-1.146022469323508, 1.4, 57) applied to vehicle ['flow_00.969' 'flow_00.959' 'flow_00.950' 'flow_00.975']
#
# Step = 10863, Shock params: (-1.146022469323508, 1.4, 57) applied to vehicle ['flow_00.969' 'flow_00.959' 'flow_00.950' 'flow_00.975']
#
# Step = 10864, Shock params: (-1.146022469323508, 1.4, 57) applied to vehicle ['flow_00.969' 'flow_00.959' 'flow_00.950' 'flow_00.975']
#
# Step = 10865, Shock params: (-1.146022469323508, 1.4, 57) applied to vehicle ['flow_00.969' 'flow_00.959' 'flow_00.950' 'flow_00.975']
#
# Step = 10866, Shock params: (-1.146022469323508, 1.4, 57) applied to vehicle ['flow_00.969' 'flow_00.959' 'flow_00.950' 'flow_00.975']
#
# Step = 10867, Shock params: (-1.146022469323508, 1.4, 57) applied to vehicle ['flow_00.969' 'flow_00.959' 'flow_00.950' 'flow_00.975']
#
# Step = 10868, Shock params: (-1.146022469323508, 1.4, 57) applied to vehicle ['flow_00.969' 'flow_00.959' 'flow_00.950' 'flow_00.975']
#
# Step = 10869, Shock params: (-1.146022469323508, 1.4, 57) applied to vehicle ['flow_00.969' 'flow_00.959' 'flow_00.950' 'flow_00.975']
#
# Step = 10870, Shock params: (-1.146022469323508, 1.4, 57) applied to vehicle ['flow_00.969' 'flow_00.959' 'flow_00.950' 'flow_00.975']
#
# Step = 10871, Shock params: (-1.146022469323508, 1.4, 57) applied to vehicle ['flow_00.969' 'flow_00.959' 'flow_00.950' 'flow_00.975']
#
# Step = 10872, Shock params: (-1.146022469323508, 1.4, 57) applied to vehicle ['flow_00.969' 'flow_00.959' 'flow_00.950' 'flow_00.975']
#
# Step = 10873, Shock params: (-1.146022469323508, 1.4, 57) applied to vehicle ['flow_00.969' 'flow_00.959' 'flow_00.950' 'flow_00.975']
#
# Step = 10874, Shock params: (-1.146022469323508, 1.4, 57) applied to vehicle ['flow_00.969' 'flow_00.959' 'flow_00.950' 'flow_00.975']
#
# Step = 10875, Shock params: (-1.146022469323508, 1.4, 57) applied to vehicle ['flow_00.969' 'flow_00.959' 'flow_00.950' 'flow_00.975']
#
#
#
# Shock ids: ['flow_00.806' 'flow_00.974' 'flow_00.993' 'flow_00.783']
#
#
# Step = 10926, Shock params: (-1.3904190666346297, 1.0, 57) applied to vehicle ['flow_00.806' 'flow_00.974' 'flow_00.993' 'flow_00.783']
#
# Step = 10927, Shock params: (-1.3904190666346297, 1.0, 57) applied to vehicle ['flow_00.806' 'flow_00.974' 'flow_00.993' 'flow_00.783']
#
# Step = 10928, Shock params: (-1.3904190666346297, 1.0, 57) applied to vehicle ['flow_00.806' 'flow_00.974' 'flow_00.993' 'flow_00.783']
#
# Step = 10929, Shock params: (-1.3904190666346297, 1.0, 57) applied to vehicle ['flow_00.806' 'flow_00.974' 'flow_00.993' 'flow_00.783']
#
# Step = 10930, Shock params: (-1.3904190666346297, 1.0, 57) applied to vehicle ['flow_00.806' 'flow_00.974' 'flow_00.993' 'flow_00.783']
#
# Step = 10931, Shock params: (-1.3904190666346297, 1.0, 57) applied to vehicle ['flow_00.806' 'flow_00.974' 'flow_00.993' 'flow_00.783']
#
# Step = 10932, Shock params: (-1.3904190666346297, 1.0, 57) applied to vehicle ['flow_00.806' 'flow_00.974' 'flow_00.993' 'flow_00.783']
#
# Step = 10933, Shock params: (-1.3904190666346297, 1.0, 57) applied to vehicle ['flow_00.806' 'flow_00.974' 'flow_00.993' 'flow_00.783']
#
# Step = 10934, Shock params: (-1.3904190666346297, 1.0, 57) applied to vehicle ['flow_00.806' 'flow_00.974' 'flow_00.993' 'flow_00.783']
#
# Step = 10935, Shock params: (-1.3904190666346297, 1.0, 57) applied to vehicle ['flow_00.806' 'flow_00.974' 'flow_00.993' 'flow_00.783']
#
# Step = 10936, Shock params: (-1.3904190666346297, 1.0, 57) applied to vehicle ['flow_00.806' 'flow_00.974' 'flow_00.993' 'flow_00.783']
#
#
#
# Shock ids: ['flow_00.879' 'flow_00.879' 'flow_00.1003' 'flow_00.962']
#
#
# Step = 10991, Shock params: (-1.056495844867419, 0.9, 57) applied to vehicle ['flow_00.879' 'flow_00.879' 'flow_00.1003' 'flow_00.962']
#
# Step = 10992, Shock params: (-1.056495844867419, 0.9, 57) applied to vehicle ['flow_00.879' 'flow_00.879' 'flow_00.1003' 'flow_00.962']
#
# Step = 10993, Shock params: (-1.056495844867419, 0.9, 57) applied to vehicle ['flow_00.879' 'flow_00.879' 'flow_00.1003' 'flow_00.962']
#
# Step = 10994, Shock params: (-1.056495844867419, 0.9, 57) applied to vehicle ['flow_00.879' 'flow_00.879' 'flow_00.1003' 'flow_00.962']
#
# Step = 10995, Shock params: (-1.056495844867419, 0.9, 57) applied to vehicle ['flow_00.879' 'flow_00.879' 'flow_00.1003' 'flow_00.962']
#
# Step = 10996, Shock params: (-1.056495844867419, 0.9, 57) applied to vehicle ['flow_00.879' 'flow_00.879' 'flow_00.1003' 'flow_00.962']
#
# Step = 10997, Shock params: (-1.056495844867419, 0.9, 57) applied to vehicle ['flow_00.879' 'flow_00.879' 'flow_00.1003' 'flow_00.962']
#
# Step = 10998, Shock params: (-1.056495844867419, 0.9, 57) applied to vehicle ['flow_00.879' 'flow_00.879' 'flow_00.1003' 'flow_00.962']
#
# Step = 10999, Shock params: (-1.056495844867419, 0.9, 57) applied to vehicle ['flow_00.879' 'flow_00.879' 'flow_00.1003' 'flow_00.962']
#
# Round 0, return: 11000
# /mnt/c/Users/09_gi/Desktop/flow/poudel_bottleneck/test_time_rollout/idm/bottleneck_2_idm_20230911-1057191694444239.1451883-0_emission.csv /mnt/c/Users/09_gi/Desktop/flow/poudel_bottleneck/test_time_rollout/idm
# Average, std returns: 11000.0, 0.0
# Average, std velocities: 8.986892361913519, 0.0
# Average, std outflows: 2865.6, 0.0
# Total time: 310.14441561698914
# steps/second: 52.35368334686247
# /mnt/c/Users/09_gi/Desktop/flow/flow/utils/flow_warnings.py:26: PendingDeprecationWarning: The attribute departLane in InFlows is deprecated, use depart_lane instead.
#   PendingDeprecationWarning
# /mnt/c/Users/09_gi/Desktop/flow/flow/utils/flow_warnings.py:26: PendingDeprecationWarning: The attribute departSpeed in InFlows is deprecated, use depart_speed instead.
#   PendingDeprecationWarning
# Frequency: 42
# Intensity: -2.224352512653411
# Duration: 1.6
# Intensity: -2.387366904834997
# Duration: 2.0
# Intensity: -1.2239636028229068
# Duration: 0.7
# Intensity: -2.740358409264145
# Duration: 0.7
# Intensity: -2.1880947587074946
# Duration: 2.0
# Intensity: -1.2089678901871337
# Duration: 1.6
# Intensity: -2.1767248237550314
# Duration: 2.0
# Intensity: -1.1563745706617932
# Duration: 0.4
# Intensity: -1.0783799437356887
# Duration: 1.5
# Intensity: -1.1249731602288708
# Duration: 1.0
# Intensity: -2.0047689583028463
# Duration: 1.7
# Intensity: -2.994801649110084
# Duration: 2.5
# Intensity: -1.3473156153314183
# Duration: 0.9
# Intensity: -2.0425529114299152
# Duration: 1.1
# Intensity: -1.9492527441653964
# Duration: 1.7
# Intensity: -2.9803217112600993
# Duration: 1.4
# Intensity: -2.095701588702566
# Duration: 1.0
# Intensity: -1.8755557633876918
# Duration: 0.7
# Intensity: -2.141994110245946
# Duration: 1.0
# Intensity: -2.840111188521478
# Duration: 2.1
# Intensity: -2.3972523650699697
# Duration: 0.6
# Intensity: -2.5633761327117313
# Duration: 1.5
# Intensity: -2.45242166206821
# Duration: 1.7
# Intensity: -1.0095550346027116
# Duration: 1.4
# Intensity: -1.301090980094003
# Duration: 1.6
# Intensity: -2.5472194536758233
# Duration: 1.7
# Intensity: -1.6866132346176363
# Duration: 1.0
# Intensity: -2.9511693673117554
# Duration: 2.4
# Intensity: -1.525196121479873
# Duration: 1.6
# Intensity: -2.4971492581050265
# Duration: 1.5
# Intensity: -1.8334092551898886
# Duration: 1.4
# Intensity: -1.565928013093045
# Duration: 1.1
# Intensity: -1.3876251847835386
# Duration: 1.0
# Intensity: -2.6636851652639657
# Duration: 2.2
# Intensity: -2.214800082572232
# Duration: 0.6
# Intensity: -2.428290512736808
# Duration: 1.6
# Intensity: -1.649819558979503
# Duration: 0.9
# Intensity: -2.9706401651711243
# Duration: 2.2
# Intensity: -1.061001697663586
# Duration: 1.5
# Intensity: -1.892036148975849
# Duration: 0.9
# Intensity: -1.8350054740489883
# Duration: 0.9
# Intensity: -1.2142918061382066
# Duration: 0.6
# Durations:  [16. 20.  7.  7. 20. 16. 20.  4. 15. 10. 17. 25.  9. 11. 17. 14. 10.  7.
#  10. 21.  6. 15. 17. 14. 16. 17. 10. 24. 16. 15. 14. 11. 10. 22.  6. 16.
#   9. 22. 15.  9.  9.  6.]
# Start times:  [ 7400  7487  7575  7662  7750  7838  7925  8013  8101  8188  8276  8364
#   8451  8539  8627  8714  8802  8890  8977  9065  9153  9240  9328  9416
#   9503  9591  9679  9766  9854  9942 10029 10117 10205 10292 10380 10468
#  10555 10643 10731 10818 10906 10994]
# End times:  [7416.0, 7507.0, 7582.0, 7669.0, 7770.0, 7854.0, 7945.0, 8017.0, 8116.0, 8198.0, 8293.0, 8389.0, 8460.0, 8550.0, 8644.0, 8728.0, 8812.0, 8897.0, 8987.0, 9086.0, 9159.0, 9255.0, 9345.0, 9430.0, 9519.0, 9608.0, 9689.0, 9790.0, 9870.0, 9957.0, 10043.0, 10128.0, 10215.0, 10314.0, 10386.0, 10484.0, 10564.0, 10665.0, 10746.0, 10827.0, 10915.0, 11000.0]
# Shock times:
#  [[ 7400.  7416.]
#  [ 7487.  7507.]
#  [ 7575.  7582.]
#  [ 7662.  7669.]
#  [ 7750.  7770.]
#  [ 7838.  7854.]
#  [ 7925.  7945.]
#  [ 8013.  8017.]
#  [ 8101.  8116.]
#  [ 8188.  8198.]
#  [ 8276.  8293.]
#  [ 8364.  8389.]
#  [ 8451.  8460.]
#  [ 8539.  8550.]
#  [ 8627.  8644.]
#  [ 8714.  8728.]
#  [ 8802.  8812.]
#  [ 8890.  8897.]
#  [ 8977.  8987.]
#  [ 9065.  9086.]
#  [ 9153.  9159.]
#  [ 9240.  9255.]
#  [ 9328.  9345.]
#  [ 9416.  9430.]
#  [ 9503.  9519.]
#  [ 9591.  9608.]
#  [ 9679.  9689.]
#  [ 9766.  9790.]
#  [ 9854.  9870.]
#  [ 9942.  9957.]
#  [10029. 10043.]
#  [10117. 10128.]
#  [10205. 10215.]
#  [10292. 10314.]
#  [10380. 10386.]
#  [10468. 10484.]
#  [10555. 10564.]
#  [10643. 10665.]
#  [10731. 10746.]
#  [10818. 10827.]
#  [10906. 10915.]
#  [10994. 11000.]]
# Traceback (most recent call last):
#   File "classic.py", line 55, in <module>
#     run(args)
#   File "classic.py", line 44, in run
#     _ = exp.run(1, convert_to_csv=False)
#   File "/mnt/c/Users/09_gi/Desktop/flow/flow/core/experiment.py", line 145, in run
#     state, reward, done, _ = self.env.step(rl_actions(state))
#   File "/mnt/c/Users/09_gi/Desktop/flow/flow/envs/classic_bottleneck.py", line 236, in step
#     return super().step(rl_actions)
#   File "/mnt/c/Users/09_gi/Desktop/flow/flow/envs/base.py", line 369, in step
#     self.k.simulation.simulation_step()
#   File "/mnt/c/Users/09_gi/Desktop/flow/flow/core/kernel/simulation/traci.py", line 92, in simulation_step
#     self.kernel_api.simulationStep()
#   File "/home/kurukshetra/anaconda3/envs/flow/lib/python3.7/site-packages/traci/connection.py", line 323, in simulationStep
#     result = self._sendExact()
#   File "/home/kurukshetra/anaconda3/envs/flow/lib/python3.7/site-packages/traci/connection.py", line 99, in _sendExact
#     raise FatalTraCIError("connection closed by SUMO")
# traci.exceptions.FatalTraCIError: connection closed by SUMO
# /mnt/c/Users/09_gi/Desktop/flow/poudel_bottleneck/test_time_rollout/idm/bottleneck_2_idm_20230911-1102301694444550.736012-0_emission.csv /mnt/c/Users/09_gi/Desktop/flow/poudel_bottleneck/test_time_rollout/idm

# %%
# !python eval_metrics.py --method idm --start_time 7400 --end_time 11000

# %% [markdown]
# ## RVs Deployed at 10%

# %%
# fs
# !python classic.py --method fs --gen_emission --num_rollouts $NUM_ROLLOUTS --shock --render

# %%
# !python eval_metrics.py --method fs --start_time 7400 --end_time 11000

# %%
# piws
# !python classic.py --method piws --gen_emission --num_rollouts $NUM_ROLLOUTS --shock --render

# %%
# !python eval_metrics.py --method pi --start_time 7400 --end_time 11000

# %%
# Vinitsky
# 3233 at around 13.5 M = 94 ep
# Here start time and end time is not 4400 and 8000 rather: 
# Data recording stars at warmup
chkpt = 94
# !python test_rllib.py ./Vinitsky_et_al/Trained_policies/PPO_BottleneckDesiredVelocityEnv-v0_18afac40_2023-09-04_11-31-19u4dl8wsj $chkpt\
--method vinitsky --num_rollouts $NUM_ROLLOUTS --gen_emission --shock --render

# %%
# !python eval_metrics.py --method vinitsky --start_time 7400 --end_time 11000

# %%
# Ours (10%)

# %% [markdown]
# ## RVs Deployed at 20%

# %%
# bcm 
# !python classic.py --method bcm --num_rollouts $NUM_ROLLOUTS --gen_emission --shock --render
# Out:
# /mnt/c/Users/09_gi/Desktop/flow/flow/utils/flow_warnings.py:26: PendingDeprecationWarning: The attribute departLane in InFlows is deprecated, use depart_lane instead.
#   PendingDeprecationWarning
# /mnt/c/Users/09_gi/Desktop/flow/flow/utils/flow_warnings.py:26: PendingDeprecationWarning: The attribute departSpeed in InFlows is deprecated, use depart_speed instead.
#   PendingDeprecationWarning
# /mnt/c/Users/09_gi/Desktop/flow/flow/utils/flow_warnings.py:26: PendingDeprecationWarning: The attribute departLane in InFlows is deprecated, use depart_lane instead.
#   PendingDeprecationWarning
# /mnt/c/Users/09_gi/Desktop/flow/flow/utils/flow_warnings.py:26: PendingDeprecationWarning: The attribute departSpeed in InFlows is deprecated, use depart_speed instead.
#   PendingDeprecationWarning
# Frequency: 27
# Intensity: -1.4780431008377957
# Duration: 0.7
# Intensity: -2.40265121943436
# Duration: 1.4
# Intensity: -2.5501364173416423
# Duration: 1.9
# Intensity: -2.882670394344556
# Duration: 2.2
# Intensity: -2.6035078805249574
# Duration: 2.0
# Intensity: -1.8110526664915625
# Duration: 2.1
# Intensity: -2.268461723885845
# Duration: 1.0
# Intensity: -2.3798655402442828
# Duration: 0.5
# Intensity: -1.791478470799625
# Duration: 1.0
# Intensity: -1.296469206307926
# Duration: 0.5
# Intensity: -1.349608431107857
# Duration: 1.9
# Intensity: -1.485911350299511
# Duration: 0.4
# Intensity: -1.3662919838982075
# Duration: 0.7
# Intensity: -1.3089327980577914
# Duration: 1.1
# Intensity: -1.4439861683633561
# Duration: 1.5
# Intensity: -1.9641140567537196
# Duration: 1.4
# Intensity: -2.4195198957016864
# Duration: 1.6
# Intensity: -2.7281890592556444
# Duration: 0.9
# Intensity: -1.206556500999123
# Duration: 0.5
# Intensity: -1.906699961528025
# Duration: 0.9
# Intensity: -2.592188694801038
# Duration: 1.1
# Intensity: -1.7680301693825726
# Duration: 0.9
# Intensity: -2.275609995866894
# Duration: 2.0
# Intensity: -1.2791164453370067
# Duration: 1.1
# Intensity: -2.340069883120788
# Duration: 0.6
# Intensity: -1.53966580351515
# Duration: 2.0
# Intensity: -1.0876949449649687
# Duration: 0.4
# Durations:  [ 7. 14. 19. 22. 20. 21. 10.  5. 10.  5. 19.  4.  7. 11. 15. 14. 16.  9.
#   5.  9. 11.  9. 20. 11.  6. 20.  4.]
# Start times:  [4400 4538 4676 4814 4953 5091 5229 5368 5506 5644 5783 5921 6059 6198
#  6336 6474 6612 6751 6889 7027 7166 7304 7442 7581 7719 7857 7996]
# End times:  [4407.0, 4552.0, 4695.0, 4836.0, 4973.0, 5112.0, 5239.0, 5373.0, 5516.0, 5649.0, 5802.0, 5925.0, 6066.0, 6209.0, 6351.0, 6488.0, 6628.0, 6760.0, 6894.0, 7036.0, 7177.0, 7313.0, 7462.0, 7592.0, 7725.0, 7877.0, 8000.0]
# Shock times:
#  [[4400. 4407.]
#  [4538. 4552.]
#  [4676. 4695.]
#  [4814. 4836.]
#  [4953. 4973.]
#  [5091. 5112.]
#  [5229. 5239.]
#  [5368. 5373.]
#  [5506. 5516.]
#  [5644. 5649.]
#  [5783. 5802.]
#  [5921. 5925.]
#  [6059. 6066.]
#  [6198. 6209.]
#  [6336. 6351.]
#  [6474. 6488.]
#  [6612. 6628.]
#  [6751. 6760.]
#  [6889. 6894.]
#  [7027. 7036.]
#  [7166. 7177.]
#  [7304. 7313.]
#  [7442. 7462.]
#  [7581. 7592.]
#  [7719. 7725.]
#  [7857. 7877.]
#  [7996. 8000.]]
# Changing vehicle type for classic_00.0 to bcm
# Changing vehicle type for classic_00.1 to bcm
# Changing vehicle type for classic_00.2 to bcm
# Changing vehicle type for classic_00.3 to bcm
# Changing vehicle type for classic_00.4 to bcm
# Changing vehicle type for classic_00.5 to bcm
# Changing vehicle type for classic_00.6 to bcm
# Changing vehicle type for classic_00.7 to bcm
# Changing vehicle type for classic_00.8 to bcm
# Changing vehicle type for classic_00.9 to bcm
# Changing vehicle type for classic_00.10 to bcm
# Changing vehicle type for classic_00.11 to bcm
# Changing vehicle type for classic_00.12 to bcm
# Changing vehicle type for classic_00.13 to bcm
# Changing vehicle type for classic_00.14 to bcm
# Changing vehicle type for classic_00.15 to bcm
# Changing vehicle type for classic_00.16 to bcm
# Changing vehicle type for classic_00.17 to bcm
# Changing vehicle type for classic_00.18 to bcm
# Changing vehicle type for classic_00.19 to bcm
# Changing vehicle type for classic_00.20 to bcm
# Changing vehicle type for classic_00.21 to bcm
# Changing vehicle type for classic_00.22 to bcm
# Changing vehicle type for classic_00.23 to bcm
# Changing vehicle type for classic_00.24 to bcm
# Changing vehicle type for classic_00.25 to bcm
# Changing vehicle type for classic_00.26 to bcm
# Changing vehicle type for classic_00.27 to bcm
# Changing vehicle type for classic_00.28 to bcm
# Changing vehicle type for classic_00.29 to bcm
# Changing vehicle type for classic_00.30 to bcm
# Changing vehicle type for classic_00.31 to bcm
# Changing vehicle type for classic_00.32 to bcm
# Changing vehicle type for classic_00.33 to bcm
# Changing vehicle type for classic_00.34 to bcm
# Changing vehicle type for classic_00.35 to bcm
# Changing vehicle type for classic_00.36 to bcm
# Changing vehicle type for classic_00.37 to bcm
# Changing vehicle type for classic_00.38 to bcm
# Changing vehicle type for classic_00.39 to bcm
# Changing vehicle type for classic_00.40 to bcm
# Changing vehicle type for classic_00.41 to bcm
# Changing vehicle type for classic_00.42 to bcm
# Changing vehicle type for classic_00.43 to bcm
# Changing vehicle type for classic_00.44 to bcm
# Changing vehicle type for classic_00.45 to bcm
# Changing vehicle type for classic_00.46 to bcm
# Changing vehicle type for classic_00.47 to bcm
# Changing vehicle type for classic_00.48 to bcm
# Changing vehicle type for classic_00.49 to bcm
# Changing vehicle type for classic_00.50 to bcm
# Changing vehicle type for classic_00.51 to bcm
# Changing vehicle type for classic_00.52 to bcm
# Changing vehicle type for classic_00.53 to bcm
# Changing vehicle type for classic_00.54 to bcm
# Changing vehicle type for classic_00.55 to bcm
# Changing vehicle type for classic_00.56 to bcm
# Changing vehicle type for classic_00.57 to bcm
# Changing vehicle type for classic_00.58 to bcm
# Changing vehicle type for classic_00.59 to bcm
# Changing vehicle type for classic_00.60 to bcm
# Changing vehicle type for classic_00.61 to bcm
# Changing vehicle type for classic_00.62 to bcm

# %%
# !python eval_metrics.py --method bcm --start_time 7400 --end_time 11000

# %%
# Ours (20%)

# %% [markdown]
# ## RVs Deployed at 40%

# %%
# lacc
# !python classic.py --method lacc --num_rollouts $NUM_ROLLOUTS --gen_emission --shock --render

# %%
# !python eval_metrics.py --method lacc --start_time 7400 --end_time 11000

# %%
# Ours (40%)
