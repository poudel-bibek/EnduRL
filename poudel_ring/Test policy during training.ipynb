# %% [markdown]
# ## Single Agent

# %%
# !python ../flow/visualize/visualizer_rllib.py \
/home/dh127-pc3/ray_results/density_aware_rl/PPO_DensityAwareRLEnv-v0_973a6732_2023-08-05_13-19-17g2c8qkbi 32
# Out:
# 2023-08-05 14:55:32,893	WARNING services.py:597 -- setpgrp failed, processes may not be cleaned up properly: [Errno 1] Operation not permitted.
# 2023-08-05 14:55:32,894	INFO resource_spec.py:216 -- Starting Ray with 6.2 GiB memory available for workers and up to 3.11 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# 2023-08-05 14:55:33,295	INFO trainer.py:371 -- Tip: set 'eager': true or the --eager flag to enable TensorFlow eager execution
# 2023-08-05 14:55:33,297	INFO trainer.py:512 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# 2023-08-05 14:55:36,598	WARNING util.py:45 -- Install gputil for GPU system monitoring.
# 2023-08-05 14:55:36,649	INFO trainable.py:346 -- Restored from checkpoint: /home/dh127-pc3/ray_results/density_aware_rl/PPO_DensityAwareRLEnv-v0_973a6732_2023-08-05_13-19-17g2c8qkbi/checkpoint_32/checkpoint-32
# ...

# %%
# !python ../flow/visualize/visualizer_rllib.py \
/home/dh127-pc3/ray_results/density_aware_rl/PPO_DensityAwareRLEnv-v0_9f06b80a_2023-07-30_19-17-237pw6u5d2 46

# %% [markdown]
# ## Multi Agent 4x

# %%
# !python ../flow/visualize/visualizer_rllib.py \
/home/dh127-pc3/ray_results/density_aware_multiagent_ring/PPO_MultiAgentDensityAwareRLEnv-v1_afccb59c_2023-07-25_09-01-00g1obocc_ 20

# %%
# !python ../flow/visualize/visualizer_rllib.py \
/home/dh127-pc3/ray_results/density_aware_multiagent_ring/PPO_MultiAgentDensityAwareRLEnv-v1_1080e51c_2023-07-24_09-40-41i7ba0qz0 46

# %% [markdown]
# ## Multi Agent 9x

# %%
# !python ../flow/visualize/visualizer_rllib.py \
/home/dh127-pc3/ray_results/PPO_MultiAgentDensityAwareRLEnv-v1_40834376_2023-07-30_19-43-22ly9k9abp 110
