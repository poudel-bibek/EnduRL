# %%
NUM_ROLLOUTS = 1
# !python test_rllib.py ./Ours/Trained_policies/ten_percent/PPO_DensityAwareBottleneckEnv-v0_a810b000_2023-09-15_10-03-33byrumwt9 1\
--method ours --num_rollouts $NUM_ROLLOUTS --gen_emission --shock --render
# Out:
# 2023-09-15 10:53:34,609	WARNING services.py:597 -- setpgrp failed, processes may not be cleaned up properly: [Errno 1] Operation not permitted.
# 2023-09-15 10:53:34,609	INFO resource_spec.py:216 -- Starting Ray with 30.81 GiB memory available for workers and up to 15.42 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# 2023-09-15 10:53:34,945	INFO trainer.py:371 -- Tip: set 'eager': true or the --eager flag to enable TensorFlow eager execution
# 2023-09-15 10:53:34,964	INFO trainer.py:512 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# 2023-09-15 10:53:38,136	WARNING util.py:45 -- Install gputil for GPU system monitoring.
# 2023-09-15 10:53:38,195	INFO trainable.py:346 -- Restored from checkpoint: ./Ours/Trained_policies/ten_percent/PPO_DensityAwareBottleneckEnv-v0_a810b000_2023-09-15_10-03-33byrumwt9/checkpoint_1/checkpoint-1
# 2023-09-15 10:53:38,195	INFO trainable.py:353 -- Current state after restoring: {'_iteration': 1, '_timesteps_total': 115200, '_time_total': 373.5308208465576, '_episodes_total': 32}
# Frequency: 39
# Intensity: -1.227218209297499
# Duration: 1.4
# Intensity: -2.7367944850968193
# Duration: 1.6
# Intensity: -1.561814402429202
# Duration: 1.1
# Intensity: -1.9330985725009868
# Duration: 1.7
# Intensity: -2.3172165771750555
# Duration: 0.6
# Intensity: -2.4047869227343406
# Duration: 0.9
# Intensity: -2.077679304636038
# Duration: 1.4
# Intensity: -2.1200156822213456
# Duration: 1.6
# Intensity: -2.5455845229899756
# Duration: 2.2
# Intensity: -1.045347181640319
# Duration: 0.4
# Intensity: -1.2815263208062135
# Duration: 0.2
# Intensity: -2.9246352958984074
# Duration: 2.4
# Intensity: -1.0739342673771555
# Duration: 1.2
# Intensity: -2.6746598580891288
# Duration: 2.1
# Intensity: -2.0860704846096514
# Duration: 2.0
# Intensity: -1.7501037772162658
# Duration: 1.9
# Intensity: -2.5174582439354145
# Duration: 1.7
# Intensity: -2.6662633768838244
# Duration: 0.9
# Intensity: -1.1213841561761044
# Duration: 0.5
# Intensity: -2.5607563457796108
# Duration: 0.9
# Intensity: -2.7108639110428694
# Duration: 1.2
# Intensity: -1.1799209809273101
# Duration: 0.2
# Intensity: -2.43837272131848
# Duration: 1.9
# Intensity: -1.6531533041261133
# Duration: 0.2
# Intensity: -2.625704870628307
# Duration: 2.2
# Intensity: -2.5796983064944747
# Duration: 0.9
# Intensity: -2.9560876228038415
# Duration: 0.9
# Intensity: -2.3558721915603815
# Duration: 1.2
# Intensity: -1.9231205589857294
# Duration: 2.0
# Intensity: -1.2655397762254497
# Duration: 2.0
# Intensity: -1.0151872630270096
# Duration: 0.2
# Intensity: -1.7216699661826742
# Duration: 0.2
# Intensity: -2.8965522411462032
# Duration: 1.9
# Intensity: -1.253749705105904
# Duration: 1.5
# Intensity: -2.5390653380070614
# Duration: 1.4
# Intensity: -2.2179720053060237
# Duration: 0.7
# Intensity: -2.3868500677449527
# Duration: 1.9
# Intensity: -1.100550290315085
# Duration: 1.5
# Intensity: -1.3080485002474345
# Duration: 1.7
# Durations:  [14. 16. 11. 17.  6.  9. 14. 16. 22.  4.  2. 24. 12. 21. 20. 19. 17.  9.
#   5.  9. 12.  2. 19.  2. 22.  9.  9. 12. 20. 20.  2.  2. 19. 15. 14.  7.
#  19. 15. 17.]
# Start times:  [ 7400  7494  7588  7682  7777  7871  7965  8060  8154  8248  8342  8437
#   8531  8625  8720  8814  8908  9002  9097  9191  9285  9380  9474  9568
#   9662  9757  9851  9945 10040 10134 10228 10322 10417 10511 10605 10700
#  10794 10888 10983]
# End times:  [7414.0, 7510.0, 7599.0, 7699.0, 7783.0, 7880.0, 7979.0, 8076.0, 8176.0, 8252.0, 8344.0, 8461.0, 8543.0, 8646.0, 8740.0, 8833.0, 8925.0, 9011.0, 9102.0, 9200.0, 9297.0, 9382.0, 9493.0, 9570.0, 9684.0, 9766.0, 9860.0, 9957.0, 10060.0, 10154.0, 10230.0, 10324.0, 10436.0, 10526.0, 10619.0, 10707.0, 10813.0, 10903.0, 11000.0]
# Shock times:
#  [[ 7400.  7414.]
#  [ 7494.  7510.]
#  [ 7588.  7599.]
#  [ 7682.  7699.]
#  [ 7777.  7783.]
#  [ 7871.  7880.]
#  [ 7965.  7979.]
#  [ 8060.  8076.]
#  [ 8154.  8176.]
#  [ 8248.  8252.]
#  [ 8342.  8344.]
#  [ 8437.  8461.]
#  [ 8531.  8543.]
#  [ 8625.  8646.]
#  [ 8720.  8740.]
#  [ 8814.  8833.]
#  [ 8908.  8925.]
#  [ 9002.  9011.]
#  [ 9097.  9102.]
#  [ 9191.  9200.]
#  [ 9285.  9297.]
#  [ 9380.  9382.]
#  [ 9474.  9493.]
#  [ 9568.  9570.]
#  [ 9662.  9684.]
#  [ 9757.  9766.]
#  [ 9851.  9860.]
#  [ 9945.  9957.]
#  [10040. 10060.]
#  [10134. 10154.]
#  [10228. 10230.]
#  [10322. 10324.]
#  [10417. 10436.]
#  [10511. 10526.]
#  [10605. 10619.]
#  [10700. 10707.]
#  [10794. 10813.]
#  [10888. 10903.]
#  [10983. 11000.]]
# Round 0, Return: -49880.19074459841
# ==== END ====
# Return:
# [11.68492546050601]
# [-49880.19074459841]
# Average, std: -49880.19074459841, 0.0
#
# Speed, mean (m/s):
# [11.68492546050601]
# Average, std: 11.68492546050601, 0.0
#
# Speed, std (m/s):
# [5.392868586631675]
# Average, std: 5.392868586631675, 0.0
#
# Outflows (veh/hr):
# [2894.4]
# Average, std: 2894.4, 0.0
# Inflows (veh/hr):
# [3600.0]
# Average, std: 3600.0, 0.0
# Throughput efficiency (veh/hr):
# [0.804]
# Average, std: 0.804, 0.0
# /mnt/c/Users/09_gi/Desktop/flow/poudel_bottleneck/test_time_rollout/ours/bottleneck_ours_20230915-1053341694789614.966235-0_emission.csv /mnt/c/Users/09_gi/Desktop/flow/poudel_bottleneck/test_time_rollout/ours
