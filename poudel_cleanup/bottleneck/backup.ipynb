# %%
# !python eval_metrics.py --method ours --start_time 7400 --end_time 11000

# %%
NUM_ROLLOUTS = 1
# !python test_rllib.py ./Ours/Trained_policies/ten_percent/PPO_DensityAwareBottleneckEnv-v0_a810b000_2023-09-15_10-03-33byrumwt9 1\
--method ours --num_rollouts $NUM_ROLLOUTS --gen_emission --shock --render
# Out:
# 2023-09-15 10:53:20,827	WARNING services.py:597 -- setpgrp failed, processes may not be cleaned up properly: [Errno 1] Operation not permitted.
# 2023-09-15 10:53:20,828	INFO resource_spec.py:216 -- Starting Ray with 30.47 GiB memory available for workers and up to 15.25 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# 2023-09-15 10:53:21,144	INFO trainer.py:371 -- Tip: set 'eager': true or the --eager flag to enable TensorFlow eager execution
# 2023-09-15 10:53:21,148	INFO trainer.py:512 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# 2023-09-15 10:53:24,473	WARNING util.py:45 -- Install gputil for GPU system monitoring.
# 2023-09-15 10:53:24,541	INFO trainable.py:346 -- Restored from checkpoint: ./Ours/Trained_policies/ten_percent/PPO_DensityAwareBottleneckEnv-v0_a810b000_2023-09-15_10-03-33byrumwt9/checkpoint_1/checkpoint-1
# 2023-09-15 10:53:24,541	INFO trainable.py:353 -- Current state after restoring: {'_iteration': 1, '_timesteps_total': 115200, '_time_total': 373.5308208465576, '_episodes_total': 32}
# Frequency: 57
# Intensity: -1.6552495514296242
# Duration: 1.0
# Intensity: -1.4261802032100412
# Duration: 2.0
# Intensity: -1.7059315079521666
# Duration: 1.7
# Intensity: -1.941353318844621
# Duration: 1.4
# Intensity: -1.2262597322377142
# Duration: 1.5
# Intensity: -1.7057799918579617
# Duration: 0.9
# Intensity: -1.9091144960955346
# Duration: 1.5
# Intensity: -1.0018397462015403
# Duration: 0.7
# Intensity: -2.761038937042838
# Duration: 1.6
# Intensity: -2.7621179627202253
# Duration: 2.0
# Intensity: -2.449688531928871
# Duration: 1.6
# Intensity: -2.7557335946485115
# Duration: 1.9
# Intensity: -1.9054437329158567
# Duration: 0.9
# Intensity: -1.5292559332161684
# Duration: 2.0
# Intensity: -1.111316790825445
# Duration: 0.2
# Intensity: -1.8374163091081228
# Duration: 1.2
# Intensity: -1.7103734738252279
# Duration: 0.2
# Intensity: -1.563674543160673
# Duration: 1.4
# Intensity: -2.7383696161842197
# Duration: 2.2
# Intensity: -1.9514089980577471
# Duration: 1.7
# Intensity: -2.3011260122301067
# Duration: 2.4
# Intensity: -1.86664857376842
# Duration: 1.0
# Intensity: -1.7974506437647784
# Duration: 0.6
# Intensity: -2.3831878382159157
# Duration: 1.5
# Intensity: -1.8024934455486294
# Duration: 1.1
# Intensity: -1.1779031915129001
# Duration: 0.2
# Intensity: -2.668344400234978
# Duration: 1.6
# Intensity: -2.6409853371444107
# Duration: 1.9
# Intensity: -2.442608152152917
# Duration: 1.5
# Intensity: -2.9607073364097545
# Duration: 1.4
# Intensity: -1.9742127443236581
# Duration: 0.2
# Intensity: -1.8607303369748207
# Duration: 0.9
# Intensity: -1.2674783989752185
# Duration: 2.0
# Intensity: -1.6943158510734873
# Duration: 1.0
# Intensity: -1.5734397796026232
# Duration: 1.2
# Intensity: -2.3067869975185347
# Duration: 2.0
# Intensity: -1.4065954770840372
# Duration: 1.2
# Intensity: -2.393675794469904
# Duration: 1.7
# Intensity: -2.427471723553583
# Duration: 1.0
# Intensity: -1.8675306721297835
# Duration: 1.7
# Intensity: -1.0358686633221943
# Duration: 1.1
# Intensity: -1.0666364551518848
# Duration: 0.7
# Intensity: -2.163906150855448
# Duration: 0.6
# Intensity: -2.1425981238060023
# Duration: 0.7
# Intensity: -1.838150304636205
# Duration: 1.6
# Intensity: -1.4036189475780907
# Duration: 0.2
# Intensity: -2.720256518059384
# Duration: 2.0
# Intensity: -1.6965980192109054
# Duration: 1.0
# Intensity: -2.9294130938195466
# Duration: 1.5
# Intensity: -1.5502420965091237
# Duration: 0.7
# Intensity: -2.0105722108992645
# Duration: 0.9
# Intensity: -1.9759886821620116
# Duration: 1.2
# Intensity: -2.8576928167328983
# Duration: 2.1
# Intensity: -1.9166706864736318
# Duration: 1.6
# Intensity: -2.794879348363361
# Duration: 1.9
# Intensity: -2.045465498475644
# Duration: 1.1
# Intensity: -1.139788696801875
# Duration: 0.2
# Durations:  [10. 20. 17. 14. 15.  9. 15.  7. 16. 20. 16. 19.  9. 20.  2. 12.  2. 14.
#  22. 17. 24. 10.  6. 15. 11.  2. 16. 19. 15. 14.  2.  9. 20. 10. 12. 20.
#  12. 17. 10. 17. 11.  7.  6.  7. 16.  2. 20. 10. 15.  7.  9. 12. 21. 16.
#  19. 11.  2.]
# Start times:  [ 7400  7464  7528  7592  7657  7721  7785  7849  7914  7978  8042  8106
#   8171  8235  8299  8363  8428  8492  8556  8620  8685  8749  8813  8877
#   8942  9006  9070  9134  9199  9263  9327  9391  9456  9520  9584  9648
#   9713  9777  9841  9905  9970 10034 10098 10162 10227 10291 10355 10419
#  10484 10548 10612 10676 10741 10805 10869 10933 10998]
# End times:  [7410.0, 7484.0, 7545.0, 7606.0, 7672.0, 7730.0, 7800.0, 7856.0, 7930.0, 7998.0, 8058.0, 8125.0, 8180.0, 8255.0, 8301.0, 8375.0, 8430.0, 8506.0, 8578.0, 8637.0, 8709.0, 8759.0, 8819.0, 8892.0, 8953.0, 9008.0, 9086.0, 9153.0, 9214.0, 9277.0, 9329.0, 9400.0, 9476.0, 9530.0, 9596.0, 9668.0, 9725.0, 9794.0, 9851.0, 9922.0, 9981.0, 10041.0, 10104.0, 10169.0, 10243.0, 10293.0, 10375.0, 10429.0, 10499.0, 10555.0, 10621.0, 10688.0, 10762.0, 10821.0, 10888.0, 10944.0, 11000.0]
# Shock times:
#  [[ 7400.  7410.]
#  [ 7464.  7484.]
#  [ 7528.  7545.]
#  [ 7592.  7606.]
#  [ 7657.  7672.]
#  [ 7721.  7730.]
#  [ 7785.  7800.]
#  [ 7849.  7856.]
#  [ 7914.  7930.]
#  [ 7978.  7998.]
#  [ 8042.  8058.]
#  [ 8106.  8125.]
#  [ 8171.  8180.]
#  [ 8235.  8255.]
#  [ 8299.  8301.]
#  [ 8363.  8375.]
#  [ 8428.  8430.]
#  [ 8492.  8506.]
#  [ 8556.  8578.]
#  [ 8620.  8637.]
#  [ 8685.  8709.]
#  [ 8749.  8759.]
#  [ 8813.  8819.]
#  [ 8877.  8892.]
#  [ 8942.  8953.]
#  [ 9006.  9008.]
#  [ 9070.  9086.]
#  [ 9134.  9153.]
#  [ 9199.  9214.]
#  [ 9263.  9277.]
#  [ 9327.  9329.]
#  [ 9391.  9400.]
#  [ 9456.  9476.]
#  [ 9520.  9530.]
#  [ 9584.  9596.]
#  [ 9648.  9668.]
#  [ 9713.  9725.]
#  [ 9777.  9794.]
#  [ 9841.  9851.]
#  [ 9905.  9922.]
#  [ 9970.  9981.]
#  [10034. 10041.]
#  [10098. 10104.]
#  [10162. 10169.]
#  [10227. 10243.]
#  [10291. 10293.]
#  [10355. 10375.]
#  [10419. 10429.]
#  [10484. 10499.]
#  [10548. 10555.]
#  [10612. 10621.]
#  [10676. 10688.]
#  [10741. 10762.]
#  [10805. 10821.]
#  [10869. 10888.]
#  [10933. 10944.]
#  [10998. 11000.]]
# Round 0, Return: -60014.96671563232
# ==== END ====
# Return:
# [9.698462876024916]
# [-60014.96671563232]
# Average, std: -60014.96671563232, 0.0
#
# Speed, mean (m/s):
# [9.698462876024916]
# Average, std: 9.698462876024916, 0.0
#
# Speed, std (m/s):
# [4.808704916631915]
# Average, std: 4.808704916631915, 0.0
#
# Outflows (veh/hr):
# [2923.2]
# Average, std: 2923.2, 0.0
# Inflows (veh/hr):
# [3600.0]
# Average, std: 3600.0, 0.0
# Throughput efficiency (veh/hr):
# [0.8119999999999999]
# Average, std: 0.8119999999999999, 0.0
# /mnt/c/Users/09_gi/Desktop/flow/poudel_bottleneck/test_time_rollout/ours/bottleneck_ours_20230915-1053211694789601.1496096-0_emission.csv /mnt/c/Users/09_gi/Desktop/flow/poudel_bottleneck/test_time_rollout/ours
