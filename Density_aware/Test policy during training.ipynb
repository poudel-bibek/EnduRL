# %%
# !python ../flow/visualize/visualizer_rllib.py \
./Ours/ray_results/density_aware_rl/PPO_DensityAwareRLEnv-v0_6084ebb2_2023-07-08_20-53-184rs2grgx 100
# Out:
# 2023-07-09 09:28:03,267	WARNING services.py:597 -- setpgrp failed, processes may not be cleaned up properly: [Errno 1] Operation not permitted.
# 2023-07-09 09:28:03,267	INFO resource_spec.py:216 -- Starting Ray with 1.81 GiB memory available for workers and up to 0.91 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# 2023-07-09 09:28:04,087	INFO trainer.py:371 -- Tip: set 'eager': true or the --eager flag to enable TensorFlow eager execution
# 2023-07-09 09:28:04,104	INFO trainer.py:512 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# 2023-07-09 09:28:10,470	WARNING util.py:45 -- Install gputil for GPU system monitoring.
# 2023-07-09 09:28:10,595	INFO trainable.py:346 -- Restored from checkpoint: ./Ours/ray_results/density_aware_rl/PPO_DensityAwareRLEnv-v0_6084ebb2_2023-07-08_20-53-184rs2grgx/checkpoint_100/checkpoint-100
# ...

# %%
# !pwd; cd ..; pwd; cd flow; ls; cd visualize; ls
# Out:
# /mnt/c/Users/09_gi/Desktop/flow/Density_aware
# /mnt/c/Users/09_gi/Desktop/flow
# __init__.py  config.py	  density_aware_util.py  networks   utils
# __pycache__  controllers  envs			 renderer   version.py
# benchmarks   core	  multiagent_envs	 scenarios  visualize
# __init__.py		       plot_ray_results.py    visualizer_rllib.py
# capacity_diagram_generator.py  time_space_diagram.py

# %%
# continue training from checkpoint
