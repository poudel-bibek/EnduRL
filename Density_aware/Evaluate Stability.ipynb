# %% [markdown]
# ### Metrics:
# 1. Wave Attenuation Ratio (WAR)
# 2. Controller Acceleration Variation (CAV)
#
# ### Notes:
#
# - Desired velocity change for FS is automaically handeled for 220, NOT YET FOR 270
# - PI can have failures, so have to turn ON render and manually check
# - LACC needs a different shock time (for no shock change time at eval)
# - Generated data will be saved in the folder `test_time_rollout`

# %% [markdown]
# ## Ring

# %%
# set parameters here

# %% [markdown]
# ### 0. IDM

# %%
# IDM

# %% [markdown]
# ### 1. Single Vehicle Systems

# %% [markdown]
# __FS__

# %%
# For CAV (first: get the data)
# !python classic.py --method fs --length 220 --gen_emission --num_rollouts 20 --shock
# Out:
# length:  220
# Desired Velocity:  2.7 m/s
# Frequency: 12
# Intensity: -1.4063559288106446
# Duration: 1.1
# Intensity: -2.2677650554122324
# Duration: 1.0
# Intensity: -1.293058971106681
# Duration: 1.5
# Intensity: -2.311803708552919
# Duration: 1.7
# Intensity: -2.0779891305283096
# Duration: 1.1
# Intensity: -1.1600004910144606
# Duration: 0.4
# Intensity: -2.8482825255017494
# Duration: 0.5
# Intensity: -1.2162746267341145
# Duration: 1.0
# Intensity: -2.8290798392686476
# Duration: 1.4
# Intensity: -1.4220224762534333
# Duration: 1.0
# Intensity: -2.4559135387775584
# Duration: 0.9
# Intensity: -2.3210492032057903
# Duration: 1.7
# Durations:  [11. 10. 15. 17. 11.  4.  5. 10. 14. 10.  9. 17.]
# Start times:  [ 8000  8271  8542  8813  9084  9355  9627  9898 10169 10440 10711 10983]
# End times:  [8011.0, 8281.0, 8557.0, 8830.0, 9095.0, 9359.0, 9632.0, 9908.0, 10183.0, 10450.0, 10720.0, 11000.0]
# Shock times:
#  [[ 8000.  8011.]
#  [ 8271.  8281.]
#  [ 8542.  8557.]
# ...

# %%
# For CAV (second: eval the data to get metrics)
# !python eval_metrics.py --method fs --metric stability

# %%
# For WAR

# %% [markdown]
# __PIwS__

# %%
# PIwS

# %%
# Wu et. al.

# %%
# Ours

# %% [markdown]
# ### 2. Multiple Vehicle Systems

# %%
# BCM

# %%
# LACC
